# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torchvision
from torchvision import datasets, models
from torchvision import transforms as T
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import pandas as pd
from skimage import io, transform
import matplotlib.image as mpimg
from PIL import Image
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F
import scipy
import random
import pickle
import scipy.io as sio
import torch.nn.init as I

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.ion()

from torch.utils.data import Dataset, DataLoader
import pandas as pd
import os
from skimage import io
import torch
from torchvision import transforms
import torchvision
from skimage import color
from torch.optim import lr_scheduler
from torchvision.utils import make_grid
import nibabel

# %%
import pickle
def pickling(file,path):
    pickle.dump(file,open(path,'wb'))
def unpickling(path):
    file_return=pickle.load(open(path,'rb'))
    return file_return

# %%
path = "../data_orig/100307/mri/"

# %%
img_orig = nibabel.freesurfer.mghformat.MGHImage.from_filename(path+"T1.mgz")
image = img_orig.get_data().astype(np.float64)
aseg_img = nibabel.freesurfer.mghformat.MGHImage.from_filename(path+"aparc+aseg.mgz")
aseg_img = aseg_img.get_data().astype(np.float64)

# %%
aseg_img.shape
# Out:
# (256, 256, 256)

# %%
uni = list(np.unique(aseg_img).astype(int))

# %%
# uni

# %%
available_segments = [0,2,4,5,7,8,10, 11, 12, 13, 14, 15, 16, 17, 18, 24, 26, 28, 30, 31, 41,
 43, 44, 46, 47, 49, 50, 51, 52, 53, 54, 58, 60, 62, 63, 77, 80, 85, 251, 252, 253,
 254, 255, 1000, 1001, 1002, 1003, 1005, 1006, 1007, 1008, 1009, 1010, 1011,
 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024,
 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 2000, 2001,
 2002, 2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028,
 2029, 2030, 2031, 2032, 2033, 2034, 2035]

# %%
rest_available = [2,4,5,7,8,10, 11, 12, 13, 14, 15, 16, 17, 18, 24, 26, 28, 30, 31, 41,
 43, 44, 46, 47, 49, 50, 51, 52, 53, 54, 58, 60, 62, 63, 77, 80, 85, 251, 252, 253,
 254, 255, 1000, 1001, 1002, 1003, 1005, 1006, 1007, 1008, 1009, 1010, 1011,
 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024,
 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 2000, 2001,
 2002, 2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028,
 2029, 2030, 2031, 2032, 2033, 2034, 2035]

# %%
# np.array(uni)==np.array(available_segment)

# %%
num_seg = len(rest_available)+1

# %%
class BrainImages(Dataset):
    def __init__(self, image_dir, label_dir, train_data = False, flipping = True, rotation = True, translation = True, \
                 coord = True):
        
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.flipping = flipping
        self.rotation = rotation
        self.translation = translation
        self.train_data = train_data
        self.coord = coord

    def __len__(self):
        return len(self.image_dir)

    def __getitem__(self,idx):
        image_path = self.image_dir[idx]
        aseg_path = self.label_dir[idx]
        
        img_orig = nibabel.freesurfer.mghformat.MGHImage.from_filename(image_path)
        image = img_orig.get_data().astype(np.float64)
        aseg_img = nibabel.freesurfer.mghformat.MGHImage.from_filename(aseg_path)
        aseg_img = aseg_img.get_data().astype(np.float64)

        flip = random.random() > 0.5
        angle = random.uniform(-10,10)
        dx = np.round(random.uniform(-20,20))
        dy = np.round(random.uniform(-20,20))
        
        im = Image.fromarray(image[0])
        target = Image.fromarray(aseg_img[0])
        if self.train_data:
            if self.flipping and flip:
                im = im.transpose(0)
                target = target.transpose(0)
            if self.rotation:
                im = im.rotate(angle)
                target = target.rotate(angle)
            if self.translation:
                im = im.transform((256,256),0, (1,0,dx,0,1,dy))
                target = target.transform((256,256),0,(1,0,dx,0,1,dy))
                
#        im = torch.from_numpy(np.array(im, np.float64, copy=False).reshape((1,256,256)))/255
        im = np.array(im, np.float64, copy=False)
        min_im = np.min(im)
        max_im = np.max(im)
        im = (im - min_im)/(max_im - min_im + 1e-4)
#         print(np.sum(im))
        if self.coord:
            im = np.array([im, x_coordinate, y_coordinate], np.float64, copy=False)
            im = torch.from_numpy(im).type(torch.FloatTensor)
        else:
            im = torch.from_numpy(im).type(torch.FloatTensor).unsqueeze(0)

        target = np.array(target, np.float64, copy=False)
        target_label = np.zeros((len(rest_available)+1,256,256))
        for i,a in enumerate(available_segments):
            temp = (target==a).astype(int)
            if a in rest_available:
                target_label[rest_available.index(a),:,:] = temp
            else:
                target_label[len(rest_available),:,:] = target_label[len(rest_available),:,:] + temp
        target_label[len(rest_available),:,:] = (target_label[len(rest_available),:,:]>=1).astype(int) 
#        print(target_label.shape)
        target_label = torch.from_numpy(target_label).type(torch.FloatTensor)
        sample = {'x':im,'y':target_label} 
        return sample

# %%
file_names = pd.read_csv("complete_path_aparc.csv")
# file_names = file_names.replace(to_replace=".*//.*",value="/")

# %%
train_subjects = unpickling("train_sub_index_aparc")
val_subjects = unpickling("val_sub_index_aparc")
test_subjects = unpickling("test_sub_index_aparc")

# %%
file_names['left_to_right_raw'][1].split('/')[8]
# Out:
# '126628'

# %%
train_subjects[1]
# Out:
# '307127'

# %%
len(list(set(train_subjects)))+len(list(set(val_subjects)))+len(list(set(test_subjects)))
# Out:
# 1113

# %%
file_names.shape
# Out:
# (284928, 6)

# %%
1113*256
# Out:
# 284928

# %%
# train_sub_index = []
# val_sub_index = []
# test_sub_index = []
# for i in range(len(file_names)):
#     name = file_names['left_to_right_raw'][i].split('/')[8]
#     if name in train_subjects:
#         train_sub_index.append(i)
#     elif name in val_subjects:
#         val_sub_index.append(i)
#     elif name in test_subjects:
#         test_sub_index.append(i)

# %%
# pickling(train_sub_index,"train_sub_index_aparc")
# pickling(val_sub_index,"val_sub_index_aparc")
# pickling(test_sub_index,"test_sub_index_aparc")

# %%
file_names.head()
# Out:
#                                    left_to_right_raw  \
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
#
#                              left_to_right_segmented  \
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/le...
#
#                                    top_to_bottom_raw  \
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
#
#                              top_to_bottom_segmented  \
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/to...
#
#                                    back_to_front_raw  \
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
#
#                              back_to_front_segmented
# 0  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 1  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 2  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 3  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...
# 4  /gpfs/data/cbi/hcp/hcp_seg/aparc_all_slices/ba...

# %%
full_train_raw = list(file_names.iloc[train_subjects,2])
full_train_seg = list(file_names.iloc[train_subjects,3])

full_val_raw = list(file_names.iloc[val_subjects,2])
full_val_seg = list(file_names.iloc[val_subjects,3])

full_test_raw = list(file_names.iloc[test_subjects,2])
full_test_seg = list(file_names.iloc[test_subjects,3])

# %%
rand1 = np.arange(len(full_train_raw))
np.random.shuffle(rand1)
rand1 = rand1[:4986]

rand2 = np.arange(len(val_subjects))
np.random.shuffle(rand2)
rand2 = rand2[:1000]

rand3 = np.arange(len(test_subjects))
np.random.shuffle(rand3)
rand3 = rand3[:3]

# %%
cd = False
transformed_dataset = {'train': BrainImages(np.array(full_train_raw)[rand1],np.array(full_train_seg)[rand1], train_data= True, flipping=False, coord = cd),
                       'validate': BrainImages(np.array(full_val_raw)[rand2],np.array(full_val_seg)[rand2], coord = cd),
                       'test': BrainImages(np.array(full_test_raw)[rand3],np.array(full_test_seg)[rand3], coord = cd)
                                               }
bs = 8
dataloader = {x: DataLoader(transformed_dataset[x], batch_size=bs,
                        shuffle=True, num_workers=0) for x in ['train', 'validate','test']}
data_sizes ={x: len(transformed_dataset[x]) for x in ['train', 'validate','test']}

# %%
data = next(iter(dataloader['train']))

# %%
data['x'].size(),data['y'].size()
# Out:
# (torch.Size([8, 1, 256, 256]), torch.Size([8, 113, 256, 256]))

# %%
# list_arr = []
# for data in dataloader["train"]:
#     y = data['y'].numpy()
#     N,C,_,_ = y.shape
#     sum_arr = np.sum(y.reshape(N,C,-1),axis = 2)
#     list_arr.append(sum_arr)
# final_arr = np.concatenate(list_arr,axis = 0)
# freq_class = np.true_divide(final_arr.sum(0),(final_arr!=0).sum(0)*(256*256))
# class_wts = np.median(freq_class)/freq_class
# pickling(class_wts,'new_class_wts_113_seg')

# %%
class_wts = unpickling('new_class_wts_113_seg')

# %%
class Downsample_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Downsample_block, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
    
    def forward(self,x):
        x = F.relu(self.bn1(self.conv1(x)))
        y = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(y, 2,stride = 2)
        
        return x, y

# %%
class Upsample_block(nn.Module):
    def __init__(self,in_channels, out_channels):
        super(Upsample_block, self).__init__()
        self.transconv = nn.ConvTranspose2d(in_channels, out_channels, 4, padding = 1, stride = 2)
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
    def forward(self,x, y):
        x = self.transconv(x)
        x = torch.cat((x,y),dim = 1)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        
        return x

# %%
class Unet(nn.Module):
    def __init__(self,in_chan = 3, out_chan = 3):
        super(Unet, self).__init__()
        self.down1 = Downsample_block(in_chan,64)
        self.down2 = Downsample_block(64,128)
        self.down3 = Downsample_block(128,256)
        self.down4 = Downsample_block(256,512)
        self.conv1 = nn.Conv2d(512,1024, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(1024)
        self.conv2 = nn.Conv2d(1024,1024,3, padding = 1)
        self.bn2 = nn.BatchNorm2d(1024)
        self.up4 = Upsample_block(1024,512)
        self.up3 = Upsample_block(512,256)
        self.up2 = Upsample_block(256,128)
        self.up1 = Upsample_block(128,64)
        self.outconv = nn.Conv2d(64,out_chan, 1)
        
    def forward(self,x):
        x, y1 = self.down1(x)
        x, y2 = self.down2(x)
        x, y3 = self.down3(x)
        x, y4 = self.down4(x)
        x = F.dropout2d(F.relu(self.bn1(self.conv1(x))))
        x = F.dropout2d(F.relu(self.bn2(self.conv2(x))))
        x = self.up4(x, y4)
        x = self.up3(x, y3)
        x = self.up2(x, y2)
        x = self.up1(x, y1)
        x = self.outconv(x)
        
        return x

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        I.xavier_normal(m.weight.data)

# %%
wts_torch = Variable(torch.from_numpy(class_wts)).cuda()

# %%
def dice_loss_2(true,scores,mean, flag="dice", epsilon = 1e-4,p = 2,we = 0.05):    
    N, C, sh1, sh2 = true.size()
    preds = F.softmax(scores, dim = 1)
    true = true.view(N, C, -1)
    preds = preds.view(N, C, -1)
    wts = torch.sum(true, dim = 2) + epsilon
    wts[:,:] = mean[None].repeat(N,1)
    grad_wts = torch.max(mean)
    prod = torch.sum(true*preds,dim = 2)
    sum_tnp = torch.sum(true + preds, dim = 2)
    num = torch.sum(wts * prod, dim = 1)
    denom = torch.sum(wts * sum_tnp, dim = 1) + epsilon
    loss = 1 - 2*(num/denom)
    cel = -torch.sum(wts * torch.sum(true*torch.log(preds),dim = 2),dim = 1)
#     return 40*torch.mean(loss)+we*torch.mean(cel)
    return torch.mean(loss)

# %%
def dice_score(true,scores, epsilon = 1e-7):
    N, C, sh1, sh2 = true.size()    
    true = true.view(N,C,-1)
    preds = F.softmax(scores, dim = 1)
    pred_class = (torch.max(preds, dim = 1)[1]).view(N,-1)
    class_score = [0]*C
    for i in range(C):
        class_score[i] = (pred_class == i).data.type(torch.cuda.FloatTensor)
    true = true.data.type(torch.cuda.FloatTensor)
    def numerator(truth,pred, idx):
        return(torch.sum(truth[:,idx,:] * pred,dim = 1)) + epsilon/2
    def denominator(truth,pred,idx):
        return(torch.sum(truth[:,idx,:]+pred,dim = 1)) + epsilon
    dice_class_score = [0]*C
    for i in range(C):
        dice_class_score[i] = torch.mean(2*(numerator(true,class_score[i],i))/(denominator(true,class_score[i],i)))
    return dice_class_score

# %%
import time
def train_model(model, optimizer,dataloader, name,num_seg = 3, num_epochs = 100, verbose = False, every = 1,\
                print_all_ds = True):
    since = time.time()
    best_loss = np.inf
    best_score = 0
    loss_hist = {'train':[],'validate':[]}
    dice_scores_of_all_class = [{'train':[],'validate':[]} for i in range(num_seg)]    
    for i in range(num_epochs):
        for phase in ['train', 'validate']:
            running_loss = 0
            run_class_scores = [0]*num_seg
            running_total = 0
            if phase == 'train':
                model.train(True)
            else:
                model.train(False)
    
            for data in dataloader[phase]:
                optimizer.zero_grad()
                x = data['x']
                y = data['y']
                x = Variable(x).cuda()
                y = Variable(y).cuda()
                N, C, sh1, sh2 = y.size()
                rand_num = np.random.rand()
                if rand_num < 0.90:
                    y_mask = (torch.sum(y[:,:(C-1),:,:].contiguous().view(N,-1),dim = 1) != 0)
                    y = y[y_mask]
                    x = x[y_mask]
                try:
                    output = model(x)
                except:
                    continue
                loss = dice_loss_2(y, output,wts_torch)
                if loss==-1:
                    continue
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                running_loss += loss.data[0] * N
                running_total += N
                dice_score_batch = dice_score(y,output)

                for j in range(num_seg):
                    run_class_scores[j] += dice_score_batch[j] * N
            epoch_loss = running_loss/running_total
            loss_hist[phase].append(epoch_loss.item())
            epoch_score = 0
            for j in range(num_seg):
                score = run_class_scores[j]/running_total
                dice_scores_of_all_class[j][phase].append(score.item())
                if j < num_seg - 1:
                    epoch_score += score.item()
            epoch_score_av = epoch_score/ (num_seg - 1)
            if verbose or i%every == 0:
                print('Epoch: {}, Phase: {}, epoch loss: {:.4f}, Av. Dice Score: {:.4f}'\
                      .format(i,phase,epoch_loss,epoch_score_av))
                if print_all_ds:
                    for j in range(num_seg - 1):
                        print('Class {} (DS): {:.4f}'.format(j,dice_scores_of_all_class[j][phase][-1]))
                print('-'*10)
            
        if phase == 'validate' and epoch_score_av > best_score:
            best_loss = epoch_loss
            best_score = epoch_score_av
            best_model_wts = model.state_dict()
            torch.save(model,name)
    print('-'*50)    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val dice loss: {:4f}, Best Average DS: {:4f}'.format(best_loss,best_score))
    
    model.load_state_dict(best_model_wts)
    pickling(loss_hist,name+'loss_hist')
    pickling(dice_scores_of_all_class,name+'dice_hist')
    
    return model, loss_hist, dice_scores_of_all_class

# %%
model = Unet(in_chan = 1,out_chan = num_seg).cuda()
model.apply(weights_init)
model = nn.DataParallel(model)
criterion = dice_loss_2

# %%
optimizer = optim.Adam(model.parameters(),lr = 1e-5)

# %%
model, loss_hist, dice_hist = train_model(model, optimizer,dataloader,'aparc_model1_1e-4_1',num_seg = num_seg, num_epochs = 10,\
                                         every = 1, print_all_ds = True)
# Out:
# Epoch: 0, Phase: train, epoch loss: 0.1736, Av. Dice Score: 0.9253
# Class 0 (DS): 0.9168
# Class 1 (DS): 0.9631
# Class 2 (DS): 0.9359
# Class 3 (DS): 0.9039
# Class 4 (DS): 0.9301
# Class 5 (DS): 0.9538
# Class 6 (DS): 0.9646
# Class 7 (DS): 0.9625
# Class 8 (DS): 0.9439
# Class 9 (DS): 0.9613
# Class 10 (DS): 0.9222
# Class 11 (DS): 0.9354
# Class 12 (DS): 0.9563
# Class 13 (DS): 0.9700
# Class 14 (DS): 0.9429
# Class 15 (DS): 0.9598
# Class 16 (DS): 0.9495
# Class 17 (DS): 0.9836
# Class 18 (DS): 0.8453
# Class 19 (DS): 0.9191
# Class 20 (DS): 0.9648
# Class 21 (DS): 0.9642
# Class 22 (DS): 0.9073
# Class 23 (DS): 0.9236
# Class 24 (DS): 0.9624
# Class 25 (DS): 0.9569
# Class 26 (DS): 0.9684
# Class 27 (DS): 0.9587
# Class 28 (DS): 0.9526
# Class 29 (DS): 0.9714
# Class 30 (DS): 0.9631
# Class 31 (DS): 0.9578
# Class 32 (DS): 0.9851
# Class 33 (DS): 0.8414
# Class 34 (DS): 0.8377
# Class 35 (DS): 0.9634
# Class 36 (DS): 0.9735
# Class 37 (DS): 0.9739
# Class 38 (DS): 0.9657
# Class 39 (DS): 0.9347
# Class 40 (DS): 0.9560
# Class 41 (DS): 0.9543
# Class 42 (DS): 0.6790
# Class 43 (DS): 0.9286
# Class 44 (DS): 0.9304
# Class 45 (DS): 0.9357
# Class 46 (DS): 0.9030
# Class 47 (DS): 0.9352
# Class 48 (DS): 0.9140
# Class 49 (DS): 0.9060
# Class 50 (DS): 0.8921
# Class 51 (DS): 0.9148
# Class 52 (DS): 0.9129
# Class 53 (DS): 0.9406
# Class 54 (DS): 0.9200
# Class 55 (DS): 0.9185
# Class 56 (DS): 0.8961
# Class 57 (DS): 0.9326
# Class 58 (DS): 0.9416
# Class 59 (DS): 0.9363
# Class 60 (DS): 0.9493
# Class 61 (DS): 0.9289
# Class 62 (DS): 0.9247
# Class 63 (DS): 0.9104
# Class 64 (DS): 0.9474
# Class 65 (DS): 0.9154
# Class 66 (DS): 0.8970
# Class 67 (DS): 0.9178
# Class 68 (DS): 0.9015
# Class 69 (DS): 0.9018
# Class 70 (DS): 0.9089
# Class 71 (DS): 0.8848
# Class 72 (DS): 0.9248
# Class 73 (DS): 0.9283
# Class 74 (DS): 0.9445
# Class 75 (DS): 0.9551
# Class 76 (DS): 0.9284
# Class 77 (DS): 0.7053
# Class 78 (DS): 0.9353
# Class 79 (DS): 0.9164
# Class 80 (DS): 0.9330
# Class 81 (DS): 0.8989
# Class 82 (DS): 0.9381
# Class 83 (DS): 0.9147
# Class 84 (DS): 0.9005
# Class 85 (DS): 0.8944
# Class 86 (DS): 0.9145
# Class 87 (DS): 0.9111
# Class 88 (DS): 0.9307
# Class 89 (DS): 0.9194
# Class 90 (DS): 0.9331
# Class 91 (DS): 0.8945
# Class 92 (DS): 0.9255
# Class 93 (DS): 0.9420
# Class 94 (DS): 0.9289
# Class 95 (DS): 0.9516
# Class 96 (DS): 0.9193
# Class 97 (DS): 0.9148
# Class 98 (DS): 0.9095
# Class 99 (DS): 0.9417
# Class 100 (DS): 0.9115
# Class 101 (DS): 0.8924
# Class 102 (DS): 0.9244
# Class 103 (DS): 0.9021
# Class 104 (DS): 0.9100
# Class 105 (DS): 0.8925
# Class 106 (DS): 0.8913
# Class 107 (DS): 0.9297
# Class 108 (DS): 0.9353
# Class 109 (DS): 0.9359
# Class 110 (DS): 0.9580
# Class 111 (DS): 0.9184
# ----------
# Epoch: 0, Phase: validate, epoch loss: 0.1591, Av. Dice Score: 0.9254
# Class 0 (DS): 0.9393
# Class 1 (DS): 0.9562
# Class 2 (DS): 0.9315
# Class 3 (DS): 0.9012
# Class 4 (DS): 0.9324
# Class 5 (DS): 0.9629
# Class 6 (DS): 0.9553
# Class 7 (DS): 0.9680
# Class 8 (DS): 0.9345
# Class 9 (DS): 0.9691
# Class 10 (DS): 0.9254
# Class 11 (DS): 0.9452
# Class 12 (DS): 0.9509
# Class 13 (DS): 0.9680
# Class 14 (DS): 0.9623
# Class 15 (DS): 0.9585
# Class 16 (DS): 0.9551
# Class 17 (DS): 0.9789
# Class 18 (DS): 0.8559
# Class 19 (DS): 0.9464
# Class 20 (DS): 0.9575
# Class 21 (DS): 0.9621
# Class 22 (DS): 0.8962
# Class 23 (DS): 0.9290
# Class 24 (DS): 0.9696
# Class 25 (DS): 0.9534
# Class 26 (DS): 0.9685
# Class 27 (DS): 0.9613
# Class 28 (DS): 0.9533
# Class 29 (DS): 0.9681
# Class 30 (DS): 0.9601
# Class 31 (DS): 0.9495
# Class 32 (DS): 0.9628
# Class 33 (DS): 0.8560
# Class 34 (DS): 0.8460
# Class 35 (DS): 0.9699
# Class 36 (DS): 0.9708
# Class 37 (DS): 0.9835
# Class 38 (DS): 0.9651
# Class 39 (DS): 0.9595
# Class 40 (DS): 0.9475
# Class 41 (DS): 0.9609
# Class 42 (DS): 0.6874
# Class 43 (DS): 0.9171
# Class 44 (DS): 0.9321
# Class 45 (DS): 0.9357
# Class 46 (DS): 0.9036
# Class 47 (DS): 0.9239
# Class 48 (DS): 0.8974
# Class 49 (DS): 0.9156
# Class 50 (DS): 0.8884
# Class 51 (DS): 0.9142
# Class 52 (DS): 0.9219
# Class 53 (DS): 0.9277
# Class 54 (DS): 0.9239
# Class 55 (DS): 0.9072
# Class 56 (DS): 0.8822
# Class 57 (DS): 0.9229
# Class 58 (DS): 0.9447
# Class 59 (DS): 0.9426
# Class 60 (DS): 0.9508
# Class 61 (DS): 0.9354
# Class 62 (DS): 0.9169
# Class 63 (DS): 0.9072
# Class 64 (DS): 0.9543
# Class 65 (DS): 0.9188
# Class 66 (DS): 0.9009
# Class 67 (DS): 0.9247
# Class 68 (DS): 0.8861
# Class 69 (DS): 0.8938
# Class 70 (DS): 0.9173
# Class 71 (DS): 0.8856
# Class 72 (DS): 0.9291
# Class 73 (DS): 0.9230
# Class 74 (DS): 0.9294
# Class 75 (DS): 0.9585
# Class 76 (DS): 0.9369
# Class 77 (DS): 0.7039
# Class 78 (DS): 0.9305
# Class 79 (DS): 0.9306
# Class 80 (DS): 0.9281
# Class 81 (DS): 0.8933
# Class 82 (DS): 0.9269
# Class 83 (DS): 0.9033
# Class 84 (DS): 0.8980
# Class 85 (DS): 0.8895
# Class 86 (DS): 0.9193
# Class 87 (DS): 0.8964
# Class 88 (DS): 0.9333
# Class 89 (DS): 0.9356
# Class 90 (DS): 0.9214
# Class 91 (DS): 0.8961
# Class 92 (DS): 0.9306
# Class 93 (DS): 0.9376
# Class 94 (DS): 0.9180
# Class 95 (DS): 0.9526
# Class 96 (DS): 0.9150
# Class 97 (DS): 0.9079
# Class 98 (DS): 0.9043
# Class 99 (DS): 0.9493
# Class 100 (DS): 0.9084
# Class 101 (DS): 0.9113
# Class 102 (DS): 0.9256
# Class 103 (DS): 0.9012
# Class 104 (DS): 0.9085
# Class 105 (DS): 0.9075
# Class 106 (DS): 0.8823
# Class 107 (DS): 0.9298
# Class 108 (DS): 0.9266
# Class 109 (DS): 0.9228
# Class 110 (DS): 0.9670
# Class 111 (DS): 0.9231
# ----------
# Epoch: 1, Phase: train, epoch loss: 0.1573, Av. Dice Score: 0.9283
# Class 0 (DS): 0.9243
# Class 1 (DS): 0.9605
# Class 2 (DS): 0.9440
# Class 3 (DS): 0.9092
# Class 4 (DS): 0.9252
# Class 5 (DS): 0.9592
# Class 6 (DS): 0.9656
# Class 7 (DS): 0.9625
# Class 8 (DS): 0.9467
# Class 9 (DS): 0.9652
# Class 10 (DS): 0.9237
# Class 11 (DS): 0.9376
# Class 12 (DS): 0.9572
# Class 13 (DS): 0.9694
# Class 14 (DS): 0.9537
# Class 15 (DS): 0.9614
# Class 16 (DS): 0.9535
# Class 17 (DS): 0.9831
# Class 18 (DS): 0.8509
# Class 19 (DS): 0.9239
# Class 20 (DS): 0.9681
# Class 21 (DS): 0.9686
# Class 22 (DS): 0.9111
# Class 23 (DS): 0.9272
# Class 24 (DS): 0.9692
# Class 25 (DS): 0.9599
# Class 26 (DS): 0.9675
# Class 27 (DS): 0.9604
# Class 28 (DS): 0.9566
# Class 29 (DS): 0.9710
# Class 30 (DS): 0.9640
# Class 31 (DS): 0.9620
# Class 32 (DS): 0.9862
# Class 33 (DS): 0.8444
# Class 34 (DS): 0.8416
# Class 35 (DS): 0.9644
# Class 36 (DS): 0.9718
# Class 37 (DS): 0.9752
# Class 38 (DS): 0.9647
# Class 39 (DS): 0.9479
# Class 40 (DS): 0.9586
# Class 41 (DS): 0.9602
# Class 42 (DS): 0.6628
# Class 43 (DS): 0.9309
# Class 44 (DS): 0.9333
# Class 45 (DS): 0.9367
# Class 46 (DS): 0.9026
# Class 47 (DS): 0.9406
# Class 48 (DS): 0.9193
# Class 49 (DS): 0.9139
# Class 50 (DS): 0.8969
# Class 51 (DS): 0.9162
# Class 52 (DS): 0.9189
# Class 53 (DS): 0.9428
# Class 54 (DS): 0.9210
# Class 55 (DS): 0.9141
# Class 56 (DS): 0.8964
# Class 57 (DS): 0.9364
# Class 58 (DS): 0.9453
# Class 59 (DS): 0.9355
# Class 60 (DS): 0.9533
# Class 61 (DS): 0.9281
# Class 62 (DS): 0.9246
# Class 63 (DS): 0.9194
# Class 64 (DS): 0.9509
# Class 65 (DS): 0.9199
# Class 66 (DS): 0.9025
# Class 67 (DS): 0.9200
# Class 68 (DS): 0.9088
# Class 69 (DS): 0.9081
# Class 70 (DS): 0.9131
# Class 71 (DS): 0.8884
# Class 72 (DS): 0.9250
# Class 73 (DS): 0.9352
# Class 74 (DS): 0.9480
# Class 75 (DS): 0.9611
# Class 76 (DS): 0.9305
# Class 77 (DS): 0.6881
# Class 78 (DS): 0.9352
# Class 79 (DS): 0.9216
# Class 80 (DS): 0.9304
# Class 81 (DS): 0.8982
# Class 82 (DS): 0.9438
# Class 83 (DS): 0.9202
# Class 84 (DS): 0.9020
# Class 85 (DS): 0.9015
# Class 86 (DS): 0.9155
# Class 87 (DS): 0.9148
# Class 88 (DS): 0.9374
# Class 89 (DS): 0.9213
# Class 90 (DS): 0.9324
# Class 91 (DS): 0.9018
# Class 92 (DS): 0.9338
# Class 93 (DS): 0.9458
# Class 94 (DS): 0.9319
# Class 95 (DS): 0.9537
# Class 96 (DS): 0.9220
# Class 97 (DS): 0.9176
# Class 98 (DS): 0.9159
# Class 99 (DS): 0.9455
# Class 100 (DS): 0.9191
# Class 101 (DS): 0.8999
# Class 102 (DS): 0.9282
# Class 103 (DS): 0.9056
# Class 104 (DS): 0.9158
# Class 105 (DS): 0.8991
# Class 106 (DS): 0.9002
# Class 107 (DS): 0.9293
# Class 108 (DS): 0.9372
# Class 109 (DS): 0.9461
# Class 110 (DS): 0.9620
# Class 111 (DS): 0.9222
# ----------
# Epoch: 1, Phase: validate, epoch loss: 0.1573, Av. Dice Score: 0.9246
# Class 0 (DS): 0.9416
# Class 1 (DS): 0.9577
# Class 2 (DS): 0.9480
# Class 3 (DS): 0.9061
# Class 4 (DS): 0.9254
# Class 5 (DS): 0.9658
# Class 6 (DS): 0.9516
# Class 7 (DS): 0.9661
# Class 8 (DS): 0.9399
# Class 9 (DS): 0.9696
# Class 10 (DS): 0.9230
# Class 11 (DS): 0.9409
# Class 12 (DS): 0.9539
# Class 13 (DS): 0.9723
# Class 14 (DS): 0.9641
# Class 15 (DS): 0.9624
# Class 16 (DS): 0.9638
# Class 17 (DS): 0.9779
# Class 18 (DS): 0.8674
# Class 19 (DS): 0.9500
# Class 20 (DS): 0.9514
# Class 21 (DS): 0.9747
# Class 22 (DS): 0.9060
# Class 23 (DS): 0.9244
# Class 24 (DS): 0.9682
# Class 25 (DS): 0.9553
# Class 26 (DS): 0.9677
# Class 27 (DS): 0.9594
# Class 28 (DS): 0.9526
# Class 29 (DS): 0.9709
# Class 30 (DS): 0.9636
# Class 31 (DS): 0.9568
# Class 32 (DS): 0.9759
# Class 33 (DS): 0.8700
# Class 34 (DS): 0.8425
# Class 35 (DS): 0.9693
# Class 36 (DS): 0.9694
# Class 37 (DS): 0.9792
# Class 38 (DS): 0.9511
# Class 39 (DS): 0.9476
# Class 40 (DS): 0.9303
# Class 41 (DS): 0.9630
# Class 42 (DS): 0.6814
# Class 43 (DS): 0.9146
# Class 44 (DS): 0.9268
# Class 45 (DS): 0.9318
# Class 46 (DS): 0.8947
# Class 47 (DS): 0.9256
# Class 48 (DS): 0.9048
# Class 49 (DS): 0.9089
# Class 50 (DS): 0.8854
# Class 51 (DS): 0.9106
# Class 52 (DS): 0.9123
# Class 53 (DS): 0.9312
# Class 54 (DS): 0.9218
# Class 55 (DS): 0.9018
# Class 56 (DS): 0.8835
# Class 57 (DS): 0.9355
# Class 58 (DS): 0.9442
# Class 59 (DS): 0.9329
# Class 60 (DS): 0.9550
# Class 61 (DS): 0.9219
# Class 62 (DS): 0.9144
# Class 63 (DS): 0.9010
# Class 64 (DS): 0.9511
# Class 65 (DS): 0.9246
# Class 66 (DS): 0.8965
# Class 67 (DS): 0.9138
# Class 68 (DS): 0.8984
# Class 69 (DS): 0.9052
# Class 70 (DS): 0.9094
# Class 71 (DS): 0.8754
# Class 72 (DS): 0.9151
# Class 73 (DS): 0.9306
# Class 74 (DS): 0.9309
# Class 75 (DS): 0.9559
# Class 76 (DS): 0.9350
# Class 77 (DS): 0.6982
# Class 78 (DS): 0.9269
# Class 79 (DS): 0.9164
# Class 80 (DS): 0.9195
# Class 81 (DS): 0.8796
# Class 82 (DS): 0.9310
# Class 83 (DS): 0.9045
# Class 84 (DS): 0.8925
# Class 85 (DS): 0.8948
# Class 86 (DS): 0.9092
# Class 87 (DS): 0.8907
# Class 88 (DS): 0.9378
# Class 89 (DS): 0.9396
# Class 90 (DS): 0.9299
# Class 91 (DS): 0.8920
# Class 92 (DS): 0.9379
# Class 93 (DS): 0.9479
# Class 94 (DS): 0.9242
# Class 95 (DS): 0.9565
# Class 96 (DS): 0.9069
# Class 97 (DS): 0.9058
# Class 98 (DS): 0.9002
# Class 99 (DS): 0.9468
# Class 100 (DS): 0.9167
# Class 101 (DS): 0.9070
# Class 102 (DS): 0.9141
# Class 103 (DS): 0.8975
# Class 104 (DS): 0.9127
# Class 105 (DS): 0.9021
# Class 106 (DS): 0.8766
# Class 107 (DS): 0.9186
# Class 108 (DS): 0.9312
# Class 109 (DS): 0.9233
# Class 110 (DS): 0.9650
# Class 111 (DS): 0.9254
# ----------
# Epoch: 2, Phase: train, epoch loss: 0.1506, Av. Dice Score: 0.9290
# Class 0 (DS): 0.9300
# Class 1 (DS): 0.9636
# Class 2 (DS): 0.9443
# Class 3 (DS): 0.9090
# Class 4 (DS): 0.9302
# Class 5 (DS): 0.9532
# Class 6 (DS): 0.9670
# Class 7 (DS): 0.9631
# Class 8 (DS): 0.9453
# Class 9 (DS): 0.9653
# Class 10 (DS): 0.9300
# Class 11 (DS): 0.9413
# Class 12 (DS): 0.9628
# Class 13 (DS): 0.9720
# Class 14 (DS): 0.9568
# Class 15 (DS): 0.9633
# Class 16 (DS): 0.9531
# Class 17 (DS): 0.9837
# Class 18 (DS): 0.8541
# Class 19 (DS): 0.9295
# Class 20 (DS): 0.9652
# Class 21 (DS): 0.9672
# Class 22 (DS): 0.9107
# Class 23 (DS): 0.9271
# Class 24 (DS): 0.9665
# Class 25 (DS): 0.9583
# Class 26 (DS): 0.9692
# Class 27 (DS): 0.9612
# Class 28 (DS): 0.9569
# Class 29 (DS): 0.9724
# Class 30 (DS): 0.9656
# Class 31 (DS): 0.9624
# Class 32 (DS): 0.9859
# Class 33 (DS): 0.8489
# Class 34 (DS): 0.8387
# Class 35 (DS): 0.9654
# Class 36 (DS): 0.9765
# Class 37 (DS): 0.9750
# Class 38 (DS): 0.9660
# Class 39 (DS): 0.9490
# Class 40 (DS): 0.9560
# Class 41 (DS): 0.9581
# Class 42 (DS): 0.6670
# Class 43 (DS): 0.9308
# Class 44 (DS): 0.9331
# Class 45 (DS): 0.9412
# Class 46 (DS): 0.9019
# Class 47 (DS): 0.9402
# Class 48 (DS): 0.9175
# Class 49 (DS): 0.9150
# Class 50 (DS): 0.8992
# Class 51 (DS): 0.9156
# Class 52 (DS): 0.9193
# Class 53 (DS): 0.9408
# Class 54 (DS): 0.9227
# Class 55 (DS): 0.9122
# Class 56 (DS): 0.8975
# Class 57 (DS): 0.9345
# Class 58 (DS): 0.9437
# Class 59 (DS): 0.9383
# Class 60 (DS): 0.9544
# Class 61 (DS): 0.9283
# Class 62 (DS): 0.9242
# Class 63 (DS): 0.9211
# Class 64 (DS): 0.9474
# Class 65 (DS): 0.9180
# Class 66 (DS): 0.9062
# Class 67 (DS): 0.9207
# Class 68 (DS): 0.9100
# Class 69 (DS): 0.9085
# Class 70 (DS): 0.9114
# Class 71 (DS): 0.8886
# Class 72 (DS): 0.9243
# Class 73 (DS): 0.9365
# Class 74 (DS): 0.9493
# Class 75 (DS): 0.9618
# Class 76 (DS): 0.9336
# Class 77 (DS): 0.6980
# Class 78 (DS): 0.9363
# Class 79 (DS): 0.9211
# Class 80 (DS): 0.9334
# Class 81 (DS): 0.9000
# Class 82 (DS): 0.9452
# Class 83 (DS): 0.9181
# Class 84 (DS): 0.9010
# Class 85 (DS): 0.9009
# Class 86 (DS): 0.9166
# Class 87 (DS): 0.9159
# Class 88 (DS): 0.9387
# Class 89 (DS): 0.9241
# Class 90 (DS): 0.9375
# Class 91 (DS): 0.9002
# Class 92 (DS): 0.9306
# Class 93 (DS): 0.9457
# Class 94 (DS): 0.9303
# Class 95 (DS): 0.9552
# Class 96 (DS): 0.9239
# Class 97 (DS): 0.9154
# Class 98 (DS): 0.9176
# Class 99 (DS): 0.9438
# Class 100 (DS): 0.9191
# Class 101 (DS): 0.9014
# Class 102 (DS): 0.9272
# Class 103 (DS): 0.9069
# Class 104 (DS): 0.9149
# Class 105 (DS): 0.9004
# Class 106 (DS): 0.8980
# Class 107 (DS): 0.9306
# Class 108 (DS): 0.9379
# Class 109 (DS): 0.9463
# Class 110 (DS): 0.9592
# Class 111 (DS): 0.9247
# ----------
# Epoch: 2, Phase: validate, epoch loss: 0.1530, Av. Dice Score: 0.9262
# Class 0 (DS): 0.9399
# Class 1 (DS): 0.9522
# Class 2 (DS): 0.9454
# Class 3 (DS): 0.9048
# Class 4 (DS): 0.9291
# Class 5 (DS): 0.9623
# Class 6 (DS): 0.9582
# Class 7 (DS): 0.9683
# Class 8 (DS): 0.9374
# Class 9 (DS): 0.9710
# Class 10 (DS): 0.9241
# Class 11 (DS): 0.9417
# Class 12 (DS): 0.9594
# Class 13 (DS): 0.9709
# Class 14 (DS): 0.9651
# Class 15 (DS): 0.9606
# Class 16 (DS): 0.9636
# Class 17 (DS): 0.9847
# Class 18 (DS): 0.8682
# Class 19 (DS): 0.9500
# Class 20 (DS): 0.9583
# Class 21 (DS): 0.9737
# Class 22 (DS): 0.9016
# Class 23 (DS): 0.9311
# Class 24 (DS): 0.9686
# Class 25 (DS): 0.9585
# Class 26 (DS): 0.9703
# Class 27 (DS): 0.9648
# Class 28 (DS): 0.9563
# Class 29 (DS): 0.9672
# Class 30 (DS): 0.9607
# Class 31 (DS): 0.9598
# Class 32 (DS): 0.9748
# Class 33 (DS): 0.8686
# Class 34 (DS): 0.8428
# Class 35 (DS): 0.9663
# Class 36 (DS): 0.9726
# Class 37 (DS): 0.9818
# Class 38 (DS): 0.9615
# Class 39 (DS): 0.9554
# Class 40 (DS): 0.9448
# Class 41 (DS): 0.9643
# Class 42 (DS): 0.6851
# Class 43 (DS): 0.9150
# Class 44 (DS): 0.9227
# Class 45 (DS): 0.9288
# Class 46 (DS): 0.9017
# Class 47 (DS): 0.9263
# Class 48 (DS): 0.8955
# Class 49 (DS): 0.9054
# Class 50 (DS): 0.8866
# Class 51 (DS): 0.9097
# Class 52 (DS): 0.9169
# Class 53 (DS): 0.9250
# Class 54 (DS): 0.9229
# Class 55 (DS): 0.8963
# Class 56 (DS): 0.8854
# Class 57 (DS): 0.9361
# Class 58 (DS): 0.9382
# Class 59 (DS): 0.9348
# Class 60 (DS): 0.9611
# Class 61 (DS): 0.9330
# Class 62 (DS): 0.9159
# Class 63 (DS): 0.9075
# Class 64 (DS): 0.9523
# Class 65 (DS): 0.9285
# Class 66 (DS): 0.8982
# Class 67 (DS): 0.9223
# Class 68 (DS): 0.8990
# Class 69 (DS): 0.9118
# Class 70 (DS): 0.9114
# Class 71 (DS): 0.8793
# Class 72 (DS): 0.9160
# Class 73 (DS): 0.9363
# Class 74 (DS): 0.9304
# Class 75 (DS): 0.9583
# Class 76 (DS): 0.9362
# Class 77 (DS): 0.7154
# Class 78 (DS): 0.9248
# Class 79 (DS): 0.9222
# Class 80 (DS): 0.9199
# Class 81 (DS): 0.8893
# Class 82 (DS): 0.9263
# Class 83 (DS): 0.9007
# Class 84 (DS): 0.8988
# Class 85 (DS): 0.8957
# Class 86 (DS): 0.9151
# Class 87 (DS): 0.8999
# Class 88 (DS): 0.9365
# Class 89 (DS): 0.9375
# Class 90 (DS): 0.9196
# Class 91 (DS): 0.8953
# Class 92 (DS): 0.9347
# Class 93 (DS): 0.9402
# Class 94 (DS): 0.9252
# Class 95 (DS): 0.9553
# Class 96 (DS): 0.9171
# Class 97 (DS): 0.9073
# Class 98 (DS): 0.9056
# Class 99 (DS): 0.9509
# Class 100 (DS): 0.9113
# Class 101 (DS): 0.9074
# Class 102 (DS): 0.9270
# Class 103 (DS): 0.9046
# Class 104 (DS): 0.9158
# Class 105 (DS): 0.9044
# Class 106 (DS): 0.8836
# Class 107 (DS): 0.9168
# Class 108 (DS): 0.9292
# Class 109 (DS): 0.9217
# Class 110 (DS): 0.9642
# Class 111 (DS): 0.9277
# ----------
# Epoch: 3, Phase: train, epoch loss: 0.1453, Av. Dice Score: 0.9297
# Class 0 (DS): 0.9253
# Class 1 (DS): 0.9643
# Class 2 (DS): 0.9494
# Class 3 (DS): 0.9090
# Class 4 (DS): 0.9304
# Class 5 (DS): 0.9557
# Class 6 (DS): 0.9664
# Class 7 (DS): 0.9648
# Class 8 (DS): 0.9417
# Class 9 (DS): 0.9660
# Class 10 (DS): 0.9293
# Class 11 (DS): 0.9386
# Class 12 (DS): 0.9602
# Class 13 (DS): 0.9735
# Class 14 (DS): 0.9578
# Class 15 (DS): 0.9637
# Class 16 (DS): 0.9515
# Class 17 (DS): 0.9822
# Class 18 (DS): 0.8588
# Class 19 (DS): 0.9307
# Class 20 (DS): 0.9657
# Class 21 (DS): 0.9696
# Class 22 (DS): 0.9109
# Class 23 (DS): 0.9263
# Class 24 (DS): 0.9673
# Class 25 (DS): 0.9567
# Class 26 (DS): 0.9682
# Class 27 (DS): 0.9569
# Class 28 (DS): 0.9583
# Class 29 (DS): 0.9743
# Class 30 (DS): 0.9649
# Class 31 (DS): 0.9619
# Class 32 (DS): 0.9860
# Class 33 (DS): 0.8488
# Class 34 (DS): 0.8311
# Class 35 (DS): 0.9626
# Class 36 (DS): 0.9788
# Class 37 (DS): 0.9743
# Class 38 (DS): 0.9642
# Class 39 (DS): 0.9534
# Class 40 (DS): 0.9589
# Class 41 (DS): 0.9602
# Class 42 (DS): 0.6615
# Class 43 (DS): 0.9296
# Class 44 (DS): 0.9354
# Class 45 (DS): 0.9420
# Class 46 (DS): 0.9021
# Class 47 (DS): 0.9421
# Class 48 (DS): 0.9197
# Class 49 (DS): 0.9149
# Class 50 (DS): 0.8962
# Class 51 (DS): 0.9162
# Class 52 (DS): 0.9239
# Class 53 (DS): 0.9389
# Class 54 (DS): 0.9244
# Class 55 (DS): 0.9153
# Class 56 (DS): 0.8962
# Class 57 (DS): 0.9350
# Class 58 (DS): 0.9460
# Class 59 (DS): 0.9413
# Class 60 (DS): 0.9511
# Class 61 (DS): 0.9298
# Class 62 (DS): 0.9238
# Class 63 (DS): 0.9190
# Class 64 (DS): 0.9506
# Class 65 (DS): 0.9227
# Class 66 (DS): 0.9013
# Class 67 (DS): 0.9237
# Class 68 (DS): 0.9174
# Class 69 (DS): 0.9093
# Class 70 (DS): 0.9131
# Class 71 (DS): 0.8944
# Class 72 (DS): 0.9269
# Class 73 (DS): 0.9389
# Class 74 (DS): 0.9516
# Class 75 (DS): 0.9616
# Class 76 (DS): 0.9311
# Class 77 (DS): 0.6977
# Class 78 (DS): 0.9324
# Class 79 (DS): 0.9205
# Class 80 (DS): 0.9374
# Class 81 (DS): 0.9027
# Class 82 (DS): 0.9467
# Class 83 (DS): 0.9230
# Class 84 (DS): 0.9023
# Class 85 (DS): 0.9008
# Class 86 (DS): 0.9181
# Class 87 (DS): 0.9196
# Class 88 (DS): 0.9362
# Class 89 (DS): 0.9248
# Class 90 (DS): 0.9358
# Class 91 (DS): 0.9020
# Class 92 (DS): 0.9368
# Class 93 (DS): 0.9477
# Class 94 (DS): 0.9359
# Class 95 (DS): 0.9554
# Class 96 (DS): 0.9253
# Class 97 (DS): 0.9155
# Class 98 (DS): 0.9144
# Class 99 (DS): 0.9472
# Class 100 (DS): 0.9222
# Class 101 (DS): 0.9007
# Class 102 (DS): 0.9293
# Class 103 (DS): 0.9074
# Class 104 (DS): 0.9191
# Class 105 (DS): 0.9046
# Class 106 (DS): 0.9014
# Class 107 (DS): 0.9311
# Class 108 (DS): 0.9368
# Class 109 (DS): 0.9510
# Class 110 (DS): 0.9583
# Class 111 (DS): 0.9262
# ----------
# Epoch: 3, Phase: validate, epoch loss: 0.1519, Av. Dice Score: 0.9257
# Class 0 (DS): 0.9371
# Class 1 (DS): 0.9556
# Class 2 (DS): 0.9450
# Class 3 (DS): 0.9065
# Class 4 (DS): 0.9303
# Class 5 (DS): 0.9558
# Class 6 (DS): 0.9627
# Class 7 (DS): 0.9664
# Class 8 (DS): 0.9374
# Class 9 (DS): 0.9686
# Class 10 (DS): 0.9314
# Class 11 (DS): 0.9369
# Class 12 (DS): 0.9575
# Class 13 (DS): 0.9706
# Class 14 (DS): 0.9679
# Class 15 (DS): 0.9565
# Class 16 (DS): 0.9566
# Class 17 (DS): 0.9793
# Class 18 (DS): 0.8702
# Class 19 (DS): 0.9495
# Class 20 (DS): 0.9580
# Class 21 (DS): 0.9726
# Class 22 (DS): 0.9012
# Class 23 (DS): 0.9293
# Class 24 (DS): 0.9712
# Class 25 (DS): 0.9585
# Class 26 (DS): 0.9662
# Class 27 (DS): 0.9630
# Class 28 (DS): 0.9549
# Class 29 (DS): 0.9662
# Class 30 (DS): 0.9620
# Class 31 (DS): 0.9559
# Class 32 (DS): 0.9739
# Class 33 (DS): 0.8633
# Class 34 (DS): 0.8482
# Class 35 (DS): 0.9750
# Class 36 (DS): 0.9661
# Class 37 (DS): 0.9812
# Class 38 (DS): 0.9555
# Class 39 (DS): 0.9497
# Class 40 (DS): 0.9412
# Class 41 (DS): 0.9611
# Class 42 (DS): 0.6750
# Class 43 (DS): 0.9186
# Class 44 (DS): 0.9292
# Class 45 (DS): 0.9338
# Class 46 (DS): 0.9041
# Class 47 (DS): 0.9192
# Class 48 (DS): 0.8983
# Class 49 (DS): 0.9119
# Class 50 (DS): 0.8875
# Class 51 (DS): 0.9137
# Class 52 (DS): 0.9087
# Class 53 (DS): 0.9349
# Class 54 (DS): 0.9075
# Class 55 (DS): 0.9125
# Class 56 (DS): 0.8781
# Class 57 (DS): 0.9353
# Class 58 (DS): 0.9380
# Class 59 (DS): 0.9410
# Class 60 (DS): 0.9600
# Class 61 (DS): 0.9250
# Class 62 (DS): 0.9149
# Class 63 (DS): 0.9093
# Class 64 (DS): 0.9579
# Class 65 (DS): 0.9241
# Class 66 (DS): 0.9009
# Class 67 (DS): 0.9172
# Class 68 (DS): 0.8959
# Class 69 (DS): 0.9131
# Class 70 (DS): 0.9034
# Class 71 (DS): 0.8894
# Class 72 (DS): 0.9149
# Class 73 (DS): 0.9269
# Class 74 (DS): 0.9310
# Class 75 (DS): 0.9567
# Class 76 (DS): 0.9339
# Class 77 (DS): 0.6955
# Class 78 (DS): 0.9296
# Class 79 (DS): 0.9250
# Class 80 (DS): 0.9269
# Class 81 (DS): 0.8877
# Class 82 (DS): 0.9291
# Class 83 (DS): 0.9068
# Class 84 (DS): 0.8984
# Class 85 (DS): 0.8957
# Class 86 (DS): 0.9178
# Class 87 (DS): 0.8890
# Class 88 (DS): 0.9383
# Class 89 (DS): 0.9289
# Class 90 (DS): 0.9277
# Class 91 (DS): 0.8922
# Class 92 (DS): 0.9336
# Class 93 (DS): 0.9409
# Class 94 (DS): 0.9267
# Class 95 (DS): 0.9549
# Class 96 (DS): 0.9190
# Class 97 (DS): 0.9096
# Class 98 (DS): 0.9019
# Class 99 (DS): 0.9562
# Class 100 (DS): 0.9163
# Class 101 (DS): 0.9112
# Class 102 (DS): 0.9247
# Class 103 (DS): 0.8995
# Class 104 (DS): 0.9177
# Class 105 (DS): 0.8947
# Class 106 (DS): 0.8910
# Class 107 (DS): 0.9146
# Class 108 (DS): 0.9237
# Class 109 (DS): 0.9244
# Class 110 (DS): 0.9661
# Class 111 (DS): 0.9216
# ----------
# Epoch: 4, Phase: train, epoch loss: 0.1413, Av. Dice Score: 0.9304
# Class 0 (DS): 0.9316
# Class 1 (DS): 0.9645
# Class 2 (DS): 0.9472
# Class 3 (DS): 0.9088
# Class 4 (DS): 0.9296
# Class 5 (DS): 0.9555
# Class 6 (DS): 0.9656
# Class 7 (DS): 0.9638
# Class 8 (DS): 0.9451
# Class 9 (DS): 0.9683
# Class 10 (DS): 0.9266
# Class 11 (DS): 0.9455
# Class 12 (DS): 0.9607
# Class 13 (DS): 0.9708
# Class 14 (DS): 0.9583
# Class 15 (DS): 0.9632
# Class 16 (DS): 0.9525
# Class 17 (DS): 0.9841
# Class 18 (DS): 0.8519
# Class 19 (DS): 0.9319
# Class 20 (DS): 0.9617
# Class 21 (DS): 0.9682
# Class 22 (DS): 0.9093
# Class 23 (DS): 0.9295
# Class 24 (DS): 0.9691
# Class 25 (DS): 0.9577
# Class 26 (DS): 0.9696
# Class 27 (DS): 0.9603
# Class 28 (DS): 0.9572
# Class 29 (DS): 0.9707
# Class 30 (DS): 0.9661
# Class 31 (DS): 0.9615
# Class 32 (DS): 0.9847
# Class 33 (DS): 0.8496
# Class 34 (DS): 0.8431
# Class 35 (DS): 0.9638
# Class 36 (DS): 0.9767
# Class 37 (DS): 0.9768
# Class 38 (DS): 0.9674
# Class 39 (DS): 0.9547
# Class 40 (DS): 0.9608
# Class 41 (DS): 0.9617
# Class 42 (DS): 0.6636
# Class 43 (DS): 0.9326
# Class 44 (DS): 0.9346
# Class 45 (DS): 0.9435
# Class 46 (DS): 0.9039
# Class 47 (DS): 0.9400
# Class 48 (DS): 0.9189
# Class 49 (DS): 0.9178
# Class 50 (DS): 0.8969
# Class 51 (DS): 0.9191
# Class 52 (DS): 0.9216
# Class 53 (DS): 0.9383
# Class 54 (DS): 0.9219
# Class 55 (DS): 0.9102
# Class 56 (DS): 0.8989
# Class 57 (DS): 0.9349
# Class 58 (DS): 0.9484
# Class 59 (DS): 0.9396
# Class 60 (DS): 0.9510
# Class 61 (DS): 0.9316
# Class 62 (DS): 0.9258
# Class 63 (DS): 0.9223
# Class 64 (DS): 0.9512
# Class 65 (DS): 0.9222
# Class 66 (DS): 0.9099
# Class 67 (DS): 0.9239
# Class 68 (DS): 0.9146
# Class 69 (DS): 0.9108
# Class 70 (DS): 0.9170
# Class 71 (DS): 0.8878
# Class 72 (DS): 0.9292
# Class 73 (DS): 0.9362
# Class 74 (DS): 0.9463
# Class 75 (DS): 0.9638
# Class 76 (DS): 0.9318
# Class 77 (DS): 0.7007
# Class 78 (DS): 0.9378
# Class 79 (DS): 0.9264
# Class 80 (DS): 0.9378
# Class 81 (DS): 0.9039
# Class 82 (DS): 0.9443
# Class 83 (DS): 0.9220
# Class 84 (DS): 0.9031
# Class 85 (DS): 0.9015
# Class 86 (DS): 0.9218
# Class 87 (DS): 0.9200
# Class 88 (DS): 0.9408
# Class 89 (DS): 0.9259
# Class 90 (DS): 0.9387
# Class 91 (DS): 0.8991
# Class 92 (DS): 0.9339
# Class 93 (DS): 0.9481
# Class 94 (DS): 0.9363
# Class 95 (DS): 0.9571
# Class 96 (DS): 0.9267
# Class 97 (DS): 0.9194
# Class 98 (DS): 0.9206
# Class 99 (DS): 0.9462
# Class 100 (DS): 0.9226
# Class 101 (DS): 0.9051
# Class 102 (DS): 0.9280
# Class 103 (DS): 0.9039
# Class 104 (DS): 0.9154
# Class 105 (DS): 0.9068
# Class 106 (DS): 0.8993
# Class 107 (DS): 0.9336
# Class 108 (DS): 0.9371
# Class 109 (DS): 0.9456
# Class 110 (DS): 0.9626
# Class 111 (DS): 0.9261
# ----------
# Epoch: 4, Phase: validate, epoch loss: 0.1460, Av. Dice Score: 0.9286
# Class 0 (DS): 0.9421
# Class 1 (DS): 0.9542
# Class 2 (DS): 0.9435
# Class 3 (DS): 0.8921
# Class 4 (DS): 0.9354
# Class 5 (DS): 0.9640
# Class 6 (DS): 0.9631
# Class 7 (DS): 0.9682
# Class 8 (DS): 0.9398
# Class 9 (DS): 0.9695
# Class 10 (DS): 0.9233
# Class 11 (DS): 0.9394
# Class 12 (DS): 0.9522
# Class 13 (DS): 0.9715
# Class 14 (DS): 0.9682
# Class 15 (DS): 0.9584
# Class 16 (DS): 0.9639
# Class 17 (DS): 0.9795
# Class 18 (DS): 0.8651
# Class 19 (DS): 0.9471
# Class 20 (DS): 0.9611
# Class 21 (DS): 0.9704
# Class 22 (DS): 0.8981
# Class 23 (DS): 0.9321
# Class 24 (DS): 0.9700
# Class 25 (DS): 0.9598
# Class 26 (DS): 0.9630
# Class 27 (DS): 0.9666
# Class 28 (DS): 0.9581
# Class 29 (DS): 0.9693
# Class 30 (DS): 0.9513
# Class 31 (DS): 0.9578
# Class 32 (DS): 0.9775
# Class 33 (DS): 0.8696
# Class 34 (DS): 0.8560
# Class 35 (DS): 0.9732
# Class 36 (DS): 0.9760
# Class 37 (DS): 0.9834
# Class 38 (DS): 0.9636
# Class 39 (DS): 0.9563
# Class 40 (DS): 0.9457
# Class 41 (DS): 0.9642
# Class 42 (DS): 0.6817
# Class 43 (DS): 0.9226
# Class 44 (DS): 0.9385
# Class 45 (DS): 0.9372
# Class 46 (DS): 0.9057
# Class 47 (DS): 0.9338
# Class 48 (DS): 0.9048
# Class 49 (DS): 0.9158
# Class 50 (DS): 0.8916
# Class 51 (DS): 0.9183
# Class 52 (DS): 0.9093
# Class 53 (DS): 0.9384
# Class 54 (DS): 0.9168
# Class 55 (DS): 0.9116
# Class 56 (DS): 0.8842
# Class 57 (DS): 0.9308
# Class 58 (DS): 0.9403
# Class 59 (DS): 0.9415
# Class 60 (DS): 0.9543
# Class 61 (DS): 0.9371
# Class 62 (DS): 0.9170
# Class 63 (DS): 0.9112
# Class 64 (DS): 0.9596
# Class 65 (DS): 0.9321
# Class 66 (DS): 0.9005
# Class 67 (DS): 0.9255
# Class 68 (DS): 0.8996
# Class 69 (DS): 0.9147
# Class 70 (DS): 0.9166
# Class 71 (DS): 0.8939
# Class 72 (DS): 0.9253
# Class 73 (DS): 0.9257
# Class 74 (DS): 0.9421
# Class 75 (DS): 0.9616
# Class 76 (DS): 0.9389
# Class 77 (DS): 0.7067
# Class 78 (DS): 0.9352
# Class 79 (DS): 0.9368
# Class 80 (DS): 0.9237
# Class 81 (DS): 0.8970
# Class 82 (DS): 0.9318
# Class 83 (DS): 0.9108
# Class 84 (DS): 0.8982
# Class 85 (DS): 0.8983
# Class 86 (DS): 0.9203
# Class 87 (DS): 0.8991
# Class 88 (DS): 0.9410
# Class 89 (DS): 0.9288
# Class 90 (DS): 0.9249
# Class 91 (DS): 0.9021
# Class 92 (DS): 0.9353
# Class 93 (DS): 0.9440
# Class 94 (DS): 0.9286
# Class 95 (DS): 0.9531
# Class 96 (DS): 0.9217
# Class 97 (DS): 0.9111
# Class 98 (DS): 0.9112
# Class 99 (DS): 0.9584
# Class 100 (DS): 0.9178
# Class 101 (DS): 0.9142
# Class 102 (DS): 0.9296
# Class 103 (DS): 0.9032
# Class 104 (DS): 0.9188
# Class 105 (DS): 0.9122
# Class 106 (DS): 0.8872
# Class 107 (DS): 0.9210
# Class 108 (DS): 0.9246
# Class 109 (DS): 0.9249
# Class 110 (DS): 0.9662
# Class 111 (DS): 0.9275
# ----------
# Epoch: 5, Phase: train, epoch loss: 0.1387, Av. Dice Score: 0.9308
# Class 0 (DS): 0.9356
# Class 1 (DS): 0.9622
# Class 2 (DS): 0.9519
# Class 3 (DS): 0.9095
# Class 4 (DS): 0.9325
# Class 5 (DS): 0.9534
# Class 6 (DS): 0.9667
# Class 7 (DS): 0.9633
# Class 8 (DS): 0.9439
# Class 9 (DS): 0.9684
# Class 10 (DS): 0.9300
# Class 11 (DS): 0.9434
# Class 12 (DS): 0.9587
# Class 13 (DS): 0.9730
# Class 14 (DS): 0.9602
# Class 15 (DS): 0.9649
# Class 16 (DS): 0.9545
# Class 17 (DS): 0.9833
# Class 18 (DS): 0.8560
# Class 19 (DS): 0.9396
# Class 20 (DS): 0.9650
# Class 21 (DS): 0.9723
# Class 22 (DS): 0.9119
# Class 23 (DS): 0.9303
# Class 24 (DS): 0.9688
# Class 25 (DS): 0.9604
# Class 26 (DS): 0.9691
# Class 27 (DS): 0.9626
# Class 28 (DS): 0.9566
# Class 29 (DS): 0.9726
# Class 30 (DS): 0.9669
# Class 31 (DS): 0.9624
# Class 32 (DS): 0.9873
# Class 33 (DS): 0.8529
# Class 34 (DS): 0.8365
# Class 35 (DS): 0.9636
# Class 36 (DS): 0.9789
# Class 37 (DS): 0.9754
# Class 38 (DS): 0.9628
# Class 39 (DS): 0.9528
# Class 40 (DS): 0.9563
# Class 41 (DS): 0.9622
# Class 42 (DS): 0.6550
# Class 43 (DS): 0.9316
# Class 44 (DS): 0.9359
# Class 45 (DS): 0.9414
# Class 46 (DS): 0.9042
# Class 47 (DS): 0.9420
# Class 48 (DS): 0.9181
# Class 49 (DS): 0.9200
# Class 50 (DS): 0.8997
# Class 51 (DS): 0.9174
# Class 52 (DS): 0.9206
# Class 53 (DS): 0.9447
# Class 54 (DS): 0.9222
# Class 55 (DS): 0.9188
# Class 56 (DS): 0.8989
# Class 57 (DS): 0.9369
# Class 58 (DS): 0.9480
# Class 59 (DS): 0.9411
# Class 60 (DS): 0.9537
# Class 61 (DS): 0.9319
# Class 62 (DS): 0.9250
# Class 63 (DS): 0.9197
# Class 64 (DS): 0.9485
# Class 65 (DS): 0.9245
# Class 66 (DS): 0.9046
# Class 67 (DS): 0.9225
# Class 68 (DS): 0.9128
# Class 69 (DS): 0.9125
# Class 70 (DS): 0.9176
# Class 71 (DS): 0.8899
# Class 72 (DS): 0.9312
# Class 73 (DS): 0.9392
# Class 74 (DS): 0.9479
# Class 75 (DS): 0.9625
# Class 76 (DS): 0.9347
# Class 77 (DS): 0.6910
# Class 78 (DS): 0.9366
# Class 79 (DS): 0.9246
# Class 80 (DS): 0.9382
# Class 81 (DS): 0.9028
# Class 82 (DS): 0.9442
# Class 83 (DS): 0.9211
# Class 84 (DS): 0.9079
# Class 85 (DS): 0.9015
# Class 86 (DS): 0.9202
# Class 87 (DS): 0.9207
# Class 88 (DS): 0.9368
# Class 89 (DS): 0.9261
# Class 90 (DS): 0.9378
# Class 91 (DS): 0.9015
# Class 92 (DS): 0.9375
# Class 93 (DS): 0.9490
# Class 94 (DS): 0.9362
# Class 95 (DS): 0.9578
# Class 96 (DS): 0.9253
# Class 97 (DS): 0.9227
# Class 98 (DS): 0.9190
# Class 99 (DS): 0.9461
# Class 100 (DS): 0.9259
# Class 101 (DS): 0.9011
# Class 102 (DS): 0.9251
# Class 103 (DS): 0.9093
# Class 104 (DS): 0.9203
# Class 105 (DS): 0.9024
# Class 106 (DS): 0.9002
# Class 107 (DS): 0.9341
# Class 108 (DS): 0.9366
# Class 109 (DS): 0.9482
# Class 110 (DS): 0.9597
# Class 111 (DS): 0.9259
# ----------
# Epoch: 5, Phase: validate, epoch loss: 0.1489, Av. Dice Score: 0.9273
# Class 0 (DS): 0.9469
# Class 1 (DS): 0.9532
# Class 2 (DS): 0.9476
# Class 3 (DS): 0.9008
# Class 4 (DS): 0.9389
# Class 5 (DS): 0.9643
# Class 6 (DS): 0.9576
# Class 7 (DS): 0.9723
# Class 8 (DS): 0.9425
# Class 9 (DS): 0.9734
# Class 10 (DS): 0.9254
# Class 11 (DS): 0.9415
# Class 12 (DS): 0.9577
# Class 13 (DS): 0.9718
# Class 14 (DS): 0.9724
# Class 15 (DS): 0.9633
# Class 16 (DS): 0.9621
# Class 17 (DS): 0.9801
# Class 18 (DS): 0.8812
# Class 19 (DS): 0.9496
# Class 20 (DS): 0.9566
# Class 21 (DS): 0.9730
# Class 22 (DS): 0.9047
# Class 23 (DS): 0.9293
# Class 24 (DS): 0.9686
# Class 25 (DS): 0.9541
# Class 26 (DS): 0.9687
# Class 27 (DS): 0.9662
# Class 28 (DS): 0.9610
# Class 29 (DS): 0.9690
# Class 30 (DS): 0.9640
# Class 31 (DS): 0.9619
# Class 32 (DS): 0.9745
# Class 33 (DS): 0.8691
# Class 34 (DS): 0.8437
# Class 35 (DS): 0.9664
# Class 36 (DS): 0.9767
# Class 37 (DS): 0.9799
# Class 38 (DS): 0.9573
# Class 39 (DS): 0.9535
# Class 40 (DS): 0.9469
# Class 41 (DS): 0.9653
# Class 42 (DS): 0.6829
# Class 43 (DS): 0.9251
# Class 44 (DS): 0.9305
# Class 45 (DS): 0.9240
# Class 46 (DS): 0.9002
# Class 47 (DS): 0.9250
# Class 48 (DS): 0.9035
# Class 49 (DS): 0.9156
# Class 50 (DS): 0.8902
# Class 51 (DS): 0.9129
# Class 52 (DS): 0.9087
# Class 53 (DS): 0.9301
# Class 54 (DS): 0.9205
# Class 55 (DS): 0.9169
# Class 56 (DS): 0.8820
# Class 57 (DS): 0.9362
# Class 58 (DS): 0.9378
# Class 59 (DS): 0.9291
# Class 60 (DS): 0.9593
# Class 61 (DS): 0.9325
# Class 62 (DS): 0.9163
# Class 63 (DS): 0.9071
# Class 64 (DS): 0.9549
# Class 65 (DS): 0.9237
# Class 66 (DS): 0.8906
# Class 67 (DS): 0.9286
# Class 68 (DS): 0.9037
# Class 69 (DS): 0.9103
# Class 70 (DS): 0.9036
# Class 71 (DS): 0.8766
# Class 72 (DS): 0.9218
# Class 73 (DS): 0.9376
# Class 74 (DS): 0.9259
# Class 75 (DS): 0.9625
# Class 76 (DS): 0.9378
# Class 77 (DS): 0.7061
# Class 78 (DS): 0.9353
# Class 79 (DS): 0.9302
# Class 80 (DS): 0.9185
# Class 81 (DS): 0.8892
# Class 82 (DS): 0.9255
# Class 83 (DS): 0.9070
# Class 84 (DS): 0.8976
# Class 85 (DS): 0.8984
# Class 86 (DS): 0.9124
# Class 87 (DS): 0.8928
# Class 88 (DS): 0.9442
# Class 89 (DS): 0.9371
# Class 90 (DS): 0.9332
# Class 91 (DS): 0.8939
# Class 92 (DS): 0.9390
# Class 93 (DS): 0.9398
# Class 94 (DS): 0.9238
# Class 95 (DS): 0.9577
# Class 96 (DS): 0.9183
# Class 97 (DS): 0.9090
# Class 98 (DS): 0.9064
# Class 99 (DS): 0.9548
# Class 100 (DS): 0.9187
# Class 101 (DS): 0.9046
# Class 102 (DS): 0.9289
# Class 103 (DS): 0.9019
# Class 104 (DS): 0.9153
# Class 105 (DS): 0.9029
# Class 106 (DS): 0.8730
# Class 107 (DS): 0.9170
# Class 108 (DS): 0.9367
# Class 109 (DS): 0.9179
# Class 110 (DS): 0.9667
# Class 111 (DS): 0.9289
# ----------
# Epoch: 6, Phase: train, epoch loss: 0.1353, Av. Dice Score: 0.9317
# Class 0 (DS): 0.9302
# Class 1 (DS): 0.9661
# Class 2 (DS): 0.9530
# Class 3 (DS): 0.9069
# Class 4 (DS): 0.9332
# Class 5 (DS): 0.9543
# Class 6 (DS): 0.9662
# Class 7 (DS): 0.9633
# Class 8 (DS): 0.9444
# Class 9 (DS): 0.9679
# Class 10 (DS): 0.9281
# Class 11 (DS): 0.9428
# Class 12 (DS): 0.9605
# Class 13 (DS): 0.9730
# Class 14 (DS): 0.9596
# Class 15 (DS): 0.9643
# Class 16 (DS): 0.9543
# Class 17 (DS): 0.9832
# Class 18 (DS): 0.8627
# Class 19 (DS): 0.9319
# Class 20 (DS): 0.9638
# Class 21 (DS): 0.9696
# Class 22 (DS): 0.9142
# Class 23 (DS): 0.9310
# Class 24 (DS): 0.9668
# Class 25 (DS): 0.9586
# Class 26 (DS): 0.9691
# Class 27 (DS): 0.9620
# Class 28 (DS): 0.9595
# Class 29 (DS): 0.9710
# Class 30 (DS): 0.9664
# Class 31 (DS): 0.9636
# Class 32 (DS): 0.9858
# Class 33 (DS): 0.8546
# Class 34 (DS): 0.8440
# Class 35 (DS): 0.9616
# Class 36 (DS): 0.9806
# Class 37 (DS): 0.9769
# Class 38 (DS): 0.9675
# Class 39 (DS): 0.9539
# Class 40 (DS): 0.9586
# Class 41 (DS): 0.9646
# Class 42 (DS): 0.6631
# Class 43 (DS): 0.9311
# Class 44 (DS): 0.9372
# Class 45 (DS): 0.9426
# Class 46 (DS): 0.9047
# Class 47 (DS): 0.9446
# Class 48 (DS): 0.9208
# Class 49 (DS): 0.9171
# Class 50 (DS): 0.9004
# Class 51 (DS): 0.9196
# Class 52 (DS): 0.9252
# Class 53 (DS): 0.9448
# Class 54 (DS): 0.9253
# Class 55 (DS): 0.9246
# Class 56 (DS): 0.8994
# Class 57 (DS): 0.9376
# Class 58 (DS): 0.9459
# Class 59 (DS): 0.9398
# Class 60 (DS): 0.9547
# Class 61 (DS): 0.9312
# Class 62 (DS): 0.9243
# Class 63 (DS): 0.9214
# Class 64 (DS): 0.9507
# Class 65 (DS): 0.9256
# Class 66 (DS): 0.9079
# Class 67 (DS): 0.9256
# Class 68 (DS): 0.9157
# Class 69 (DS): 0.9145
# Class 70 (DS): 0.9154
# Class 71 (DS): 0.8927
# Class 72 (DS): 0.9282
# Class 73 (DS): 0.9401
# Class 74 (DS): 0.9517
# Class 75 (DS): 0.9604
# Class 76 (DS): 0.9381
# Class 77 (DS): 0.7036
# Class 78 (DS): 0.9364
# Class 79 (DS): 0.9221
# Class 80 (DS): 0.9388
# Class 81 (DS): 0.9043
# Class 82 (DS): 0.9484
# Class 83 (DS): 0.9241
# Class 84 (DS): 0.9051
# Class 85 (DS): 0.9047
# Class 86 (DS): 0.9183
# Class 87 (DS): 0.9205
# Class 88 (DS): 0.9425
# Class 89 (DS): 0.9234
# Class 90 (DS): 0.9387
# Class 91 (DS): 0.8990
# Class 92 (DS): 0.9386
# Class 93 (DS): 0.9470
# Class 94 (DS): 0.9391
# Class 95 (DS): 0.9589
# Class 96 (DS): 0.9270
# Class 97 (DS): 0.9170
# Class 98 (DS): 0.9198
# Class 99 (DS): 0.9508
# Class 100 (DS): 0.9243
# Class 101 (DS): 0.9035
# Class 102 (DS): 0.9291
# Class 103 (DS): 0.9110
# Class 104 (DS): 0.9187
# Class 105 (DS): 0.9044
# Class 106 (DS): 0.9058
# Class 107 (DS): 0.9334
# Class 108 (DS): 0.9383
# Class 109 (DS): 0.9501
# Class 110 (DS): 0.9593
# Class 111 (DS): 0.9280
# ----------
# Epoch: 6, Phase: validate, epoch loss: 0.1437, Av. Dice Score: 0.9274
# Class 0 (DS): 0.9434
# Class 1 (DS): 0.9596
# Class 2 (DS): 0.9496
# Class 3 (DS): 0.8985
# Class 4 (DS): 0.9306
# Class 5 (DS): 0.9641
# Class 6 (DS): 0.9636
# Class 7 (DS): 0.9654
# Class 8 (DS): 0.9374
# Class 9 (DS): 0.9719
# Class 10 (DS): 0.9268
# Class 11 (DS): 0.9377
# Class 12 (DS): 0.9562
# Class 13 (DS): 0.9701
# Class 14 (DS): 0.9691
# Class 15 (DS): 0.9586
# Class 16 (DS): 0.9636
# Class 17 (DS): 0.9801
# Class 18 (DS): 0.8690
# Class 19 (DS): 0.9474
# Class 20 (DS): 0.9581
# Class 21 (DS): 0.9715
# Class 22 (DS): 0.8950
# Class 23 (DS): 0.9279
# Class 24 (DS): 0.9597
# Class 25 (DS): 0.9580
# Class 26 (DS): 0.9672
# Class 27 (DS): 0.9647
# Class 28 (DS): 0.9604
# Class 29 (DS): 0.9702
# Class 30 (DS): 0.9630
# Class 31 (DS): 0.9583
# Class 32 (DS): 0.9743
# Class 33 (DS): 0.8671
# Class 34 (DS): 0.8441
# Class 35 (DS): 0.9681
# Class 36 (DS): 0.9707
# Class 37 (DS): 0.9793
# Class 38 (DS): 0.9586
# Class 39 (DS): 0.9537
# Class 40 (DS): 0.9430
# Class 41 (DS): 0.9597
# Class 42 (DS): 0.6834
# Class 43 (DS): 0.9207
# Class 44 (DS): 0.9341
# Class 45 (DS): 0.9411
# Class 46 (DS): 0.9030
# Class 47 (DS): 0.9281
# Class 48 (DS): 0.9024
# Class 49 (DS): 0.9117
# Class 50 (DS): 0.8884
# Class 51 (DS): 0.9141
# Class 52 (DS): 0.9065
# Class 53 (DS): 0.9449
# Class 54 (DS): 0.9204
# Class 55 (DS): 0.9122
# Class 56 (DS): 0.8829
# Class 57 (DS): 0.9286
# Class 58 (DS): 0.9442
# Class 59 (DS): 0.9404
# Class 60 (DS): 0.9593
# Class 61 (DS): 0.9301
# Class 62 (DS): 0.9174
# Class 63 (DS): 0.9115
# Class 64 (DS): 0.9576
# Class 65 (DS): 0.9298
# Class 66 (DS): 0.9043
# Class 67 (DS): 0.9279
# Class 68 (DS): 0.9050
# Class 69 (DS): 0.9165
# Class 70 (DS): 0.9117
# Class 71 (DS): 0.8876
# Class 72 (DS): 0.9197
# Class 73 (DS): 0.9291
# Class 74 (DS): 0.9350
# Class 75 (DS): 0.9605
# Class 76 (DS): 0.9366
# Class 77 (DS): 0.7066
# Class 78 (DS): 0.9287
# Class 79 (DS): 0.9317
# Class 80 (DS): 0.9309
# Class 81 (DS): 0.8848
# Class 82 (DS): 0.9276
# Class 83 (DS): 0.8952
# Class 84 (DS): 0.8969
# Class 85 (DS): 0.8946
# Class 86 (DS): 0.9184
# Class 87 (DS): 0.8952
# Class 88 (DS): 0.9377
# Class 89 (DS): 0.9358
# Class 90 (DS): 0.9241
# Class 91 (DS): 0.8958
# Class 92 (DS): 0.9349
# Class 93 (DS): 0.9434
# Class 94 (DS): 0.9316
# Class 95 (DS): 0.9544
# Class 96 (DS): 0.9183
# Class 97 (DS): 0.9115
# Class 98 (DS): 0.9088
# Class 99 (DS): 0.9576
# Class 100 (DS): 0.9163
# Class 101 (DS): 0.9135
# Class 102 (DS): 0.9241
# Class 103 (DS): 0.9062
# Class 104 (DS): 0.9135
# Class 105 (DS): 0.9102
# Class 106 (DS): 0.8818
# Class 107 (DS): 0.9170
# Class 108 (DS): 0.9259
# Class 109 (DS): 0.9230
# Class 110 (DS): 0.9640
# Class 111 (DS): 0.9298
# ----------
# Epoch: 7, Phase: train, epoch loss: 0.1354, Av. Dice Score: 0.9306
# Class 0 (DS): 0.9227
# Class 1 (DS): 0.9634
# Class 2 (DS): 0.9481
# Class 3 (DS): 0.9094
# Class 4 (DS): 0.9338
# Class 5 (DS): 0.9532
# Class 6 (DS): 0.9652
# Class 7 (DS): 0.9616
# Class 8 (DS): 0.9446
# Class 9 (DS): 0.9675
# Class 10 (DS): 0.9290
# Class 11 (DS): 0.9422
# Class 12 (DS): 0.9607
# Class 13 (DS): 0.9697
# Class 14 (DS): 0.9588
# Class 15 (DS): 0.9620
# Class 16 (DS): 0.9582
# Class 17 (DS): 0.9842
# Class 18 (DS): 0.8542
# Class 19 (DS): 0.9354
# Class 20 (DS): 0.9627
# Class 21 (DS): 0.9682
# Class 22 (DS): 0.9108
# Class 23 (DS): 0.9294
# Class 24 (DS): 0.9669
# Class 25 (DS): 0.9586
# Class 26 (DS): 0.9669
# Class 27 (DS): 0.9600
# Class 28 (DS): 0.9575
# Class 29 (DS): 0.9718
# Class 30 (DS): 0.9649
# Class 31 (DS): 0.9620
# Class 32 (DS): 0.9868
# Class 33 (DS): 0.8498
# Class 34 (DS): 0.8398
# Class 35 (DS): 0.9613
# Class 36 (DS): 0.9763
# Class 37 (DS): 0.9745
# Class 38 (DS): 0.9669
# Class 39 (DS): 0.9549
# Class 40 (DS): 0.9576
# Class 41 (DS): 0.9636
# Class 42 (DS): 0.6580
# Class 43 (DS): 0.9330
# Class 44 (DS): 0.9351
# Class 45 (DS): 0.9433
# Class 46 (DS): 0.9050
# Class 47 (DS): 0.9430
# Class 48 (DS): 0.9182
# Class 49 (DS): 0.9161
# Class 50 (DS): 0.8996
# Class 51 (DS): 0.9203
# Class 52 (DS): 0.9245
# Class 53 (DS): 0.9414
# Class 54 (DS): 0.9199
# Class 55 (DS): 0.9179
# Class 56 (DS): 0.8989
# Class 57 (DS): 0.9354
# Class 58 (DS): 0.9497
# Class 59 (DS): 0.9402
# Class 60 (DS): 0.9538
# Class 61 (DS): 0.9358
# Class 62 (DS): 0.9267
# Class 63 (DS): 0.9202
# Class 64 (DS): 0.9496
# Class 65 (DS): 0.9228
# Class 66 (DS): 0.9095
# Class 67 (DS): 0.9214
# Class 68 (DS): 0.9159
# Class 69 (DS): 0.9131
# Class 70 (DS): 0.9151
# Class 71 (DS): 0.8920
# Class 72 (DS): 0.9294
# Class 73 (DS): 0.9374
# Class 74 (DS): 0.9507
# Class 75 (DS): 0.9621
# Class 76 (DS): 0.9344
# Class 77 (DS): 0.6923
# Class 78 (DS): 0.9347
# Class 79 (DS): 0.9209
# Class 80 (DS): 0.9390
# Class 81 (DS): 0.9045
# Class 82 (DS): 0.9462
# Class 83 (DS): 0.9210
# Class 84 (DS): 0.9061
# Class 85 (DS): 0.9002
# Class 86 (DS): 0.9187
# Class 87 (DS): 0.9174
# Class 88 (DS): 0.9402
# Class 89 (DS): 0.9211
# Class 90 (DS): 0.9391
# Class 91 (DS): 0.8988
# Class 92 (DS): 0.9379
# Class 93 (DS): 0.9495
# Class 94 (DS): 0.9395
# Class 95 (DS): 0.9570
# Class 96 (DS): 0.9259
# Class 97 (DS): 0.9184
# Class 98 (DS): 0.9188
# Class 99 (DS): 0.9484
# Class 100 (DS): 0.9269
# Class 101 (DS): 0.9060
# Class 102 (DS): 0.9261
# Class 103 (DS): 0.9099
# Class 104 (DS): 0.9210
# Class 105 (DS): 0.9057
# Class 106 (DS): 0.9032
# Class 107 (DS): 0.9352
# Class 108 (DS): 0.9362
# Class 109 (DS): 0.9479
# Class 110 (DS): 0.9580
# Class 111 (DS): 0.9263
# ----------
# Epoch: 8, Phase: train, epoch loss: 0.1334, Av. Dice Score: 0.9301
# Class 0 (DS): 0.9237
# Class 1 (DS): 0.9616
# Class 2 (DS): 0.9453
# Class 3 (DS): 0.9087
# Class 4 (DS): 0.9310
# Class 5 (DS): 0.9540
# Class 6 (DS): 0.9666
# Class 7 (DS): 0.9620
# Class 8 (DS): 0.9435
# Class 9 (DS): 0.9673
# Class 10 (DS): 0.9301
# Class 11 (DS): 0.9432
# Class 12 (DS): 0.9591
# Class 13 (DS): 0.9700
# Class 14 (DS): 0.9595
# Class 15 (DS): 0.9620
# Class 16 (DS): 0.9516
# Class 17 (DS): 0.9830
# Class 18 (DS): 0.8487
# Class 19 (DS): 0.9363
# Class 20 (DS): 0.9618
# Class 21 (DS): 0.9681
# Class 22 (DS): 0.9072
# Class 23 (DS): 0.9274
# Class 24 (DS): 0.9652
# Class 25 (DS): 0.9566
# Class 26 (DS): 0.9679
# Class 27 (DS): 0.9581
# Class 28 (DS): 0.9570
# Class 29 (DS): 0.9727
# Class 30 (DS): 0.9651
# Class 31 (DS): 0.9609
# Class 32 (DS): 0.9842
# Class 33 (DS): 0.8472
# Class 34 (DS): 0.8401
# Class 35 (DS): 0.9611
# Class 36 (DS): 0.9775
# Class 37 (DS): 0.9762
# Class 38 (DS): 0.9666
# Class 39 (DS): 0.9569
# Class 40 (DS): 0.9609
# Class 41 (DS): 0.9606
# Class 42 (DS): 0.6484
# Class 43 (DS): 0.9293
# Class 44 (DS): 0.9392
# Class 45 (DS): 0.9453
# Class 46 (DS): 0.9053
# Class 47 (DS): 0.9407
# Class 48 (DS): 0.9166
# Class 49 (DS): 0.9178
# Class 50 (DS): 0.8997
# Class 51 (DS): 0.9161
# Class 52 (DS): 0.9227
# Class 53 (DS): 0.9420
# Class 54 (DS): 0.9218
# Class 55 (DS): 0.9177
# Class 56 (DS): 0.9004
# Class 57 (DS): 0.9323
# Class 58 (DS): 0.9514
# Class 59 (DS): 0.9375
# Class 60 (DS): 0.9474
# Class 61 (DS): 0.9321
# Class 62 (DS): 0.9224
# Class 63 (DS): 0.9262
# Class 64 (DS): 0.9503
# Class 65 (DS): 0.9239
# Class 66 (DS): 0.9107
# Class 67 (DS): 0.9234
# Class 68 (DS): 0.9142
# Class 69 (DS): 0.9122
# Class 70 (DS): 0.9203
# Class 71 (DS): 0.8899
# Class 72 (DS): 0.9305
# Class 73 (DS): 0.9375
# Class 74 (DS): 0.9507
# Class 75 (DS): 0.9588
# Class 76 (DS): 0.9347
# Class 77 (DS): 0.6840
# Class 78 (DS): 0.9350
# Class 79 (DS): 0.9246
# Class 80 (DS): 0.9394
# Class 81 (DS): 0.9053
# Class 82 (DS): 0.9460
# Class 83 (DS): 0.9213
# Class 84 (DS): 0.9088
# Class 85 (DS): 0.9016
# Class 86 (DS): 0.9178
# Class 87 (DS): 0.9185
# Class 88 (DS): 0.9397
# Class 89 (DS): 0.9240
# Class 90 (DS): 0.9355
# Class 91 (DS): 0.9010
# Class 92 (DS): 0.9343
# Class 93 (DS): 0.9520
# Class 94 (DS): 0.9345
# Class 95 (DS): 0.9534
# Class 96 (DS): 0.9228
# Class 97 (DS): 0.9141
# Class 98 (DS): 0.9217
# Class 99 (DS): 0.9489
# Class 100 (DS): 0.9271
# Class 101 (DS): 0.9089
# Class 102 (DS): 0.9272
# Class 103 (DS): 0.9110
# Class 104 (DS): 0.9204
# Class 105 (DS): 0.9094
# Class 106 (DS): 0.9021
# Class 107 (DS): 0.9309
# Class 108 (DS): 0.9366
# Class 109 (DS): 0.9480
# Class 110 (DS): 0.9607
# Class 111 (DS): 0.9252
# ----------
# Epoch: 8, Phase: validate, epoch loss: 0.1436, Av. Dice Score: 0.9262
# Class 0 (DS): 0.9432
# Class 1 (DS): 0.9560
# Class 2 (DS): 0.9445
# Class 3 (DS): 0.9064
# Class 4 (DS): 0.9269
# Class 5 (DS): 0.9562
# Class 6 (DS): 0.9554
# Class 7 (DS): 0.9678
# Class 8 (DS): 0.9327
# Class 9 (DS): 0.9720
# Class 10 (DS): 0.9268
# Class 11 (DS): 0.9392
# Class 12 (DS): 0.9577
# Class 13 (DS): 0.9729
# Class 14 (DS): 0.9696
# Class 15 (DS): 0.9583
# Class 16 (DS): 0.9614
# Class 17 (DS): 0.9815
# Class 18 (DS): 0.8644
# Class 19 (DS): 0.9505
# Class 20 (DS): 0.9557
# Class 21 (DS): 0.9700
# Class 22 (DS): 0.8999
# Class 23 (DS): 0.9205
# Class 24 (DS): 0.9647
# Class 25 (DS): 0.9480
# Class 26 (DS): 0.9654
# Class 27 (DS): 0.9605
# Class 28 (DS): 0.9563
# Class 29 (DS): 0.9704
# Class 30 (DS): 0.9626
# Class 31 (DS): 0.9590
# Class 32 (DS): 0.9758
# Class 33 (DS): 0.8645
# Class 34 (DS): 0.8503
# Class 35 (DS): 0.9683
# Class 36 (DS): 0.9681
# Class 37 (DS): 0.9802
# Class 38 (DS): 0.9559
# Class 39 (DS): 0.9490
# Class 40 (DS): 0.9391
# Class 41 (DS): 0.9650
# Class 42 (DS): 0.6676
# Class 43 (DS): 0.9208
# Class 44 (DS): 0.9258
# Class 45 (DS): 0.9326
# Class 46 (DS): 0.9008
# Class 47 (DS): 0.9344
# Class 48 (DS): 0.9008
# Class 49 (DS): 0.9113
# Class 50 (DS): 0.8899
# Class 51 (DS): 0.9100
# Class 52 (DS): 0.9065
# Class 53 (DS): 0.9403
# Class 54 (DS): 0.9213
# Class 55 (DS): 0.9010
# Class 56 (DS): 0.8816
# Class 57 (DS): 0.9396
# Class 58 (DS): 0.9368
# Class 59 (DS): 0.9269
# Class 60 (DS): 0.9571
# Class 61 (DS): 0.9304
# Class 62 (DS): 0.9093
# Class 63 (DS): 0.9062
# Class 64 (DS): 0.9550
# Class 65 (DS): 0.9228
# Class 66 (DS): 0.9004
# Class 67 (DS): 0.9240
# Class 68 (DS): 0.8999
# Class 69 (DS): 0.9158
# Class 70 (DS): 0.9098
# Class 71 (DS): 0.8866
# Class 72 (DS): 0.9229
# Class 73 (DS): 0.9305
# Class 74 (DS): 0.9407
# Class 75 (DS): 0.9628
# Class 76 (DS): 0.9371
# Class 77 (DS): 0.7015
# Class 78 (DS): 0.9274
# Class 79 (DS): 0.9287
# Class 80 (DS): 0.9196
# Class 81 (DS): 0.8881
# Class 82 (DS): 0.9346
# Class 83 (DS): 0.9013
# Class 84 (DS): 0.8974
# Class 85 (DS): 0.8981
# Class 86 (DS): 0.9185
# Class 87 (DS): 0.8930
# Class 88 (DS): 0.9476
# Class 89 (DS): 0.9336
# Class 90 (DS): 0.9205
# Class 91 (DS): 0.8949
# Class 92 (DS): 0.9391
# Class 93 (DS): 0.9415
# Class 94 (DS): 0.9249
# Class 95 (DS): 0.9527
# Class 96 (DS): 0.9171
# Class 97 (DS): 0.9002
# Class 98 (DS): 0.9042
# Class 99 (DS): 0.9592
# Class 100 (DS): 0.9136
# Class 101 (DS): 0.9170
# Class 102 (DS): 0.9288
# Class 103 (DS): 0.9033
# Class 104 (DS): 0.9146
# Class 105 (DS): 0.9054
# Class 106 (DS): 0.8842
# Class 107 (DS): 0.9166
# Class 108 (DS): 0.9296
# Class 109 (DS): 0.9317
# Class 110 (DS): 0.9655
# Class 111 (DS): 0.9316
# ----------
# Epoch: 9, Phase: train, epoch loss: 0.1312, Av. Dice Score: 0.9313
# Class 0 (DS): 0.9373
# Class 1 (DS): 0.9624
# Class 2 (DS): 0.9508
# Class 3 (DS): 0.9040
# Class 4 (DS): 0.9354
# Class 5 (DS): 0.9527
# Class 6 (DS): 0.9651
# Class 7 (DS): 0.9627
# Class 8 (DS): 0.9449
# Class 9 (DS): 0.9655
# Class 10 (DS): 0.9325
# Class 11 (DS): 0.9445
# Class 12 (DS): 0.9619
# Class 13 (DS): 0.9723
# Class 14 (DS): 0.9575
# Class 15 (DS): 0.9634
# Class 16 (DS): 0.9543
# Class 17 (DS): 0.9826
# Class 18 (DS): 0.8582
# Class 19 (DS): 0.9420
# Class 20 (DS): 0.9652
# Class 21 (DS): 0.9729
# Class 22 (DS): 0.9119
# Class 23 (DS): 0.9328
# Class 24 (DS): 0.9640
# Class 25 (DS): 0.9557
# Class 26 (DS): 0.9658
# Class 27 (DS): 0.9588
# Class 28 (DS): 0.9595
# Class 29 (DS): 0.9733
# Class 30 (DS): 0.9659
# Class 31 (DS): 0.9614
# Class 32 (DS): 0.9855
# Class 33 (DS): 0.8487
# Class 34 (DS): 0.8410
# Class 35 (DS): 0.9578
# Class 36 (DS): 0.9791
# Class 37 (DS): 0.9746
# Class 38 (DS): 0.9662
# Class 39 (DS): 0.9527
# Class 40 (DS): 0.9586
# Class 41 (DS): 0.9602
# Class 42 (DS): 0.6597
# Class 43 (DS): 0.9307
# Class 44 (DS): 0.9375
# Class 45 (DS): 0.9460
# Class 46 (DS): 0.9080
# Class 47 (DS): 0.9429
# Class 48 (DS): 0.9218
# Class 49 (DS): 0.9179
# Class 50 (DS): 0.9027
# Class 51 (DS): 0.9199
# Class 52 (DS): 0.9247
# Class 53 (DS): 0.9458
# Class 54 (DS): 0.9242
# Class 55 (DS): 0.9202
# Class 56 (DS): 0.8990
# Class 57 (DS): 0.9340
# Class 58 (DS): 0.9517
# Class 59 (DS): 0.9395
# Class 60 (DS): 0.9533
# Class 61 (DS): 0.9338
# Class 62 (DS): 0.9234
# Class 63 (DS): 0.9245
# Class 64 (DS): 0.9517
# Class 65 (DS): 0.9265
# Class 66 (DS): 0.9099
# Class 67 (DS): 0.9225
# Class 68 (DS): 0.9176
# Class 69 (DS): 0.9131
# Class 70 (DS): 0.9170
# Class 71 (DS): 0.8880
# Class 72 (DS): 0.9310
# Class 73 (DS): 0.9376
# Class 74 (DS): 0.9486
# Class 75 (DS): 0.9607
# Class 76 (DS): 0.9373
# Class 77 (DS): 0.6919
# Class 78 (DS): 0.9382
# Class 79 (DS): 0.9261
# Class 80 (DS): 0.9398
# Class 81 (DS): 0.9055
# Class 82 (DS): 0.9451
# Class 83 (DS): 0.9239
# Class 84 (DS): 0.9062
# Class 85 (DS): 0.9054
# Class 86 (DS): 0.9176
# Class 87 (DS): 0.9198
# Class 88 (DS): 0.9378
# Class 89 (DS): 0.9256
# Class 90 (DS): 0.9382
# Class 91 (DS): 0.8996
# Class 92 (DS): 0.9360
# Class 93 (DS): 0.9511
# Class 94 (DS): 0.9348
# Class 95 (DS): 0.9584
# Class 96 (DS): 0.9210
# Class 97 (DS): 0.9160
# Class 98 (DS): 0.9199
# Class 99 (DS): 0.9502
# Class 100 (DS): 0.9251
# Class 101 (DS): 0.9060
# Class 102 (DS): 0.9255
# Class 103 (DS): 0.9127
# Class 104 (DS): 0.9201
# Class 105 (DS): 0.9089
# Class 106 (DS): 0.9028
# Class 107 (DS): 0.9330
# Class 108 (DS): 0.9393
# Class 109 (DS): 0.9491
# Class 110 (DS): 0.9605
# Class 111 (DS): 0.9255
# ----------
# Epoch: 9, Phase: validate, epoch loss: 0.1404, Av. Dice Score: 0.9287
# Class 0 (DS): 0.9448
# Class 1 (DS): 0.9595
# Class 2 (DS): 0.9545
# Class 3 (DS): 0.9036
# Class 4 (DS): 0.9333
# Class 5 (DS): 0.9602
# Class 6 (DS): 0.9576
# Class 7 (DS): 0.9716
# Class 8 (DS): 0.9344
# Class 9 (DS): 0.9741
# Class 10 (DS): 0.9323
# Class 11 (DS): 0.9455
# Class 12 (DS): 0.9563
# Class 13 (DS): 0.9702
# Class 14 (DS): 0.9700
# Class 15 (DS): 0.9626
# Class 16 (DS): 0.9637
# Class 17 (DS): 0.9819
# Class 18 (DS): 0.8723
# Class 19 (DS): 0.9503
# Class 20 (DS): 0.9543
# Class 21 (DS): 0.9751
# Class 22 (DS): 0.9058
# Class 23 (DS): 0.9316
# Class 24 (DS): 0.9694
# Class 25 (DS): 0.9601
# Class 26 (DS): 0.9675
# Class 27 (DS): 0.9633
# Class 28 (DS): 0.9594
# Class 29 (DS): 0.9695
# Class 30 (DS): 0.9637
# Class 31 (DS): 0.9631
# Class 32 (DS): 0.9736
# Class 33 (DS): 0.8732
# Class 34 (DS): 0.8460
# Class 35 (DS): 0.9668
# Class 36 (DS): 0.9751
# Class 37 (DS): 0.9827
# Class 38 (DS): 0.9600
# Class 39 (DS): 0.9541
# Class 40 (DS): 0.9467
# Class 41 (DS): 0.9638
# Class 42 (DS): 0.6906
# Class 43 (DS): 0.9234
# Class 44 (DS): 0.9329
# Class 45 (DS): 0.9301
# Class 46 (DS): 0.8988
# Class 47 (DS): 0.9316
# Class 48 (DS): 0.9090
# Class 49 (DS): 0.9088
# Class 50 (DS): 0.8971
# Class 51 (DS): 0.9145
# Class 52 (DS): 0.9104
# Class 53 (DS): 0.9450
# Class 54 (DS): 0.9154
# Class 55 (DS): 0.9167
# Class 56 (DS): 0.8882
# Class 57 (DS): 0.9337
# Class 58 (DS): 0.9397
# Class 59 (DS): 0.9362
# Class 60 (DS): 0.9556
# Class 61 (DS): 0.9255
# Class 62 (DS): 0.9169
# Class 63 (DS): 0.9086
# Class 64 (DS): 0.9500
# Class 65 (DS): 0.9181
# Class 66 (DS): 0.9017
# Class 67 (DS): 0.9264
# Class 68 (DS): 0.8970
# Class 69 (DS): 0.9142
# Class 70 (DS): 0.9080
# Class 71 (DS): 0.8899
# Class 72 (DS): 0.9209
# Class 73 (DS): 0.9346
# Class 74 (DS): 0.9430
# Class 75 (DS): 0.9644
# Class 76 (DS): 0.9395
# Class 77 (DS): 0.7109
# Class 78 (DS): 0.9304
# Class 79 (DS): 0.9265
# Class 80 (DS): 0.9259
# Class 81 (DS): 0.8872
# Class 82 (DS): 0.9357
# Class 83 (DS): 0.9147
# Class 84 (DS): 0.8970
# Class 85 (DS): 0.8988
# Class 86 (DS): 0.9185
# Class 87 (DS): 0.8978
# Class 88 (DS): 0.9474
# Class 89 (DS): 0.9330
# Class 90 (DS): 0.9348
# Class 91 (DS): 0.9071
# Class 92 (DS): 0.9389
# Class 93 (DS): 0.9424
# Class 94 (DS): 0.9292
# Class 95 (DS): 0.9499
# Class 96 (DS): 0.9238
# Class 97 (DS): 0.9080
# Class 98 (DS): 0.9077
# Class 99 (DS): 0.9545
# Class 100 (DS): 0.9186
# Class 101 (DS): 0.9092
# Class 102 (DS): 0.9237
# Class 103 (DS): 0.8977
# Class 104 (DS): 0.9148
# Class 105 (DS): 0.9081
# Class 106 (DS): 0.8856
# Class 107 (DS): 0.9104
# Class 108 (DS): 0.9303
# Class 109 (DS): 0.9332
# Class 110 (DS): 0.9679
# Class 111 (DS): 0.9302
# ----------
# --------------------------------------------------
# Training complete in 87m 41s
# Best val dice loss: 0.140371, Best Average DS: 0.928663

# %%
def visualize1(image):
    p = F.softmax(image)
    p_maxim = torch.max(p, dim=0)[1]
    img = []
    for seg in range(num_seg):
        masked = (p_maxim==seg).data.type(torch.cuda.FloatTensor)
        img.append(masked)
    #plt.title(title)
    #plt.imshow(masked[:,:].cpu().numpy())
    #print(torch.stack(img).size())
    return torch.stack(img).resize(num_seg,1,256,256).cpu()

# %%
# %matplotlib inline
def show(img):
    
    npimg = img.numpy()
    #print(npimg.shape)
    plt.figure(figsize = (30,30))
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    plt.show()

# %%
data = next(iter(dataloader["validate"]))
model.train(False)
x = data['x']
y = data['y']
x = Variable(x).type(torch.FloatTensor).cuda()
y = Variable(y).type(torch.FloatTensor).cuda()
                
output = model(x)
for i in range(bs):
    print('-'*100)
    print('Ground Truth')
    abc = data['y'][i,:,:,:]
    bcd = abc.resize(num_seg,1,256,256)
    show(make_grid(bcd,padding=10,pad_value=1)) 
    print('-'*100)
    print('Prediction')
    show(make_grid(visualize1(output[i,:,:,:]),padding=10,pad_value=1))
# Out:
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
