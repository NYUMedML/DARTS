# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torchvision
from torchvision import datasets, models
from torchvision import transforms as T
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import pandas as pd
from skimage import io, transform
import matplotlib.image as mpimg
from PIL import Image
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F
import scipy
import random
import pickle
import scipy.io as sio
import torch.nn.init as I

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.ion()

from torch.utils.data import Dataset, DataLoader
import pandas as pd
import os
from skimage import io
import torch
from torchvision import transforms
import torchvision
from skimage import color
from torch.optim import lr_scheduler
from torchvision.utils import make_grid
import nibabel

from PIL import ImageEnhance
from skimage import data, exposure, img_as_float
from skimage.filters import gaussian

# %%
import pickle
def pickling(file,path):
    pickle.dump(file,open(path,'wb'))
def unpickling(path):
    file_return=pickle.load(open(path,'rb'))
    return file_return

# %%
available_segments = [  0,   2,   3,   4,   5,   7,   8,  10,  11,  12,  13,  14,  15,
        16,  17,  18,  24,  26,  28,  30,  31,  41,  42,  43,  44,  46,
        47,  49,  50,  51,  52,  53,  54,  58,  60,  62,  63,  72,  77,
        80,  85, 251, 252, 253, 254, 255]

# %%
# rest_available = [11,12,50,51]
rest_available = [ 2,   3,   4,   5,   7,   8,  10,  11,  12,  13,  14,  15,
        16,  17,  18,  24,  26,  28,  30,  31,  41,  42,  43,  44,  46,
        47,  49,  50,  51,  52,  53,  54,  58,  60,  62,  63,  72,  77,
        80,  85, 251, 252, 253, 254, 255]

# %%
p = "/gpfs/data/cbi/hcp/hcp_seg/data_manual_extract/train/1000_3/Data_orig/image100.mat"

# %%
i = sio.loadmat(p)['img']

# %%
i.shape
# Out:
# (1, 256, 287)

# %%
plt.imshow(i[0])

# %%
# import dipy
# import matplotlib.pylab as plt

# from dipy.data import get_data
# from dipy.align.imwarp import SymmetricDiffeomorphicRegistration
# from dipy.align.metrics import SSDMetric, CCMetric, EMMetric
# import dipy.align.imwarp as imwarp
# from dipy.viz import regtools

# %%
# metric = SSDMetric(2)
# level_iters = [200, 100, 50, 25]
# sdr = SymmetricDiffeomorphicRegistration(metric, level_iters, inv_iter = 50)

# %%
# m1 = x[88].reshape([256,256])
# m2 = x[94].reshape([256,256])

# plt.imshow(m1); plt.colorbar(); plt.show()
# plt.imshow(m2); plt.colorbar(); plt.show()

# regtools.overlay_images(m1, m2, 'channel1', 'channel2', 'both channels', 'tmp.png');
# metric = SSDMetric(2)
# level_iters = [200, 100, 50, 25]
# sdr = SymmetricDiffeomorphicRegistration(metric, level_iters, inv_iter = 50)

# mapping = sdr.optimize(m1, m2)

# regtools.plot_2d_diffeomorphic_map(mapping, 10, 'diffeomorphic_map.png')
# warped_m2 = mapping.transform(m2, 'linear')

# regtools.overlay_images(m1, warped_m2, 'initial m1','Overlay','Warped m2', 'direct_warp_result.png')
# plt.imshow(warped_m2); plt.colorbar(); plt.show()

# plt.imshow(m1-warped_m2); plt.colorbar(); plt.show()
# plt.imshow(m1-m2); plt.colorbar(); plt.show()

# %%
num_seg = len(rest_available)+1

# %%
x_coordinate = np.zeros((256,256))
for i in range(256):
    x_coordinate[i:] = [i]*256    
y_coordinate = x_coordinate.copy()
y_coordinate = y_coordinate.T

# %%
x_coordinate = x_coordinate/255
y_coordinate = y_coordinate/255

# %%
class BrainImages(Dataset):
    def __init__(self, image_dir, label_dir, train_data = False, flipping = True, rotation = True, translation = True, \
                 coord = True):
        
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.flipping = flipping
        self.rotation = rotation
        self.translation = translation
        self.train_data = train_data
        self.coord = coord

    def __len__(self):
        return len(self.image_dir)

    def __getitem__(self,idx):
        image_path = "/gpfs/data/"+self.image_dir[idx]
        aseg_path = "/gpfs/data/"+self.label_dir[idx]
        
        img_orig = nibabel.freesurfer.mghformat.MGHImage.from_filename(image_path)
        image = img_orig.get_data().astype(np.float64)
        aseg_img = nibabel.freesurfer.mghformat.MGHImage.from_filename(aseg_path)
        aseg_img = aseg_img.get_data().astype(np.float64)

        flip = random.random() > 0.5
        angle = random.uniform(-10,10)
        dx = np.round(random.uniform(-25,25))
        dy = np.round(random.uniform(-25,25))
        
        im = Image.fromarray(image[0])
        target = Image.fromarray(aseg_img[0])
        if self.train_data:
            if self.flipping and flip:
                im = im.transpose(0)
                target = target.transpose(0)
            if self.rotation:
                im = im.rotate(angle)
                target = target.rotate(angle)
            if self.translation:
                im = im.transform((256,256),0, (1,0,dx,0,1,dy))
                target = target.transform((256,256),0,(1,0,dx,0,1,dy))
                
#        im = torch.from_numpy(np.array(im, np.float64, copy=False).reshape((1,256,256)))/255
        guassian_flag = random.random() > 0.5
        
        im = np.array(im, np.float64, copy=False)
        min_im = np.min(im)
        max_im = np.max(im)
        im = (im - min_im)/(max_im - min_im + 1e-4)
        if self.train_data and guassian_flag:
            sigma_rand = random.uniform(0.65,1.0)
            im_sigma = gaussian(im, sigma = sigma_rand)
            gamma_rand = random.uniform(1.6,2.4)
            im_sigma_gamma = exposure.adjust_gamma(im_sigma, gamma_rand)
            im = (im_sigma_gamma - np.min(im_sigma_gamma))/(np.max(im_sigma_gamma)-np.min(im_sigma_gamma)+1e-4)
        
        
        if self.coord:
            im = np.array([im, x_coordinate, y_coordinate], np.float64, copy=False)
            im = torch.from_numpy(im).type(torch.FloatTensor)
        else:
            im = torch.from_numpy(im).type(torch.FloatTensor).unsqueeze(0)

        target = np.array(target, np.float64, copy=False)
        target_label = np.zeros((len(rest_available)+1,256,256))
        for i,a in enumerate(available_segments):
            temp = (target==a).astype(int)
            if a in rest_available:
                target_label[rest_available.index(a),:,:] = temp
            else:
                target_label[len(rest_available),:,:] = target_label[len(rest_available),:,:] + temp
        target_label[len(rest_available),:,:] = (target_label[len(rest_available),:,:]>=1).astype(int) 
#        print(target_label.shape)
        target_label = torch.from_numpy(target_label).type(torch.FloatTensor)
        sample = {'x':im,'y':target_label} 
        return sample

# %%
file_names = pd.read_csv("all_complete_path.csv")

# %%
train_subjects = unpickling("train_subject_index")
val_subjects = unpickling("val_subject_index")
test_subjects = unpickling("test_subject_index")

# %%
full_train_raw = list(file_names.iloc[train_subjects,2])
full_train_seg = list(file_names.iloc[train_subjects,3])

full_val_raw = list(file_names.iloc[val_subjects,2])
full_val_seg = list(file_names.iloc[val_subjects,3])

full_test_raw = list(file_names.iloc[test_subjects,2])
full_test_seg = list(file_names.iloc[test_subjects,3])

# %%
277*18
# Out:
# 4986

# %%
rand1 = np.arange(len(full_train_raw))
np.random.shuffle(rand1)
rand1 = rand1[:5000]

rand2 = np.arange(len(val_subjects))
np.random.shuffle(rand2)
rand2 = rand2[:1000]

rand3 = np.arange(len(test_subjects))
np.random.shuffle(rand3)
rand3 = rand3[:3]

# %%
cd = False
transformed_dataset = {'train': BrainImages(np.array(full_train_raw)[rand1],np.array(full_train_seg)[rand1], train_data= True, flipping=False, coord = cd),
                       'validate': BrainImages(np.array(full_val_raw)[rand2],np.array(full_val_seg)[rand2], coord = cd),
                       'test': BrainImages(np.array(full_test_raw)[rand3],np.array(full_test_seg)[rand3], coord = cd)
                                               }
bs = 12
dataloader = {x: DataLoader(transformed_dataset[x], batch_size=bs,
                        shuffle=True, num_workers=0) for x in ['train', 'validate','test']}
data_sizes ={x: len(transformed_dataset[x]) for x in ['train', 'validate','test']}

# %%
data = next(iter(dataloader['train']))

# %%
data['y'].size()
# Out:
# torch.Size([12, 46, 256, 256])

# %%
data['x'].size()
# Out:
# torch.Size([12, 1, 256, 256])

# %%
for i in range(bs):
    plt.imshow(data['x'][i,0,:,:],cmap='gray')
    plt.show()

# %%
# list_arr = []
# for data in dataloader["train"]:
#     y = data['y'].numpy()
#     N,C,_,_ = y.shape
#     sum_arr = np.sum(y.reshape(N,C,-1),axis = 2)
#     list_arr.append(sum_arr)
# final_arr = np.concatenate(list_arr,axis = 0)
# freq_class = np.true_divide(final_arr.sum(0),(final_arr!=0).sum(0)*(256*256))
# class_wts = np.median(freq_class)/freq_class
# pickling(class_wts,'new_class_wts_46_seg')

# %%
class_wts = unpickling('new_class_wts_46_seg')

# %%
class Downsample_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Downsample_block, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
    
    def forward(self,x):
        x = F.relu(self.bn1(self.conv1(x)))
        y = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(y, 2,stride = 2)
        
        return x, y

# %%
class Upsample_block(nn.Module):
    def __init__(self,in_channels, out_channels):
        super(Upsample_block, self).__init__()
        self.transconv = nn.ConvTranspose2d(in_channels, out_channels, 4, padding = 1, stride = 2)
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
    def forward(self,x, y):
        x = self.transconv(x)
        x = torch.cat((x,y),dim = 1)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        
        return x

# %%
class Unet(nn.Module):
    def __init__(self,in_chan = 3, out_chan = 3):
        super(Unet, self).__init__()
        self.down1 = Downsample_block(in_chan,64)
        self.down2 = Downsample_block(64,128)
        self.down3 = Downsample_block(128,256)
        self.down4 = Downsample_block(256,512)
        self.conv1 = nn.Conv2d(512,1024, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(1024)
        self.conv2 = nn.Conv2d(1024,1024,3, padding = 1)
        self.bn2 = nn.BatchNorm2d(1024)
        self.up4 = Upsample_block(1024,512)
        self.up3 = Upsample_block(512,256)
        self.up2 = Upsample_block(256,128)
        self.up1 = Upsample_block(128,64)
        self.outconv = nn.Conv2d(64,out_chan, 1)
        
    def forward(self,x):
        x, y1 = self.down1(x)
        x, y2 = self.down2(x)
        x, y3 = self.down3(x)
        x, y4 = self.down4(x)
        x = F.dropout2d(F.relu(self.bn1(self.conv1(x))))
        x = F.dropout2d(F.relu(self.bn2(self.conv2(x))))
        x = self.up4(x, y4)
        x = self.up3(x, y3)
        x = self.up2(x, y2)
        x = self.up1(x, y1)
        x = self.outconv(x)
        
        return x

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        I.xavier_normal(m.weight.data)

# %%
wts_torch = Variable(torch.from_numpy(class_wts)).cuda()

# %%
def get_gradient(true):
    true = true.data.cpu().numpy()
    N,C,sh1,sh2 = true.shape
    grads = []
    for i in range(N):
        grad_chan = []
        for j in range(C):
            sx = ndimage.sobel(true_out[i,j],axis=0,mode='constant')
            sy = ndimage.sobel(true_out[i,j],axis=1,mode='constant')
            sobel=np.hypot(sx,sy)
            grad_chan.append(sobel)
        grad_chan = np.vstack(grad_chan)
        grads.append(grad_chan)
    grads = np.vstack(grads)
    grads_mask = torch.from_numpy((np.absolute(grads)>0)).type(torch.cuda.FloatTensor)
    
    return grads_mask.view(N,C,-1)

# %%
def dice_loss_2(true,scores,mean, epsilon = 1e-4,p = 2,we = 0.05):
#     N, C, sh1, sh2 = true1.size()
    
#     true = []
#     scores = []
#     for c in range(N):
#         if not torch.sum(true1[c,1:,:,:])==0:
#             true.append(true1[c,:,:,:])
#             scores.append(scores1[c,:,:,:])
#     try:
#         true = torch.stack(true)
#         scores = torch.stack(scores)
#     except:
#         return -1
    
    
    
    N, C, sh1, sh2 = true.size()
#     grad_mask = get_gradient(true)
#     grad_mask = grad_mask.view(N,C,-1)
    
    preds = F.softmax(scores, dim = 1)
    true = true.view(N, C, -1)
    preds = preds.view(N, C, -1)
    wts = torch.sum(true, dim = 2) + epsilon
#     mean = 1/torch.pow(mean,p)
    wts[:,:] = mean[None].repeat(N,1)
#     wts = wts/(torch.sum(wts,dim = 1)[:,None])
#     print(wts)
    grad_wts = torch.max(mean)
    prod = torch.sum(true*preds,dim = 2)
    sum_tnp = torch.sum(true + preds, dim = 2)
    num = torch.sum(wts * prod, dim = 1)
    denom = torch.sum(wts * sum_tnp, dim = 1) + epsilon
    loss = 1 - 2*(num/denom)
    cel = -torch.sum(wts * torch.sum(true*torch.log(preds),dim = 2),dim = 1)
#     grad_loss = -torch.sum(2*grad_wts * torch.sum(grad_mask*torch.log(preds),dim = 2),dim = 1)
    return 40*torch.mean(loss)+we*torch.mean(cel)
#     return torch.mean(loss)

# %%
def dice_score(true,scores, epsilon = 1e-7):
#     N ,C, sh1, sh2 = true1.size()
#     true = []
#     scores = []
#     for c in range(N):
#         if not torch.sum(true1[c,1:,:,:])==0:
#             true.append(true1[c,:,:,:])
#             scores.append(scores1[c,:,:,:])
#     try:
#         true = torch.stack(true)
#         scores = torch.stack(scores)
#     except:
#         return 0
    
    N, C, sh1, sh2 = true.size()
    
    true = true.view(N,C,-1)
    preds = F.softmax(scores, dim = 1)
    pred_class = (torch.max(preds, dim = 1)[1]).view(N,-1)
    class_score = [0]*C
    for i in range(C):
        class_score[i] = (pred_class == i).data.type(torch.cuda.FloatTensor)
    true = true.data.type(torch.cuda.FloatTensor)
    def numerator(truth,pred, idx):
        return(torch.sum(truth[:,idx,:] * pred,dim = 1)) + epsilon/2
    def denominator(truth,pred,idx):
        return(torch.sum(truth[:,idx,:]+pred,dim = 1)) + epsilon
    dice_class_score = [0]*C
    for i in range(C):
        dice_class_score[i] = torch.mean(2*(numerator(true,class_score[i],i))/(denominator(true,class_score[i],i)))
    return dice_class_score

# %%
import time
def train_model(model, optimizer,dataloader, name,num_seg = 3, num_epochs = 100, verbose = False, every = 1,\
                print_all_ds = True):
    since = time.time()
    best_loss = np.inf
    best_score = 0
    loss_hist = {'train':[],'validate':[]}
    dice_scores_of_all_class = [{'train':[],'validate':[]} for i in range(num_seg)]    
    for i in range(num_epochs):
        for phase in ['train', 'validate']:
            running_loss = 0
            run_class_scores = [0]*num_seg
            running_total = 0
            if phase == 'train':
                model.train(True)
            else:
                model.train(False)
    
            for data in dataloader[phase]:
                optimizer.zero_grad()
                x = data['x']
                y = data['y']
                x = Variable(x).cuda()
                y = Variable(y).cuda()
                N, C, sh1, sh2 = y.size()
                rand_num = np.random.rand()
                if rand_num < 0.90:
                    y_mask = (torch.sum(y[:,:(C-1),:,:].contiguous().view(N,-1),dim = 1) != 0)
                    y = y[y_mask]
                    x = x[y_mask]
#                 for sel in range(x.size()[0]):
#                     if torch.sum(y[sel,0,:,:]) != 0:
#                         y_sel.append(y[sel,:,:,:])
#                         x_sel.append(x[sel,:,:,:])

#                 try:
#                     y_sel = torch.stack(y_sel)
#                     output_sel = torch.stack(output_sel)
#                 except:
#                     continue
#                 output = model(x)
                try:
                    output = model(x)
                except:
                    continue
                loss = dice_loss_2(y, output,wts_torch)
                #loss = Variable(dice_loss_2(y_sel, output_sel,wts_torch),requires_grad=True)
                if loss==-1:
                    continue
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                running_loss += loss.data[0] * N
                running_total += N
                dice_score_batch = dice_score(y,output)

                for j in range(num_seg):
                    run_class_scores[j] += dice_score_batch[j] * N
            epoch_loss = running_loss/running_total
            loss_hist[phase].append(epoch_loss.item())
            epoch_score = 0
            for j in range(num_seg):
                score = run_class_scores[j]/running_total
                dice_scores_of_all_class[j][phase].append(score.item())
                if j < num_seg - 1:
                    epoch_score += score.item()
            epoch_score_av = epoch_score/ (num_seg - 1)
            if verbose or i%every == 0:
                print('Epoch: {}, Phase: {}, epoch loss: {:.4f}, Av. Dice Score: {:.4f}'\
                      .format(i,phase,epoch_loss,epoch_score_av))
#                 epoch_score = 0
                if print_all_ds:
                    for j in range(num_seg - 1):
                        print('Class {} (DS): {:.4f}'.format(j,dice_scores_of_all_class[j][phase][-1]))
    #                 epoch_score += dice_scores_of_all_class[j][phase][-1]
    #             epoch_score_av = epoch_score / (num_seg - 1)
                print('-'*10)
            
        if phase == 'validate' and epoch_score_av > best_score:
            best_loss = epoch_loss
            best_score = epoch_score_av
            best_model_wts = model.state_dict()
            torch.save(model,name)
        #print(i)
    print('-'*50)    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val dice loss: {:4f}, Best Average DS: {:4f}'.format(best_loss,best_score))
    
    model.load_state_dict(best_model_wts)
    pickling(loss_hist,name+'loss_hist')
    pickling(dice_scores_of_all_class,name+'dice_hist')
    
    return model, loss_hist, dice_scores_of_all_class

# %%
model = Unet(in_chan = 1,out_chan = num_seg).cuda()
model.apply(weights_init)
model = nn.DataParallel(model)
criterion = dice_loss_2
#scheduler = lr_scheduler.StepLR(optimizer,step_size = 15)

# %%
optimizer = optim.Adam(model.parameters(),lr = 1e-4)

# %%
model, loss_hist, dice_hist = train_model(model, optimizer,dataloader,'exp_1_dnc_then_d_lr_1e-4',num_seg = num_seg, num_epochs = 30,\
                                         every = 1, print_all_ds = True)
# Out:
# Epoch: 0, Phase: train, epoch loss: 159.3691, Av. Dice Score: 0.2087
# Class 0 (DS): 0.4801
# Class 1 (DS): 0.3658
# Class 2 (DS): 0.0563
# Class 3 (DS): 0.0226
# Class 4 (DS): 0.1155
# Class 5 (DS): 0.5621
# Class 6 (DS): 0.3520
# Class 7 (DS): 0.0482
# Class 8 (DS): 0.0602
# Class 9 (DS): 0.0011
# Class 10 (DS): 0.0374
# Class 11 (DS): 0.5105
# Class 12 (DS): 0.0865
# Class 13 (DS): 0.1806
# Class 14 (DS): 0.0490
# Class 15 (DS): 0.0073
# Class 16 (DS): 0.7241
# Class 17 (DS): 0.7275
# Class 18 (DS): 0.1406
# Class 19 (DS): 0.0477
# Class 20 (DS): 0.4378
# Class 21 (DS): 0.4041
# Class 22 (DS): 0.1326
# Class 23 (DS): 0.1233
# Class 24 (DS): 0.1289
# Class 25 (DS): 0.5708
# Class 26 (DS): 0.1089
# Class 27 (DS): 0.0670
# Class 28 (DS): 0.1177
# Class 29 (DS): 0.0612
# Class 30 (DS): 0.0313
# Class 31 (DS): 0.0309
# Class 32 (DS): 0.0304
# Class 33 (DS): 0.1466
# Class 34 (DS): 0.9578
# Class 35 (DS): 0.0202
# Class 36 (DS): 0.1401
# Class 37 (DS): 0.0412
# Class 38 (DS): 0.0000
# Class 39 (DS): 0.0157
# Class 40 (DS): 0.8624
# Class 41 (DS): 0.0348
# Class 42 (DS): 0.0377
# Class 43 (DS): 0.2318
# Class 44 (DS): 0.0835
# ----------
# Epoch: 0, Phase: validate, epoch loss: 98.5631, Av. Dice Score: 0.2512
# Class 0 (DS): 0.6096
# Class 1 (DS): 0.5203
# Class 2 (DS): 0.0595
# Class 3 (DS): 0.0007
# Class 4 (DS): 0.1305
# Class 5 (DS): 0.7754
# Class 6 (DS): 0.1337
# Class 7 (DS): 0.1027
# Class 8 (DS): 0.1297
# Class 9 (DS): 0.0062
# Class 10 (DS): 0.0924
# Class 11 (DS): 0.6064
# Class 12 (DS): 0.1271
# Class 13 (DS): 0.1383
# Class 14 (DS): 0.0330
# Class 15 (DS): 0.0200
# Class 16 (DS): 0.2678
# Class 17 (DS): 0.8222
# Class 18 (DS): 0.5973
# Class 19 (DS): 0.0548
# Class 20 (DS): 0.5264
# Class 21 (DS): 0.4862
# Class 22 (DS): 0.2384
# Class 23 (DS): 0.0625
# Class 24 (DS): 0.1351
# Class 25 (DS): 0.6391
# Class 26 (DS): 0.4888
# Class 27 (DS): 0.0995
# Class 28 (DS): 0.2265
# Class 29 (DS): 0.1008
# Class 30 (DS): 0.0660
# Class 31 (DS): 0.0637
# Class 32 (DS): 0.0571
# Class 33 (DS): 0.6067
# Class 34 (DS): 0.9727
# Class 35 (DS): 0.0257
# Class 36 (DS): 0.1857
# Class 37 (DS): 0.0639
# Class 38 (DS): 0.0000
# Class 39 (DS): 0.0391
# Class 40 (DS): 0.7111
# Class 41 (DS): 0.0515
# Class 42 (DS): 0.0412
# Class 43 (DS): 0.0794
# Class 44 (DS): 0.1071
# ----------
# Epoch: 1, Phase: train, epoch loss: 84.8425, Av. Dice Score: 0.3486
# Class 0 (DS): 0.6258
# Class 1 (DS): 0.5020
# Class 2 (DS): 0.0930
# Class 3 (DS): 0.1608
# Class 4 (DS): 0.1961
# Class 5 (DS): 0.7043
# Class 6 (DS): 0.3825
# Class 7 (DS): 0.2767
# Class 8 (DS): 0.3160
# Class 9 (DS): 0.0808
# Class 10 (DS): 0.1917
# Class 11 (DS): 0.6333
# Class 12 (DS): 0.2149
# Class 13 (DS): 0.6175
# Class 14 (DS): 0.2185
# Class 15 (DS): 0.0897
# Class 16 (DS): 0.5112
# Class 17 (DS): 0.6700
# Class 18 (DS): 0.5873
# Class 19 (DS): 0.1292
# Class 20 (DS): 0.4892
# Class 21 (DS): 0.4772
# Class 22 (DS): 0.3039
# Class 23 (DS): 0.1819
# Class 24 (DS): 0.2571
# Class 25 (DS): 0.4811
# Class 26 (DS): 0.5378
# Class 27 (DS): 0.2077
# Class 28 (DS): 0.5600
# Class 29 (DS): 0.4794
# Class 30 (DS): 0.1942
# Class 31 (DS): 0.1215
# Class 32 (DS): 0.1460
# Class 33 (DS): 0.5146
# Class 34 (DS): 0.8792
# Class 35 (DS): 0.2057
# Class 36 (DS): 0.7027
# Class 37 (DS): 0.1219
# Class 38 (DS): 0.0648
# Class 39 (DS): 0.1081
# Class 40 (DS): 0.6573
# Class 41 (DS): 0.1050
# Class 42 (DS): 0.0841
# Class 43 (DS): 0.2478
# Class 44 (DS): 0.3585
# ----------
# Epoch: 1, Phase: validate, epoch loss: 73.1892, Av. Dice Score: 0.5340
# Class 0 (DS): 0.6805
# Class 1 (DS): 0.5803
# Class 2 (DS): 0.1505
# Class 3 (DS): 0.2761
# Class 4 (DS): 0.2468
# Class 5 (DS): 0.7494
# Class 6 (DS): 0.7180
# Class 7 (DS): 0.6759
# Class 8 (DS): 0.8013
# Class 9 (DS): 0.3100
# Class 10 (DS): 0.3721
# Class 11 (DS): 0.6790
# Class 12 (DS): 0.3245
# Class 13 (DS): 0.7991
# Class 14 (DS): 0.4001
# Class 15 (DS): 0.0836
# Class 16 (DS): 0.7874
# Class 17 (DS): 0.8438
# Class 18 (DS): 0.9717
# Class 19 (DS): 0.2884
# Class 20 (DS): 0.5203
# Class 21 (DS): 0.5567
# Class 22 (DS): 0.4024
# Class 23 (DS): 0.4353
# Class 24 (DS): 0.4970
# Class 25 (DS): 0.7467
# Class 26 (DS): 0.8571
# Class 27 (DS): 0.3902
# Class 28 (DS): 0.8654
# Class 29 (DS): 0.8354
# Class 30 (DS): 0.3922
# Class 31 (DS): 0.2482
# Class 32 (DS): 0.5479
# Class 33 (DS): 0.8040
# Class 34 (DS): 0.9450
# Class 35 (DS): 0.2022
# Class 36 (DS): 0.9309
# Class 37 (DS): 0.1997
# Class 38 (DS): 0.1632
# Class 39 (DS): 0.3852
# Class 40 (DS): 0.4972
# Class 41 (DS): 0.2585
# Class 42 (DS): 0.1142
# Class 43 (DS): 0.7486
# Class 44 (DS): 0.7477
# ----------
# Epoch: 2, Phase: train, epoch loss: 72.7766, Av. Dice Score: 0.7244
# Class 0 (DS): 0.6630
# Class 1 (DS): 0.5834
# Class 2 (DS): 0.3897
# Class 3 (DS): 0.7229
# Class 4 (DS): 0.7151
# Class 5 (DS): 0.7681
# Class 6 (DS): 0.8259
# Class 7 (DS): 0.8038
# Class 8 (DS): 0.8558
# Class 9 (DS): 0.5219
# Class 10 (DS): 0.6734
# Class 11 (DS): 0.6956
# Class 12 (DS): 0.6623
# Class 13 (DS): 0.8596
# Class 14 (DS): 0.7809
# Class 15 (DS): 0.4657
# Class 16 (DS): 0.8778
# Class 17 (DS): 0.8511
# Class 18 (DS): 0.9502
# Class 19 (DS): 0.6538
# Class 20 (DS): 0.5912
# Class 21 (DS): 0.5694
# Class 22 (DS): 0.6958
# Class 23 (DS): 0.7610
# Class 24 (DS): 0.7628
# Class 25 (DS): 0.7685
# Class 26 (DS): 0.9077
# Class 27 (DS): 0.7407
# Class 28 (DS): 0.8335
# Class 29 (DS): 0.8834
# Class 30 (DS): 0.7082
# Class 31 (DS): 0.6623
# Class 32 (DS): 0.8828
# Class 33 (DS): 0.8493
# Class 34 (DS): 0.9154
# Class 35 (DS): 0.5610
# Class 36 (DS): 0.9065
# Class 37 (DS): 0.4533
# Class 38 (DS): 0.6409
# Class 39 (DS): 0.6618
# Class 40 (DS): 0.8471
# Class 41 (DS): 0.6233
# Class 42 (DS): 0.4401
# Class 43 (DS): 0.7940
# Class 44 (DS): 0.8182
# ----------
# Epoch: 2, Phase: validate, epoch loss: 68.9332, Av. Dice Score: 0.8245
# Class 0 (DS): 0.6599
# Class 1 (DS): 0.5945
# Class 2 (DS): 0.6430
# Class 3 (DS): 0.7955
# Class 4 (DS): 0.8339
# Class 5 (DS): 0.8307
# Class 6 (DS): 0.8618
# Class 7 (DS): 0.8943
# Class 8 (DS): 0.9005
# Class 9 (DS): 0.7852
# Class 10 (DS): 0.6595
# Class 11 (DS): 0.7146
# Class 12 (DS): 0.8381
# Class 13 (DS): 0.8934
# Class 14 (DS): 0.8653
# Class 15 (DS): 0.5406
# Class 16 (DS): 0.8357
# Class 17 (DS): 0.8607
# Class 18 (DS): 0.9691
# Class 19 (DS): 0.7701
# Class 20 (DS): 0.6320
# Class 21 (DS): 0.6039
# Class 22 (DS): 0.8936
# Class 23 (DS): 0.9369
# Class 24 (DS): 0.8345
# Class 25 (DS): 0.8222
# Class 26 (DS): 0.9390
# Class 27 (DS): 0.9164
# Class 28 (DS): 0.9220
# Class 29 (DS): 0.9301
# Class 30 (DS): 0.8461
# Class 31 (DS): 0.8712
# Class 32 (DS): 0.9085
# Class 33 (DS): 0.8610
# Class 34 (DS): 0.9656
# Class 35 (DS): 0.7194
# Class 36 (DS): 0.9558
# Class 37 (DS): 0.7209
# Class 38 (DS): 0.8503
# Class 39 (DS): 0.8807
# Class 40 (DS): 0.9454
# Class 41 (DS): 0.8514
# Class 42 (DS): 0.8103
# Class 43 (DS): 0.8518
# Class 44 (DS): 0.8878
# ----------
# Epoch: 3, Phase: train, epoch loss: 64.8799, Av. Dice Score: 0.8374
# Class 0 (DS): 0.7130
# Class 1 (DS): 0.6436
# Class 2 (DS): 0.7091
# Class 3 (DS): 0.8759
# Class 4 (DS): 0.8143
# Class 5 (DS): 0.8105
# Class 6 (DS): 0.9095
# Class 7 (DS): 0.8917
# Class 8 (DS): 0.9084
# Class 9 (DS): 0.7679
# Class 10 (DS): 0.8054
# Class 11 (DS): 0.7176
# Class 12 (DS): 0.8449
# Class 13 (DS): 0.9008
# Class 14 (DS): 0.9157
# Class 15 (DS): 0.7810
# Class 16 (DS): 0.9237
# Class 17 (DS): 0.9034
# Class 18 (DS): 0.9598
# Class 19 (DS): 0.7615
# Class 20 (DS): 0.6587
# Class 21 (DS): 0.6257
# Class 22 (DS): 0.8554
# Class 23 (DS): 0.9108
# Class 24 (DS): 0.8379
# Class 25 (DS): 0.8215
# Class 26 (DS): 0.9376
# Class 27 (DS): 0.9096
# Class 28 (DS): 0.9090
# Class 29 (DS): 0.9258
# Class 30 (DS): 0.8668
# Class 31 (DS): 0.8824
# Class 32 (DS): 0.9355
# Class 33 (DS): 0.9044
# Class 34 (DS): 0.9469
# Class 35 (DS): 0.7098
# Class 36 (DS): 0.9209
# Class 37 (DS): 0.6229
# Class 38 (DS): 0.8187
# Class 39 (DS): 0.8805
# Class 40 (DS): 0.9093
# Class 41 (DS): 0.8519
# Class 42 (DS): 0.7551
# Class 43 (DS): 0.8479
# Class 44 (DS): 0.8817
# ----------
# Epoch: 3, Phase: validate, epoch loss: 61.2305, Av. Dice Score: 0.8573
# Class 0 (DS): 0.6805
# Class 1 (DS): 0.6367
# Class 2 (DS): 0.6719
# Class 3 (DS): 0.9152
# Class 4 (DS): 0.7557
# Class 5 (DS): 0.7868
# Class 6 (DS): 0.9362
# Class 7 (DS): 0.9192
# Class 8 (DS): 0.9198
# Class 9 (DS): 0.8548
# Class 10 (DS): 0.8484
# Class 11 (DS): 0.7188
# Class 12 (DS): 0.8537
# Class 13 (DS): 0.9027
# Class 14 (DS): 0.9129
# Class 15 (DS): 0.8388
# Class 16 (DS): 0.8806
# Class 17 (DS): 0.8943
# Class 18 (DS): 0.9733
# Class 19 (DS): 0.8312
# Class 20 (DS): 0.6798
# Class 21 (DS): 0.6536
# Class 22 (DS): 0.8681
# Class 23 (DS): 0.9523
# Class 24 (DS): 0.7952
# Class 25 (DS): 0.8099
# Class 26 (DS): 0.9480
# Class 27 (DS): 0.9242
# Class 28 (DS): 0.9409
# Class 29 (DS): 0.9467
# Class 30 (DS): 0.9032
# Class 31 (DS): 0.9402
# Class 32 (DS): 0.9084
# Class 33 (DS): 0.9318
# Class 34 (DS): 0.9779
# Class 35 (DS): 0.7643
# Class 36 (DS): 0.9384
# Class 37 (DS): 0.7532
# Class 38 (DS): 0.8657
# Class 39 (DS): 0.9239
# Class 40 (DS): 0.9155
# Class 41 (DS): 0.9357
# Class 42 (DS): 0.9019
# Class 43 (DS): 0.8418
# Class 44 (DS): 0.8251
# ----------
# Epoch: 4, Phase: train, epoch loss: 59.5288, Av. Dice Score: 0.8677
# Class 0 (DS): 0.7556
# Class 1 (DS): 0.6776
# Class 2 (DS): 0.8262
# Class 3 (DS): 0.9061
# Class 4 (DS): 0.8363
# Class 5 (DS): 0.8184
# Class 6 (DS): 0.9294
# Class 7 (DS): 0.9185
# Class 8 (DS): 0.9222
# Class 9 (DS): 0.8645
# Class 10 (DS): 0.8574
# Class 11 (DS): 0.7397
# Class 12 (DS): 0.8729
# Class 13 (DS): 0.9151
# Class 14 (DS): 0.9373
# Class 15 (DS): 0.8575
# Class 16 (DS): 0.9284
# Class 17 (DS): 0.9221
# Class 18 (DS): 0.9643
# Class 19 (DS): 0.7854
# Class 20 (DS): 0.7000
# Class 21 (DS): 0.6620
# Class 22 (DS): 0.8865
# Class 23 (DS): 0.9316
# Class 24 (DS): 0.8535
# Class 25 (DS): 0.8366
# Class 26 (DS): 0.9464
# Class 27 (DS): 0.9304
# Class 28 (DS): 0.9230
# Class 29 (DS): 0.9312
# Class 30 (DS): 0.8934
# Class 31 (DS): 0.9269
# Class 32 (DS): 0.9416
# Class 33 (DS): 0.9202
# Class 34 (DS): 0.9616
# Class 35 (DS): 0.7479
# Class 36 (DS): 0.9225
# Class 37 (DS): 0.6739
# Class 38 (DS): 0.8489
# Class 39 (DS): 0.9219
# Class 40 (DS): 0.9291
# Class 41 (DS): 0.9083
# Class 42 (DS): 0.8499
# Class 43 (DS): 0.8682
# Class 44 (DS): 0.8968
# ----------
# Epoch: 4, Phase: validate, epoch loss: 59.8099, Av. Dice Score: 0.8896
# Class 0 (DS): 0.8080
# Class 1 (DS): 0.8020
# Class 2 (DS): 0.8812
# Class 3 (DS): 0.9242
# Class 4 (DS): 0.8611
# Class 5 (DS): 0.8763
# Class 6 (DS): 0.9306
# Class 7 (DS): 0.9105
# Class 8 (DS): 0.9404
# Class 9 (DS): 0.8990
# Class 10 (DS): 0.9103
# Class 11 (DS): 0.8240
# Class 12 (DS): 0.9075
# Class 13 (DS): 0.9123
# Class 14 (DS): 0.9393
# Class 15 (DS): 0.8820
# Class 16 (DS): 0.9087
# Class 17 (DS): 0.9349
# Class 18 (DS): 0.9631
# Class 19 (DS): 0.8294
# Class 20 (DS): 0.7444
# Class 21 (DS): 0.7210
# Class 22 (DS): 0.9327
# Class 23 (DS): 0.9376
# Class 24 (DS): 0.8484
# Class 25 (DS): 0.8700
# Class 26 (DS): 0.9524
# Class 27 (DS): 0.9385
# Class 28 (DS): 0.9179
# Class 29 (DS): 0.9135
# Class 30 (DS): 0.9218
# Class 31 (DS): 0.9430
# Class 32 (DS): 0.9134
# Class 33 (DS): 0.9417
# Class 34 (DS): 0.9803
# Class 35 (DS): 0.7837
# Class 36 (DS): 0.9499
# Class 37 (DS): 0.7584
# Class 38 (DS): 0.7968
# Class 39 (DS): 0.9087
# Class 40 (DS): 0.9551
# Class 41 (DS): 0.9490
# Class 42 (DS): 0.8718
# Class 43 (DS): 0.8452
# Class 44 (DS): 0.8925
# ----------
# Epoch: 5, Phase: train, epoch loss: 55.3732, Av. Dice Score: 0.8805
# Class 0 (DS): 0.7809
# Class 1 (DS): 0.7056
# Class 2 (DS): 0.8685
# Class 3 (DS): 0.9009
# Class 4 (DS): 0.8566
# Class 5 (DS): 0.8389
# Class 6 (DS): 0.9377
# Class 7 (DS): 0.9246
# Class 8 (DS): 0.9348
# Class 9 (DS): 0.8886
# Class 10 (DS): 0.8782
# Class 11 (DS): 0.7498
# Class 12 (DS): 0.8876
# Class 13 (DS): 0.9183
# Class 14 (DS): 0.9379
# Class 15 (DS): 0.8873
# Class 16 (DS): 0.9354
# Class 17 (DS): 0.9271
# Class 18 (DS): 0.9674
# Class 19 (DS): 0.8005
# Class 20 (DS): 0.7441
# Class 21 (DS): 0.6843
# Class 22 (DS): 0.9060
# Class 23 (DS): 0.9320
# Class 24 (DS): 0.8725
# Class 25 (DS): 0.8441
# Class 26 (DS): 0.9458
# Class 27 (DS): 0.9370
# Class 28 (DS): 0.9302
# Class 29 (DS): 0.9339
# Class 30 (DS): 0.8975
# Class 31 (DS): 0.9314
# Class 32 (DS): 0.9428
# Class 33 (DS): 0.9371
# Class 34 (DS): 0.9657
# Class 35 (DS): 0.7787
# Class 36 (DS): 0.9347
# Class 37 (DS): 0.6950
# Class 38 (DS): 0.8392
# Class 39 (DS): 0.9287
# Class 40 (DS): 0.9505
# Class 41 (DS): 0.9264
# Class 42 (DS): 0.8611
# Class 43 (DS): 0.8761
# Class 44 (DS): 0.9031
# ----------
# Epoch: 5, Phase: validate, epoch loss: 53.8574, Av. Dice Score: 0.8795
# Class 0 (DS): 0.8807
# Class 1 (DS): 0.7646
# Class 2 (DS): 0.9019
# Class 3 (DS): 0.9260
# Class 4 (DS): 0.8172
# Class 5 (DS): 0.8520
# Class 6 (DS): 0.9190
# Class 7 (DS): 0.9207
# Class 8 (DS): 0.9205
# Class 9 (DS): 0.9074
# Class 10 (DS): 0.8789
# Class 11 (DS): 0.7940
# Class 12 (DS): 0.8702
# Class 13 (DS): 0.9170
# Class 14 (DS): 0.9347
# Class 15 (DS): 0.9123
# Class 16 (DS): 0.9048
# Class 17 (DS): 0.9218
# Class 18 (DS): 0.9503
# Class 19 (DS): 0.8107
# Class 20 (DS): 0.8078
# Class 21 (DS): 0.6652
# Class 22 (DS): 0.8958
# Class 23 (DS): 0.9666
# Class 24 (DS): 0.8025
# Class 25 (DS): 0.7906
# Class 26 (DS): 0.9404
# Class 27 (DS): 0.9459
# Class 28 (DS): 0.9417
# Class 29 (DS): 0.9302
# Class 30 (DS): 0.8695
# Class 31 (DS): 0.9423
# Class 32 (DS): 0.9201
# Class 33 (DS): 0.9173
# Class 34 (DS): 0.9715
# Class 35 (DS): 0.6296
# Class 36 (DS): 0.9641
# Class 37 (DS): 0.7105
# Class 38 (DS): 0.8215
# Class 39 (DS): 0.9458
# Class 40 (DS): 0.9408
# Class 41 (DS): 0.9161
# Class 42 (DS): 0.8791
# Class 43 (DS): 0.8560
# Class 44 (DS): 0.9000
# ----------
# Epoch: 6, Phase: train, epoch loss: 49.2829, Av. Dice Score: 0.8938
# Class 0 (DS): 0.8055
# Class 1 (DS): 0.7047
# Class 2 (DS): 0.9165
# Class 3 (DS): 0.9189
# Class 4 (DS): 0.8736
# Class 5 (DS): 0.8574
# Class 6 (DS): 0.9348
# Class 7 (DS): 0.9240
# Class 8 (DS): 0.9354
# Class 9 (DS): 0.9036
# Class 10 (DS): 0.8967
# Class 11 (DS): 0.7961
# Class 12 (DS): 0.9003
# Class 13 (DS): 0.9193
# Class 14 (DS): 0.9417
# Class 15 (DS): 0.9082
# Class 16 (DS): 0.9342
# Class 17 (DS): 0.9330
# Class 18 (DS): 0.9712
# Class 19 (DS): 0.8121
# Class 20 (DS): 0.7730
# Class 21 (DS): 0.6986
# Class 22 (DS): 0.9339
# Class 23 (DS): 0.9455
# Class 24 (DS): 0.8819
# Class 25 (DS): 0.8615
# Class 26 (DS): 0.9477
# Class 27 (DS): 0.9428
# Class 28 (DS): 0.9403
# Class 29 (DS): 0.9365
# Class 30 (DS): 0.9051
# Class 31 (DS): 0.9432
# Class 32 (DS): 0.9453
# Class 33 (DS): 0.9398
# Class 34 (DS): 0.9737
# Class 35 (DS): 0.7961
# Class 36 (DS): 0.9409
# Class 37 (DS): 0.7395
# Class 38 (DS): 0.8892
# Class 39 (DS): 0.9441
# Class 40 (DS): 0.9531
# Class 41 (DS): 0.9331
# Class 42 (DS): 0.8776
# Class 43 (DS): 0.8798
# Class 44 (DS): 0.9129
# ----------
# Epoch: 6, Phase: validate, epoch loss: 44.5686, Av. Dice Score: 0.9056
# Class 0 (DS): 0.7836
# Class 1 (DS): 0.6704
# Class 2 (DS): 0.9462
# Class 3 (DS): 0.9213
# Class 4 (DS): 0.8945
# Class 5 (DS): 0.8789
# Class 6 (DS): 0.9342
# Class 7 (DS): 0.9472
# Class 8 (DS): 0.9451
# Class 9 (DS): 0.9153
# Class 10 (DS): 0.9291
# Class 11 (DS): 0.8542
# Class 12 (DS): 0.8991
# Class 13 (DS): 0.9074
# Class 14 (DS): 0.9165
# Class 15 (DS): 0.8918
# Class 16 (DS): 0.9409
# Class 17 (DS): 0.9387
# Class 18 (DS): 0.9767
# Class 19 (DS): 0.8371
# Class 20 (DS): 0.8534
# Class 21 (DS): 0.7713
# Class 22 (DS): 0.9446
# Class 23 (DS): 0.9226
# Class 24 (DS): 0.9044
# Class 25 (DS): 0.8810
# Class 26 (DS): 0.9302
# Class 27 (DS): 0.9425
# Class 28 (DS): 0.9531
# Class 29 (DS): 0.9286
# Class 30 (DS): 0.9313
# Class 31 (DS): 0.9545
# Class 32 (DS): 0.9271
# Class 33 (DS): 0.9219
# Class 34 (DS): 0.9850
# Class 35 (DS): 0.7860
# Class 36 (DS): 0.9784
# Class 37 (DS): 0.8077
# Class 38 (DS): 0.9247
# Class 39 (DS): 0.9516
# Class 40 (DS): 0.9595
# Class 41 (DS): 0.9426
# Class 42 (DS): 0.8829
# Class 43 (DS): 0.8969
# Class 44 (DS): 0.9409
# ----------
# Epoch: 7, Phase: train, epoch loss: 33.8211, Av. Dice Score: 0.9151
# Class 0 (DS): 0.8714
# Class 1 (DS): 0.7883
# Class 2 (DS): 0.9440
# Class 3 (DS): 0.9316
# Class 4 (DS): 0.8946
# Class 5 (DS): 0.8864
# Class 6 (DS): 0.9397
# Class 7 (DS): 0.9323
# Class 8 (DS): 0.9468
# Class 9 (DS): 0.9234
# Class 10 (DS): 0.9204
# Class 11 (DS): 0.8543
# Class 12 (DS): 0.9113
# Class 13 (DS): 0.9291
# Class 14 (DS): 0.9492
# Class 15 (DS): 0.9243
# Class 16 (DS): 0.9472
# Class 17 (DS): 0.9435
# Class 18 (DS): 0.9801
# Class 19 (DS): 0.8253
# Class 20 (DS): 0.8595
# Class 21 (DS): 0.7876
# Class 22 (DS): 0.9469
# Class 23 (DS): 0.9510
# Class 24 (DS): 0.8996
# Class 25 (DS): 0.8953
# Class 26 (DS): 0.9431
# Class 27 (DS): 0.9452
# Class 28 (DS): 0.9529
# Class 29 (DS): 0.9452
# Class 30 (DS): 0.9246
# Class 31 (DS): 0.9502
# Class 32 (DS): 0.9488
# Class 33 (DS): 0.9425
# Class 34 (DS): 0.9803
# Class 35 (DS): 0.8199
# Class 36 (DS): 0.9578
# Class 37 (DS): 0.7917
# Class 38 (DS): 0.9338
# Class 39 (DS): 0.9582
# Class 40 (DS): 0.9570
# Class 41 (DS): 0.9463
# Class 42 (DS): 0.8864
# Class 43 (DS): 0.8922
# Class 44 (DS): 0.9216
# ----------
# Epoch: 7, Phase: validate, epoch loss: 24.8852, Av. Dice Score: 0.9228
# Class 0 (DS): 0.8942
# Class 1 (DS): 0.8341
# Class 2 (DS): 0.9420
# Class 3 (DS): 0.9370
# Class 4 (DS): 0.9057
# Class 5 (DS): 0.8880
# Class 6 (DS): 0.9402
# Class 7 (DS): 0.9448
# Class 8 (DS): 0.9333
# Class 9 (DS): 0.9235
# Class 10 (DS): 0.9269
# Class 11 (DS): 0.8916
# Class 12 (DS): 0.9204
# Class 13 (DS): 0.9249
# Class 14 (DS): 0.9598
# Class 15 (DS): 0.9384
# Class 16 (DS): 0.9297
# Class 17 (DS): 0.9358
# Class 18 (DS): 0.9679
# Class 19 (DS): 0.8455
# Class 20 (DS): 0.9001
# Class 21 (DS): 0.8415
# Class 22 (DS): 0.9628
# Class 23 (DS): 0.9611
# Class 24 (DS): 0.9064
# Class 25 (DS): 0.9058
# Class 26 (DS): 0.9332
# Class 27 (DS): 0.9625
# Class 28 (DS): 0.9660
# Class 29 (DS): 0.9593
# Class 30 (DS): 0.9272
# Class 31 (DS): 0.9390
# Class 32 (DS): 0.9399
# Class 33 (DS): 0.9378
# Class 34 (DS): 0.9856
# Class 35 (DS): 0.8132
# Class 36 (DS): 0.9672
# Class 37 (DS): 0.8290
# Class 38 (DS): 0.9413
# Class 39 (DS): 0.9495
# Class 40 (DS): 0.9719
# Class 41 (DS): 0.9499
# Class 42 (DS): 0.9036
# Class 43 (DS): 0.8796
# Class 44 (DS): 0.9085
# ----------
# Epoch: 8, Phase: train, epoch loss: 24.4730, Av. Dice Score: 0.9194
# Class 0 (DS): 0.8752
# Class 1 (DS): 0.8069
# Class 2 (DS): 0.9487
# Class 3 (DS): 0.9249
# Class 4 (DS): 0.8965
# Class 5 (DS): 0.9020
# Class 6 (DS): 0.9431
# Class 7 (DS): 0.9347
# Class 8 (DS): 0.9433
# Class 9 (DS): 0.9282
# Class 10 (DS): 0.9230
# Class 11 (DS): 0.8914
# Class 12 (DS): 0.9206
# Class 13 (DS): 0.9277
# Class 14 (DS): 0.9540
# Class 15 (DS): 0.9312
# Class 16 (DS): 0.9480
# Class 17 (DS): 0.9408
# Class 18 (DS): 0.9787
# Class 19 (DS): 0.8281
# Class 20 (DS): 0.8737
# Class 21 (DS): 0.8123
# Class 22 (DS): 0.9521
# Class 23 (DS): 0.9460
# Class 24 (DS): 0.8989
# Class 25 (DS): 0.9050
# Class 26 (DS): 0.9521
# Class 27 (DS): 0.9494
# Class 28 (DS): 0.9524
# Class 29 (DS): 0.9408
# Class 30 (DS): 0.9210
# Class 31 (DS): 0.9549
# Class 32 (DS): 0.9505
# Class 33 (DS): 0.9404
# Class 34 (DS): 0.9775
# Class 35 (DS): 0.8275
# Class 36 (DS): 0.9596
# Class 37 (DS): 0.8023
# Class 38 (DS): 0.9324
# Class 39 (DS): 0.9611
# Class 40 (DS): 0.9600
# Class 41 (DS): 0.9532
# Class 42 (DS): 0.8844
# Class 43 (DS): 0.8914
# Class 44 (DS): 0.9273
# ----------
# Epoch: 8, Phase: validate, epoch loss: 22.7529, Av. Dice Score: 0.9229
# Class 0 (DS): 0.8933
# Class 1 (DS): 0.8437
# Class 2 (DS): 0.9509
# Class 3 (DS): 0.9441
# Class 4 (DS): 0.9024
# Class 5 (DS): 0.9040
# Class 6 (DS): 0.9381
# Class 7 (DS): 0.9425
# Class 8 (DS): 0.9343
# Class 9 (DS): 0.8981
# Class 10 (DS): 0.9461
# Class 11 (DS): 0.9273
# Class 12 (DS): 0.9156
# Class 13 (DS): 0.9424
# Class 14 (DS): 0.9532
# Class 15 (DS): 0.9488
# Class 16 (DS): 0.9131
# Class 17 (DS): 0.9365
# Class 18 (DS): 0.9692
# Class 19 (DS): 0.8512
# Class 20 (DS): 0.8879
# Class 21 (DS): 0.8506
# Class 22 (DS): 0.9641
# Class 23 (DS): 0.9612
# Class 24 (DS): 0.9140
# Class 25 (DS): 0.9236
# Class 26 (DS): 0.9479
# Class 27 (DS): 0.9503
# Class 28 (DS): 0.9392
# Class 29 (DS): 0.9291
# Class 30 (DS): 0.9246
# Class 31 (DS): 0.9400
# Class 32 (DS): 0.9432
# Class 33 (DS): 0.9457
# Class 34 (DS): 0.9825
# Class 35 (DS): 0.8321
# Class 36 (DS): 0.9702
# Class 37 (DS): 0.8124
# Class 38 (DS): 0.8819
# Class 39 (DS): 0.9662
# Class 40 (DS): 0.9575
# Class 41 (DS): 0.9362
# Class 42 (DS): 0.9007
# Class 43 (DS): 0.8949
# Class 44 (DS): 0.9201
# ----------
# Epoch: 9, Phase: train, epoch loss: 21.4572, Av. Dice Score: 0.9232
# Class 0 (DS): 0.8936
# Class 1 (DS): 0.8336
# Class 2 (DS): 0.9473
# Class 3 (DS): 0.9296
# Class 4 (DS): 0.8999
# Class 5 (DS): 0.9044
# Class 6 (DS): 0.9484
# Class 7 (DS): 0.9419
# Class 8 (DS): 0.9460
# Class 9 (DS): 0.9246
# Class 10 (DS): 0.9325
# Class 11 (DS): 0.8862
# Class 12 (DS): 0.9273
# Class 13 (DS): 0.9343
# Class 14 (DS): 0.9557
# Class 15 (DS): 0.9374
# Class 16 (DS): 0.9487
# Class 17 (DS): 0.9457
# Class 18 (DS): 0.9784
# Class 19 (DS): 0.8323
# Class 20 (DS): 0.8913
# Class 21 (DS): 0.8311
# Class 22 (DS): 0.9550
# Class 23 (DS): 0.9510
# Class 24 (DS): 0.9027
# Class 25 (DS): 0.9081
# Class 26 (DS): 0.9500
# Class 27 (DS): 0.9476
# Class 28 (DS): 0.9474
# Class 29 (DS): 0.9472
# Class 30 (DS): 0.9278
# Class 31 (DS): 0.9559
# Class 32 (DS): 0.9467
# Class 33 (DS): 0.9444
# Class 34 (DS): 0.9804
# Class 35 (DS): 0.8315
# Class 36 (DS): 0.9598
# Class 37 (DS): 0.8019
# Class 38 (DS): 0.9285
# Class 39 (DS): 0.9603
# Class 40 (DS): 0.9625
# Class 41 (DS): 0.9524
# Class 42 (DS): 0.8889
# Class 43 (DS): 0.8946
# Class 44 (DS): 0.9298
# ----------
# Epoch: 9, Phase: validate, epoch loss: 18.6565, Av. Dice Score: 0.9304
# Class 0 (DS): 0.9090
# Class 1 (DS): 0.8664
# Class 2 (DS): 0.9566
# Class 3 (DS): 0.9312
# Class 4 (DS): 0.9067
# Class 5 (DS): 0.9260
# Class 6 (DS): 0.9557
# Class 7 (DS): 0.9601
# Class 8 (DS): 0.9580
# Class 9 (DS): 0.9324
# Class 10 (DS): 0.9442
# Class 11 (DS): 0.8791
# Class 12 (DS): 0.9165
# Class 13 (DS): 0.9350
# Class 14 (DS): 0.9694
# Class 15 (DS): 0.9336
# Class 16 (DS): 0.9433
# Class 17 (DS): 0.9476
# Class 18 (DS): 0.9792
# Class 19 (DS): 0.8465
# Class 20 (DS): 0.9056
# Class 21 (DS): 0.8262
# Class 22 (DS): 0.9696
# Class 23 (DS): 0.9661
# Class 24 (DS): 0.9053
# Class 25 (DS): 0.9207
# Class 26 (DS): 0.9500
# Class 27 (DS): 0.9510
# Class 28 (DS): 0.9662
# Class 29 (DS): 0.9514
# Class 30 (DS): 0.9457
# Class 31 (DS): 0.9633
# Class 32 (DS): 0.9428
# Class 33 (DS): 0.9480
# Class 34 (DS): 0.9854
# Class 35 (DS): 0.8389
# Class 36 (DS): 0.9532
# Class 37 (DS): 0.8276
# Class 38 (DS): 0.9303
# Class 39 (DS): 0.9692
# Class 40 (DS): 0.9694
# Class 41 (DS): 0.9522
# Class 42 (DS): 0.9103
# Class 43 (DS): 0.9031
# Class 44 (DS): 0.9224
# ----------
# Epoch: 10, Phase: train, epoch loss: 20.0148, Av. Dice Score: 0.9262
# Class 0 (DS): 0.8997
# Class 1 (DS): 0.8426
# Class 2 (DS): 0.9489
# Class 3 (DS): 0.9318
# Class 4 (DS): 0.9009
# Class 5 (DS): 0.9095
# Class 6 (DS): 0.9493
# Class 7 (DS): 0.9433
# Class 8 (DS): 0.9512
# Class 9 (DS): 0.9316
# Class 10 (DS): 0.9416
# Class 11 (DS): 0.8936
# Class 12 (DS): 0.9257
# Class 13 (DS): 0.9296
# Class 14 (DS): 0.9575
# Class 15 (DS): 0.9354
# Class 16 (DS): 0.9541
# Class 17 (DS): 0.9479
# Class 18 (DS): 0.9799
# Class 19 (DS): 0.8391
# Class 20 (DS): 0.8954
# Class 21 (DS): 0.8463
# Class 22 (DS): 0.9577
# Class 23 (DS): 0.9510
# Class 24 (DS): 0.9013
# Class 25 (DS): 0.9173
# Class 26 (DS): 0.9537
# Class 27 (DS): 0.9495
# Class 28 (DS): 0.9514
# Class 29 (DS): 0.9463
# Class 30 (DS): 0.9292
# Class 31 (DS): 0.9598
# Class 32 (DS): 0.9554
# Class 33 (DS): 0.9464
# Class 34 (DS): 0.9797
# Class 35 (DS): 0.8285
# Class 36 (DS): 0.9600
# Class 37 (DS): 0.8084
# Class 38 (DS): 0.9377
# Class 39 (DS): 0.9602
# Class 40 (DS): 0.9624
# Class 41 (DS): 0.9532
# Class 42 (DS): 0.8902
# Class 43 (DS): 0.8973
# Class 44 (DS): 0.9279
# ----------
# Epoch: 10, Phase: validate, epoch loss: 22.4147, Av. Dice Score: 0.9236
# Class 0 (DS): 0.8929
# Class 1 (DS): 0.8144
# Class 2 (DS): 0.9381
# Class 3 (DS): 0.9226
# Class 4 (DS): 0.8926
# Class 5 (DS): 0.9129
# Class 6 (DS): 0.9447
# Class 7 (DS): 0.9508
# Class 8 (DS): 0.9404
# Class 9 (DS): 0.9141
# Class 10 (DS): 0.9579
# Class 11 (DS): 0.8980
# Class 12 (DS): 0.9065
# Class 13 (DS): 0.9456
# Class 14 (DS): 0.9400
# Class 15 (DS): 0.9425
# Class 16 (DS): 0.9335
# Class 17 (DS): 0.9389
# Class 18 (DS): 0.9642
# Class 19 (DS): 0.8543
# Class 20 (DS): 0.8905
# Class 21 (DS): 0.8277
# Class 22 (DS): 0.9665
# Class 23 (DS): 0.9648
# Class 24 (DS): 0.9142
# Class 25 (DS): 0.9219
# Class 26 (DS): 0.9555
# Class 27 (DS): 0.9503
# Class 28 (DS): 0.9436
# Class 29 (DS): 0.9425
# Class 30 (DS): 0.9415
# Class 31 (DS): 0.9541
# Class 32 (DS): 0.9354
# Class 33 (DS): 0.9482
# Class 34 (DS): 0.9792
# Class 35 (DS): 0.8084
# Class 36 (DS): 0.9621
# Class 37 (DS): 0.8231
# Class 38 (DS): 0.9142
# Class 39 (DS): 0.9641
# Class 40 (DS): 0.9646
# Class 41 (DS): 0.9453
# Class 42 (DS): 0.9095
# Class 43 (DS): 0.9108
# Class 44 (DS): 0.9188
# ----------
# Epoch: 11, Phase: train, epoch loss: 19.4188, Av. Dice Score: 0.9265
# Class 0 (DS): 0.9001
# Class 1 (DS): 0.8442
# Class 2 (DS): 0.9513
# Class 3 (DS): 0.9338
# Class 4 (DS): 0.9033
# Class 5 (DS): 0.9096
# Class 6 (DS): 0.9493
# Class 7 (DS): 0.9369
# Class 8 (DS): 0.9493
# Class 9 (DS): 0.9320
# Class 10 (DS): 0.9376
# Class 11 (DS): 0.8951
# Class 12 (DS): 0.9302
# Class 13 (DS): 0.9309
# Class 14 (DS): 0.9583
# Class 15 (DS): 0.9389
# Class 16 (DS): 0.9510
# Class 17 (DS): 0.9456
# Class 18 (DS): 0.9766
# Class 19 (DS): 0.8363
# Class 20 (DS): 0.8959
# Class 21 (DS): 0.8470
# Class 22 (DS): 0.9582
# Class 23 (DS): 0.9550
# Class 24 (DS): 0.9064
# Class 25 (DS): 0.9137
# Class 26 (DS): 0.9522
# Class 27 (DS): 0.9484
# Class 28 (DS): 0.9572
# Class 29 (DS): 0.9465
# Class 30 (DS): 0.9286
# Class 31 (DS): 0.9585
# Class 32 (DS): 0.9543
# Class 33 (DS): 0.9426
# Class 34 (DS): 0.9787
# Class 35 (DS): 0.8329
# Class 36 (DS): 0.9596
# Class 37 (DS): 0.8079
# Class 38 (DS): 0.9258
# Class 39 (DS): 0.9662
# Class 40 (DS): 0.9626
# Class 41 (DS): 0.9546
# Class 42 (DS): 0.8938
# Class 43 (DS): 0.9032
# Class 44 (DS): 0.9311
# ----------
# Epoch: 11, Phase: validate, epoch loss: 20.0991, Av. Dice Score: 0.9277
# Class 0 (DS): 0.8955
# Class 1 (DS): 0.8671
# Class 2 (DS): 0.9477
# Class 3 (DS): 0.9342
# Class 4 (DS): 0.8923
# Class 5 (DS): 0.9129
# Class 6 (DS): 0.9572
# Class 7 (DS): 0.9468
# Class 8 (DS): 0.9388
# Class 9 (DS): 0.9395
# Class 10 (DS): 0.9475
# Class 11 (DS): 0.9291
# Class 12 (DS): 0.9212
# Class 13 (DS): 0.9308
# Class 14 (DS): 0.9573
# Class 15 (DS): 0.9193
# Class 16 (DS): 0.9379
# Class 17 (DS): 0.9380
# Class 18 (DS): 0.9805
# Class 19 (DS): 0.8402
# Class 20 (DS): 0.9112
# Class 21 (DS): 0.8614
# Class 22 (DS): 0.9597
# Class 23 (DS): 0.9670
# Class 24 (DS): 0.8818
# Class 25 (DS): 0.9201
# Class 26 (DS): 0.9620
# Class 27 (DS): 0.9560
# Class 28 (DS): 0.9515
# Class 29 (DS): 0.9565
# Class 30 (DS): 0.9451
# Class 31 (DS): 0.9613
# Class 32 (DS): 0.9370
# Class 33 (DS): 0.9408
# Class 34 (DS): 0.9904
# Class 35 (DS): 0.8302
# Class 36 (DS): 0.9671
# Class 37 (DS): 0.7950
# Class 38 (DS): 0.9119
# Class 39 (DS): 0.9702
# Class 40 (DS): 0.9622
# Class 41 (DS): 0.9493
# Class 42 (DS): 0.9053
# Class 43 (DS): 0.8964
# Class 44 (DS): 0.9229
# ----------
# Epoch: 12, Phase: train, epoch loss: 18.8724, Av. Dice Score: 0.9278
# Class 0 (DS): 0.9027
# Class 1 (DS): 0.8459
# Class 2 (DS): 0.9526
# Class 3 (DS): 0.9340
# Class 4 (DS): 0.8970
# Class 5 (DS): 0.9070
# Class 6 (DS): 0.9519
# Class 7 (DS): 0.9432
# Class 8 (DS): 0.9481
# Class 9 (DS): 0.9366
# Class 10 (DS): 0.9416
# Class 11 (DS): 0.8994
# Class 12 (DS): 0.9305
# Class 13 (DS): 0.9375
# Class 14 (DS): 0.9634
# Class 15 (DS): 0.9369
# Class 16 (DS): 0.9496
# Class 17 (DS): 0.9491
# Class 18 (DS): 0.9805
# Class 19 (DS): 0.8436
# Class 20 (DS): 0.8968
# Class 21 (DS): 0.8474
# Class 22 (DS): 0.9568
# Class 23 (DS): 0.9516
# Class 24 (DS): 0.9043
# Class 25 (DS): 0.9139
# Class 26 (DS): 0.9582
# Class 27 (DS): 0.9512
# Class 28 (DS): 0.9564
# Class 29 (DS): 0.9462
# Class 30 (DS): 0.9312
# Class 31 (DS): 0.9594
# Class 32 (DS): 0.9565
# Class 33 (DS): 0.9502
# Class 34 (DS): 0.9815
# Class 35 (DS): 0.8374
# Class 36 (DS): 0.9667
# Class 37 (DS): 0.8011
# Class 38 (DS): 0.9211
# Class 39 (DS): 0.9646
# Class 40 (DS): 0.9635
# Class 41 (DS): 0.9526
# Class 42 (DS): 0.8951
# Class 43 (DS): 0.9013
# Class 44 (DS): 0.9356
# ----------
# Epoch: 12, Phase: validate, epoch loss: 19.5706, Av. Dice Score: 0.9277
# Class 0 (DS): 0.9019
# Class 1 (DS): 0.8416
# Class 2 (DS): 0.9489
# Class 3 (DS): 0.9270
# Class 4 (DS): 0.8907
# Class 5 (DS): 0.9012
# Class 6 (DS): 0.9520
# Class 7 (DS): 0.9505
# Class 8 (DS): 0.9601
# Class 9 (DS): 0.9428
# Class 10 (DS): 0.9472
# Class 11 (DS): 0.8945
# Class 12 (DS): 0.9320
# Class 13 (DS): 0.9404
# Class 14 (DS): 0.9637
# Class 15 (DS): 0.9518
# Class 16 (DS): 0.9435
# Class 17 (DS): 0.9368
# Class 18 (DS): 0.9764
# Class 19 (DS): 0.8439
# Class 20 (DS): 0.8978
# Class 21 (DS): 0.8454
# Class 22 (DS): 0.9682
# Class 23 (DS): 0.9656
# Class 24 (DS): 0.9017
# Class 25 (DS): 0.9139
# Class 26 (DS): 0.9597
# Class 27 (DS): 0.9555
# Class 28 (DS): 0.9591
# Class 29 (DS): 0.9498
# Class 30 (DS): 0.9488
# Class 31 (DS): 0.9552
# Class 32 (DS): 0.9453
# Class 33 (DS): 0.9469
# Class 34 (DS): 0.9823
# Class 35 (DS): 0.8386
# Class 36 (DS): 0.9804
# Class 37 (DS): 0.8122
# Class 38 (DS): 0.9415
# Class 39 (DS): 0.9621
# Class 40 (DS): 0.9480
# Class 41 (DS): 0.9386
# Class 42 (DS): 0.8800
# Class 43 (DS): 0.8802
# Class 44 (DS): 0.9248
# ----------
# Epoch: 13, Phase: train, epoch loss: 18.1804, Av. Dice Score: 0.9290
# Class 0 (DS): 0.9040
# Class 1 (DS): 0.8528
# Class 2 (DS): 0.9520
# Class 3 (DS): 0.9403
# Class 4 (DS): 0.9047
# Class 5 (DS): 0.9155
# Class 6 (DS): 0.9519
# Class 7 (DS): 0.9461
# Class 8 (DS): 0.9522
# Class 9 (DS): 0.9305
# Class 10 (DS): 0.9468
# Class 11 (DS): 0.8976
# Class 12 (DS): 0.9291
# Class 13 (DS): 0.9379
# Class 14 (DS): 0.9627
# Class 15 (DS): 0.9389
# Class 16 (DS): 0.9543
# Class 17 (DS): 0.9495
# Class 18 (DS): 0.9804
# Class 19 (DS): 0.8408
# Class 20 (DS): 0.9015
# Class 21 (DS): 0.8575
# Class 22 (DS): 0.9604
# Class 23 (DS): 0.9574
# Class 24 (DS): 0.9066
# Class 25 (DS): 0.9100
# Class 26 (DS): 0.9572
# Class 27 (DS): 0.9538
# Class 28 (DS): 0.9550
# Class 29 (DS): 0.9450
# Class 30 (DS): 0.9317
# Class 31 (DS): 0.9589
# Class 32 (DS): 0.9546
# Class 33 (DS): 0.9521
# Class 34 (DS): 0.9796
# Class 35 (DS): 0.8347
# Class 36 (DS): 0.9626
# Class 37 (DS): 0.8030
# Class 38 (DS): 0.9285
# Class 39 (DS): 0.9656
# Class 40 (DS): 0.9660
# Class 41 (DS): 0.9552
# Class 42 (DS): 0.8911
# Class 43 (DS): 0.8965
# Class 44 (DS): 0.9338
# ----------
# Epoch: 13, Phase: validate, epoch loss: 18.9974, Av. Dice Score: 0.9271
# Class 0 (DS): 0.8692
# Class 1 (DS): 0.8543
# Class 2 (DS): 0.9581
# Class 3 (DS): 0.9237
# Class 4 (DS): 0.9039
# Class 5 (DS): 0.9212
# Class 6 (DS): 0.9516
# Class 7 (DS): 0.9654
# Class 8 (DS): 0.9581
# Class 9 (DS): 0.9336
# Class 10 (DS): 0.9497
# Class 11 (DS): 0.8722
# Class 12 (DS): 0.9198
# Class 13 (DS): 0.9214
# Class 14 (DS): 0.9453
# Class 15 (DS): 0.9393
# Class 16 (DS): 0.9510
# Class 17 (DS): 0.9204
# Class 18 (DS): 0.9783
# Class 19 (DS): 0.8465
# Class 20 (DS): 0.9075
# Class 21 (DS): 0.8705
# Class 22 (DS): 0.9745
# Class 23 (DS): 0.9553
# Class 24 (DS): 0.9156
# Class 25 (DS): 0.9159
# Class 26 (DS): 0.9574
# Class 27 (DS): 0.9558
# Class 28 (DS): 0.9581
# Class 29 (DS): 0.9575
# Class 30 (DS): 0.9275
# Class 31 (DS): 0.9250
# Class 32 (DS): 0.9474
# Class 33 (DS): 0.9321
# Class 34 (DS): 0.9799
# Class 35 (DS): 0.8357
# Class 36 (DS): 0.9816
# Class 37 (DS): 0.8377
# Class 38 (DS): 0.9114
# Class 39 (DS): 0.9449
# Class 40 (DS): 0.9696
# Class 41 (DS): 0.9505
# Class 42 (DS): 0.8940
# Class 43 (DS): 0.8966
# Class 44 (DS): 0.9328
# ----------
# Epoch: 14, Phase: train, epoch loss: 17.5650, Av. Dice Score: 0.9307
# Class 0 (DS): 0.9049
# Class 1 (DS): 0.8610
# Class 2 (DS): 0.9554
# Class 3 (DS): 0.9376
# Class 4 (DS): 0.9035
# Class 5 (DS): 0.9173
# Class 6 (DS): 0.9542
# Class 7 (DS): 0.9464
# Class 8 (DS): 0.9552
# Class 9 (DS): 0.9332
# Class 10 (DS): 0.9454
# Class 11 (DS): 0.9060
# Class 12 (DS): 0.9302
# Class 13 (DS): 0.9399
# Class 14 (DS): 0.9629
# Class 15 (DS): 0.9411
# Class 16 (DS): 0.9541
# Class 17 (DS): 0.9495
# Class 18 (DS): 0.9789
# Class 19 (DS): 0.8419
# Class 20 (DS): 0.9044
# Class 21 (DS): 0.8675
# Class 22 (DS): 0.9598
# Class 23 (DS): 0.9625
# Class 24 (DS): 0.9094
# Class 25 (DS): 0.9178
# Class 26 (DS): 0.9572
# Class 27 (DS): 0.9511
# Class 28 (DS): 0.9577
# Class 29 (DS): 0.9467
# Class 30 (DS): 0.9322
# Class 31 (DS): 0.9626
# Class 32 (DS): 0.9550
# Class 33 (DS): 0.9495
# Class 34 (DS): 0.9814
# Class 35 (DS): 0.8392
# Class 36 (DS): 0.9652
# Class 37 (DS): 0.7997
# Class 38 (DS): 0.9259
# Class 39 (DS): 0.9673
# Class 40 (DS): 0.9639
# Class 41 (DS): 0.9557
# Class 42 (DS): 0.8962
# Class 43 (DS): 0.9016
# Class 44 (DS): 0.9352
# ----------
# Epoch: 14, Phase: validate, epoch loss: 17.5494, Av. Dice Score: 0.9325
# Class 0 (DS): 0.9044
# Class 1 (DS): 0.8826
# Class 2 (DS): 0.9518
# Class 3 (DS): 0.9401
# Class 4 (DS): 0.9039
# Class 5 (DS): 0.9315
# Class 6 (DS): 0.9545
# Class 7 (DS): 0.9522
# Class 8 (DS): 0.9549
# Class 9 (DS): 0.9436
# Class 10 (DS): 0.9616
# Class 11 (DS): 0.8969
# Class 12 (DS): 0.9297
# Class 13 (DS): 0.9329
# Class 14 (DS): 0.9522
# Class 15 (DS): 0.9330
# Class 16 (DS): 0.9485
# Class 17 (DS): 0.9486
# Class 18 (DS): 0.9793
# Class 19 (DS): 0.8481
# Class 20 (DS): 0.9182
# Class 21 (DS): 0.8738
# Class 22 (DS): 0.9687
# Class 23 (DS): 0.9696
# Class 24 (DS): 0.9153
# Class 25 (DS): 0.9321
# Class 26 (DS): 0.9611
# Class 27 (DS): 0.9463
# Class 28 (DS): 0.9561
# Class 29 (DS): 0.9521
# Class 30 (DS): 0.9467
# Class 31 (DS): 0.9581
# Class 32 (DS): 0.9341
# Class 33 (DS): 0.9415
# Class 34 (DS): 0.9805
# Class 35 (DS): 0.8309
# Class 36 (DS): 0.9686
# Class 37 (DS): 0.8229
# Class 38 (DS): 0.9251
# Class 39 (DS): 0.9667
# Class 40 (DS): 0.9646
# Class 41 (DS): 0.9558
# Class 42 (DS): 0.9127
# Class 43 (DS): 0.8897
# Class 44 (DS): 0.9201
# ----------
# Epoch: 15, Phase: train, epoch loss: 17.2861, Av. Dice Score: 0.9316
# Class 0 (DS): 0.9134
# Class 1 (DS): 0.8650
# Class 2 (DS): 0.9543
# Class 3 (DS): 0.9393
# Class 4 (DS): 0.9086
# Class 5 (DS): 0.9174
# Class 6 (DS): 0.9529
# Class 7 (DS): 0.9474
# Class 8 (DS): 0.9546
# Class 9 (DS): 0.9348
# Class 10 (DS): 0.9452
# Class 11 (DS): 0.9072
# Class 12 (DS): 0.9307
# Class 13 (DS): 0.9378
# Class 14 (DS): 0.9613
# Class 15 (DS): 0.9422
# Class 16 (DS): 0.9546
# Class 17 (DS): 0.9525
# Class 18 (DS): 0.9791
# Class 19 (DS): 0.8449
# Class 20 (DS): 0.9015
# Class 21 (DS): 0.8646
# Class 22 (DS): 0.9620
# Class 23 (DS): 0.9563
# Class 24 (DS): 0.9140
# Class 25 (DS): 0.9196
# Class 26 (DS): 0.9595
# Class 27 (DS): 0.9524
# Class 28 (DS): 0.9589
# Class 29 (DS): 0.9442
# Class 30 (DS): 0.9290
# Class 31 (DS): 0.9605
# Class 32 (DS): 0.9541
# Class 33 (DS): 0.9477
# Class 34 (DS): 0.9799
# Class 35 (DS): 0.8388
# Class 36 (DS): 0.9626
# Class 37 (DS): 0.8141
# Class 38 (DS): 0.9252
# Class 39 (DS): 0.9640
# Class 40 (DS): 0.9675
# Class 41 (DS): 0.9593
# Class 42 (DS): 0.8954
# Class 43 (DS): 0.9065
# Class 44 (DS): 0.9391
# ----------
# Epoch: 15, Phase: validate, epoch loss: 18.6477, Av. Dice Score: 0.9278
# Class 0 (DS): 0.9017
# Class 1 (DS): 0.8469
# Class 2 (DS): 0.9329
# Class 3 (DS): 0.9344
# Class 4 (DS): 0.8919
# Class 5 (DS): 0.9001
# Class 6 (DS): 0.9524
# Class 7 (DS): 0.9529
# Class 8 (DS): 0.9626
# Class 9 (DS): 0.9406
# Class 10 (DS): 0.9613
# Class 11 (DS): 0.9086
# Class 12 (DS): 0.9184
# Class 13 (DS): 0.9460
# Class 14 (DS): 0.9671
# Class 15 (DS): 0.9494
# Class 16 (DS): 0.9457
# Class 17 (DS): 0.9426
# Class 18 (DS): 0.9753
# Class 19 (DS): 0.8473
# Class 20 (DS): 0.9122
# Class 21 (DS): 0.8505
# Class 22 (DS): 0.9476
# Class 23 (DS): 0.9650
# Class 24 (DS): 0.9098
# Class 25 (DS): 0.9092
# Class 26 (DS): 0.9573
# Class 27 (DS): 0.9450
# Class 28 (DS): 0.9564
# Class 29 (DS): 0.9496
# Class 30 (DS): 0.9491
# Class 31 (DS): 0.9525
# Class 32 (DS): 0.9343
# Class 33 (DS): 0.9426
# Class 34 (DS): 0.9752
# Class 35 (DS): 0.8090
# Class 36 (DS): 0.9816
# Class 37 (DS): 0.8243
# Class 38 (DS): 0.9449
# Class 39 (DS): 0.9675
# Class 40 (DS): 0.9587
# Class 41 (DS): 0.9532
# Class 42 (DS): 0.8968
# Class 43 (DS): 0.8805
# Class 44 (DS): 0.8985
# ----------
# Epoch: 16, Phase: train, epoch loss: 17.2481, Av. Dice Score: 0.9303
# Class 0 (DS): 0.9051
# Class 1 (DS): 0.8550
# Class 2 (DS): 0.9548
# Class 3 (DS): 0.9401
# Class 4 (DS): 0.9051
# Class 5 (DS): 0.9213
# Class 6 (DS): 0.9521
# Class 7 (DS): 0.9465
# Class 8 (DS): 0.9507
# Class 9 (DS): 0.9315
# Class 10 (DS): 0.9442
# Class 11 (DS): 0.9038
# Class 12 (DS): 0.9320
# Class 13 (DS): 0.9376
# Class 14 (DS): 0.9609
# Class 15 (DS): 0.9390
# Class 16 (DS): 0.9543
# Class 17 (DS): 0.9506
# Class 18 (DS): 0.9797
# Class 19 (DS): 0.8389
# Class 20 (DS): 0.9047
# Class 21 (DS): 0.8665
# Class 22 (DS): 0.9597
# Class 23 (DS): 0.9615
# Class 24 (DS): 0.9099
# Class 25 (DS): 0.9224
# Class 26 (DS): 0.9575
# Class 27 (DS): 0.9520
# Class 28 (DS): 0.9586
# Class 29 (DS): 0.9417
# Class 30 (DS): 0.9312
# Class 31 (DS): 0.9625
# Class 32 (DS): 0.9528
# Class 33 (DS): 0.9524
# Class 34 (DS): 0.9803
# Class 35 (DS): 0.8373
# Class 36 (DS): 0.9645
# Class 37 (DS): 0.8117
# Class 38 (DS): 0.9220
# Class 39 (DS): 0.9656
# Class 40 (DS): 0.9651
# Class 41 (DS): 0.9559
# Class 42 (DS): 0.8885
# Class 43 (DS): 0.9020
# Class 44 (DS): 0.9346
# ----------
# Epoch: 16, Phase: validate, epoch loss: 18.3870, Av. Dice Score: 0.9272
# Class 0 (DS): 0.9062
# Class 1 (DS): 0.8568
# Class 2 (DS): 0.9478
# Class 3 (DS): 0.9258
# Class 4 (DS): 0.9047
# Class 5 (DS): 0.9234
# Class 6 (DS): 0.9394
# Class 7 (DS): 0.9632
# Class 8 (DS): 0.9628
# Class 9 (DS): 0.9351
# Class 10 (DS): 0.9426
# Class 11 (DS): 0.9187
# Class 12 (DS): 0.9310
# Class 13 (DS): 0.9358
# Class 14 (DS): 0.9524
# Class 15 (DS): 0.9254
# Class 16 (DS): 0.9526
# Class 17 (DS): 0.9413
# Class 18 (DS): 0.9748
# Class 19 (DS): 0.8363
# Class 20 (DS): 0.8881
# Class 21 (DS): 0.8241
# Class 22 (DS): 0.9632
# Class 23 (DS): 0.9688
# Class 24 (DS): 0.9104
# Class 25 (DS): 0.9248
# Class 26 (DS): 0.9601
# Class 27 (DS): 0.9518
# Class 28 (DS): 0.9567
# Class 29 (DS): 0.9517
# Class 30 (DS): 0.9464
# Class 31 (DS): 0.9575
# Class 32 (DS): 0.9344
# Class 33 (DS): 0.9417
# Class 34 (DS): 0.9805
# Class 35 (DS): 0.8149
# Class 36 (DS): 0.9735
# Class 37 (DS): 0.7762
# Class 38 (DS): 0.9393
# Class 39 (DS): 0.9569
# Class 40 (DS): 0.9664
# Class 41 (DS): 0.9569
# Class 42 (DS): 0.8749
# Class 43 (DS): 0.8873
# Class 44 (DS): 0.9429
# ----------
# Epoch: 17, Phase: train, epoch loss: 16.7734, Av. Dice Score: 0.9322
# Class 0 (DS): 0.9114
# Class 1 (DS): 0.8631
# Class 2 (DS): 0.9573
# Class 3 (DS): 0.9425
# Class 4 (DS): 0.9091
# Class 5 (DS): 0.9205
# Class 6 (DS): 0.9569
# Class 7 (DS): 0.9445
# Class 8 (DS): 0.9540
# Class 9 (DS): 0.9327
# Class 10 (DS): 0.9493
# Class 11 (DS): 0.9102
# Class 12 (DS): 0.9368
# Class 13 (DS): 0.9385
# Class 14 (DS): 0.9656
# Class 15 (DS): 0.9387
# Class 16 (DS): 0.9565
# Class 17 (DS): 0.9540
# Class 18 (DS): 0.9810
# Class 19 (DS): 0.8479
# Class 20 (DS): 0.9115
# Class 21 (DS): 0.8657
# Class 22 (DS): 0.9618
# Class 23 (DS): 0.9571
# Class 24 (DS): 0.9123
# Class 25 (DS): 0.9234
# Class 26 (DS): 0.9580
# Class 27 (DS): 0.9522
# Class 28 (DS): 0.9548
# Class 29 (DS): 0.9468
# Class 30 (DS): 0.9273
# Class 31 (DS): 0.9619
# Class 32 (DS): 0.9547
# Class 33 (DS): 0.9505
# Class 34 (DS): 0.9784
# Class 35 (DS): 0.8422
# Class 36 (DS): 0.9673
# Class 37 (DS): 0.8105
# Class 38 (DS): 0.9246
# Class 39 (DS): 0.9635
# Class 40 (DS): 0.9665
# Class 41 (DS): 0.9594
# Class 42 (DS): 0.8930
# Class 43 (DS): 0.9018
# Class 44 (DS): 0.9344
# ----------
# Epoch: 17, Phase: validate, epoch loss: 18.5517, Av. Dice Score: 0.9290
# Class 0 (DS): 0.8992
# Class 1 (DS): 0.8771
# Class 2 (DS): 0.9631
# Class 3 (DS): 0.9350
# Class 4 (DS): 0.9045
# Class 5 (DS): 0.9223
# Class 6 (DS): 0.9541
# Class 7 (DS): 0.9547
# Class 8 (DS): 0.9569
# Class 9 (DS): 0.9438
# Class 10 (DS): 0.9636
# Class 11 (DS): 0.9129
# Class 12 (DS): 0.9241
# Class 13 (DS): 0.9181
# Class 14 (DS): 0.9370
# Class 15 (DS): 0.9488
# Class 16 (DS): 0.9462
# Class 17 (DS): 0.9362
# Class 18 (DS): 0.9774
# Class 19 (DS): 0.8532
# Class 20 (DS): 0.8969
# Class 21 (DS): 0.8541
# Class 22 (DS): 0.9677
# Class 23 (DS): 0.9730
# Class 24 (DS): 0.9045
# Class 25 (DS): 0.9232
# Class 26 (DS): 0.9567
# Class 27 (DS): 0.9543
# Class 28 (DS): 0.9707
# Class 29 (DS): 0.9527
# Class 30 (DS): 0.9087
# Class 31 (DS): 0.9416
# Class 32 (DS): 0.9389
# Class 33 (DS): 0.9333
# Class 34 (DS): 0.9855
# Class 35 (DS): 0.8409
# Class 36 (DS): 0.9645
# Class 37 (DS): 0.8114
# Class 38 (DS): 0.9288
# Class 39 (DS): 0.9560
# Class 40 (DS): 0.9632
# Class 41 (DS): 0.9540
# Class 42 (DS): 0.8976
# Class 43 (DS): 0.8751
# Class 44 (DS): 0.9235
# ----------
# Epoch: 18, Phase: train, epoch loss: 16.6002, Av. Dice Score: 0.9316
# Class 0 (DS): 0.9023
# Class 1 (DS): 0.8576
# Class 2 (DS): 0.9537
# Class 3 (DS): 0.9421
# Class 4 (DS): 0.9052
# Class 5 (DS): 0.9120
# Class 6 (DS): 0.9554
# Class 7 (DS): 0.9457
# Class 8 (DS): 0.9524
# Class 9 (DS): 0.9360
# Class 10 (DS): 0.9500
# Class 11 (DS): 0.9075
# Class 12 (DS): 0.9304
# Class 13 (DS): 0.9414
# Class 14 (DS): 0.9667
# Class 15 (DS): 0.9423
# Class 16 (DS): 0.9566
# Class 17 (DS): 0.9479
# Class 18 (DS): 0.9806
# Class 19 (DS): 0.8519
# Class 20 (DS): 0.8996
# Class 21 (DS): 0.8628
# Class 22 (DS): 0.9624
# Class 23 (DS): 0.9590
# Class 24 (DS): 0.9096
# Class 25 (DS): 0.9118
# Class 26 (DS): 0.9609
# Class 27 (DS): 0.9516
# Class 28 (DS): 0.9573
# Class 29 (DS): 0.9472
# Class 30 (DS): 0.9335
# Class 31 (DS): 0.9641
# Class 32 (DS): 0.9571
# Class 33 (DS): 0.9516
# Class 34 (DS): 0.9787
# Class 35 (DS): 0.8377
# Class 36 (DS): 0.9648
# Class 37 (DS): 0.8114
# Class 38 (DS): 0.9193
# Class 39 (DS): 0.9671
# Class 40 (DS): 0.9669
# Class 41 (DS): 0.9590
# Class 42 (DS): 0.8980
# Class 43 (DS): 0.9140
# Class 44 (DS): 0.9378
# ----------
# Epoch: 18, Phase: validate, epoch loss: 16.9706, Av. Dice Score: 0.9337
# Class 0 (DS): 0.9085
# Class 1 (DS): 0.8757
# Class 2 (DS): 0.9507
# Class 3 (DS): 0.9356
# Class 4 (DS): 0.9122
# Class 5 (DS): 0.9204
# Class 6 (DS): 0.9520
# Class 7 (DS): 0.9564
# Class 8 (DS): 0.9479
# Class 9 (DS): 0.9404
# Class 10 (DS): 0.9589
# Class 11 (DS): 0.9076
# Class 12 (DS): 0.9304
# Class 13 (DS): 0.9350
# Class 14 (DS): 0.9546
# Class 15 (DS): 0.9379
# Class 16 (DS): 0.9460
# Class 17 (DS): 0.9417
# Class 18 (DS): 0.9765
# Class 19 (DS): 0.8484
# Class 20 (DS): 0.9215
# Class 21 (DS): 0.8702
# Class 22 (DS): 0.9713
# Class 23 (DS): 0.9602
# Class 24 (DS): 0.9178
# Class 25 (DS): 0.9259
# Class 26 (DS): 0.9598
# Class 27 (DS): 0.9489
# Class 28 (DS): 0.9658
# Class 29 (DS): 0.9506
# Class 30 (DS): 0.9440
# Class 31 (DS): 0.9466
# Class 32 (DS): 0.9348
# Class 33 (DS): 0.9459
# Class 34 (DS): 0.9777
# Class 35 (DS): 0.8439
# Class 36 (DS): 0.9839
# Class 37 (DS): 0.8050
# Class 38 (DS): 0.9357
# Class 39 (DS): 0.9591
# Class 40 (DS): 0.9743
# Class 41 (DS): 0.9604
# Class 42 (DS): 0.9195
# Class 43 (DS): 0.9256
# Class 44 (DS): 0.9312
# ----------
# Epoch: 19, Phase: train, epoch loss: 16.5814, Av. Dice Score: 0.9330
# Class 0 (DS): 0.9160
# Class 1 (DS): 0.8721
# Class 2 (DS): 0.9553
# Class 3 (DS): 0.9450
# Class 4 (DS): 0.9081
# Class 5 (DS): 0.9211
# Class 6 (DS): 0.9542
# Class 7 (DS): 0.9486
# Class 8 (DS): 0.9515
# Class 9 (DS): 0.9393
# Class 10 (DS): 0.9474
# Class 11 (DS): 0.9083
# Class 12 (DS): 0.9365
# Class 13 (DS): 0.9403
# Class 14 (DS): 0.9649
# Class 15 (DS): 0.9410
# Class 16 (DS): 0.9572
# Class 17 (DS): 0.9519
# Class 18 (DS): 0.9794
# Class 19 (DS): 0.8432
# Class 20 (DS): 0.9123
# Class 21 (DS): 0.8768
# Class 22 (DS): 0.9606
# Class 23 (DS): 0.9576
# Class 24 (DS): 0.9121
# Class 25 (DS): 0.9243
# Class 26 (DS): 0.9589
# Class 27 (DS): 0.9520
# Class 28 (DS): 0.9531
# Class 29 (DS): 0.9472
# Class 30 (DS): 0.9312
# Class 31 (DS): 0.9603
# Class 32 (DS): 0.9555
# Class 33 (DS): 0.9535
# Class 34 (DS): 0.9777
# Class 35 (DS): 0.8370
# Class 36 (DS): 0.9674
# Class 37 (DS): 0.8128
# Class 38 (DS): 0.9164
# Class 39 (DS): 0.9666
# Class 40 (DS): 0.9660
# Class 41 (DS): 0.9604
# Class 42 (DS): 0.8974
# Class 43 (DS): 0.9100
# Class 44 (DS): 0.9365
# ----------
# Epoch: 19, Phase: validate, epoch loss: 17.6525, Av. Dice Score: 0.9283
# Class 0 (DS): 0.9058
# Class 1 (DS): 0.8682
# Class 2 (DS): 0.9493
# Class 3 (DS): 0.9436
# Class 4 (DS): 0.9025
# Class 5 (DS): 0.8813
# Class 6 (DS): 0.9606
# Class 7 (DS): 0.9610
# Class 8 (DS): 0.9573
# Class 9 (DS): 0.9342
# Class 10 (DS): 0.9617
# Class 11 (DS): 0.8858
# Class 12 (DS): 0.9187
# Class 13 (DS): 0.9329
# Class 14 (DS): 0.9568
# Class 15 (DS): 0.9381
# Class 16 (DS): 0.9412
# Class 17 (DS): 0.9416
# Class 18 (DS): 0.9730
# Class 19 (DS): 0.8433
# Class 20 (DS): 0.9069
# Class 21 (DS): 0.8667
# Class 22 (DS): 0.9691
# Class 23 (DS): 0.9728
# Class 24 (DS): 0.9072
# Class 25 (DS): 0.8780
# Class 26 (DS): 0.9591
# Class 27 (DS): 0.9595
# Class 28 (DS): 0.9646
# Class 29 (DS): 0.9497
# Class 30 (DS): 0.9342
# Class 31 (DS): 0.9525
# Class 32 (DS): 0.9396
# Class 33 (DS): 0.9488
# Class 34 (DS): 0.9664
# Class 35 (DS): 0.8389
# Class 36 (DS): 0.9784
# Class 37 (DS): 0.8125
# Class 38 (DS): 0.9160
# Class 39 (DS): 0.9633
# Class 40 (DS): 0.9672
# Class 41 (DS): 0.9613
# Class 42 (DS): 0.8945
# Class 43 (DS): 0.8864
# Class 44 (DS): 0.9216
# ----------
# Epoch: 20, Phase: train, epoch loss: 16.0144, Av. Dice Score: 0.9347
# Class 0 (DS): 0.9144
# Class 1 (DS): 0.8692
# Class 2 (DS): 0.9590
# Class 3 (DS): 0.9465
# Class 4 (DS): 0.9155
# Class 5 (DS): 0.9246
# Class 6 (DS): 0.9546
# Class 7 (DS): 0.9506
# Class 8 (DS): 0.9531
# Class 9 (DS): 0.9350
# Class 10 (DS): 0.9510
# Class 11 (DS): 0.9107
# Class 12 (DS): 0.9357
# Class 13 (DS): 0.9411
# Class 14 (DS): 0.9679
# Class 15 (DS): 0.9434
# Class 16 (DS): 0.9575
# Class 17 (DS): 0.9516
# Class 18 (DS): 0.9824
# Class 19 (DS): 0.8492
# Class 20 (DS): 0.9084
# Class 21 (DS): 0.8694
# Class 22 (DS): 0.9641
# Class 23 (DS): 0.9589
# Class 24 (DS): 0.9163
# Class 25 (DS): 0.9169
# Class 26 (DS): 0.9610
# Class 27 (DS): 0.9559
# Class 28 (DS): 0.9572
# Class 29 (DS): 0.9477
# Class 30 (DS): 0.9307
# Class 31 (DS): 0.9611
# Class 32 (DS): 0.9590
# Class 33 (DS): 0.9556
# Class 34 (DS): 0.9824
# Class 35 (DS): 0.8480
# Class 36 (DS): 0.9638
# Class 37 (DS): 0.8156
# Class 38 (DS): 0.9250
# Class 39 (DS): 0.9673
# Class 40 (DS): 0.9691
# Class 41 (DS): 0.9604
# Class 42 (DS): 0.9007
# Class 43 (DS): 0.9126
# Class 44 (DS): 0.9401
# ----------
# Epoch: 20, Phase: validate, epoch loss: 15.9553, Av. Dice Score: 0.9341
# Class 0 (DS): 0.9145
# Class 1 (DS): 0.8710
# Class 2 (DS): 0.9542
# Class 3 (DS): 0.9389
# Class 4 (DS): 0.9120
# Class 5 (DS): 0.9193
# Class 6 (DS): 0.9580
# Class 7 (DS): 0.9549
# Class 8 (DS): 0.9555
# Class 9 (DS): 0.9437
# Class 10 (DS): 0.9555
# Class 11 (DS): 0.9231
# Class 12 (DS): 0.9286
# Class 13 (DS): 0.9349
# Class 14 (DS): 0.9569
# Class 15 (DS): 0.9309
# Class 16 (DS): 0.9468
# Class 17 (DS): 0.9357
# Class 18 (DS): 0.9775
# Class 19 (DS): 0.8562
# Class 20 (DS): 0.9223
# Class 21 (DS): 0.8655
# Class 22 (DS): 0.9696
# Class 23 (DS): 0.9681
# Class 24 (DS): 0.9173
# Class 25 (DS): 0.9203
# Class 26 (DS): 0.9615
# Class 27 (DS): 0.9578
# Class 28 (DS): 0.9647
# Class 29 (DS): 0.9596
# Class 30 (DS): 0.9528
# Class 31 (DS): 0.9619
# Class 32 (DS): 0.9468
# Class 33 (DS): 0.9493
# Class 34 (DS): 0.9763
# Class 35 (DS): 0.8383
# Class 36 (DS): 0.9719
# Class 37 (DS): 0.8250
# Class 38 (DS): 0.9132
# Class 39 (DS): 0.9626
# Class 40 (DS): 0.9698
# Class 41 (DS): 0.9553
# Class 42 (DS): 0.8977
# Class 43 (DS): 0.8963
# Class 44 (DS): 0.9420
# ----------
# Epoch: 21, Phase: train, epoch loss: 15.5523, Av. Dice Score: 0.9360
# Class 0 (DS): 0.9158
# Class 1 (DS): 0.8719
# Class 2 (DS): 0.9610
# Class 3 (DS): 0.9480
# Class 4 (DS): 0.9153
# Class 5 (DS): 0.9229
# Class 6 (DS): 0.9562
# Class 7 (DS): 0.9513
# Class 8 (DS): 0.9569
# Class 9 (DS): 0.9390
# Class 10 (DS): 0.9506
# Class 11 (DS): 0.9160
# Class 12 (DS): 0.9343
# Class 13 (DS): 0.9450
# Class 14 (DS): 0.9687
# Class 15 (DS): 0.9418
# Class 16 (DS): 0.9575
# Class 17 (DS): 0.9551
# Class 18 (DS): 0.9806
# Class 19 (DS): 0.8513
# Class 20 (DS): 0.9110
# Class 21 (DS): 0.8721
# Class 22 (DS): 0.9644
# Class 23 (DS): 0.9621
# Class 24 (DS): 0.9162
# Class 25 (DS): 0.9231
# Class 26 (DS): 0.9614
# Class 27 (DS): 0.9557
# Class 28 (DS): 0.9606
# Class 29 (DS): 0.9471
# Class 30 (DS): 0.9344
# Class 31 (DS): 0.9653
# Class 32 (DS): 0.9553
# Class 33 (DS): 0.9533
# Class 34 (DS): 0.9815
# Class 35 (DS): 0.8488
# Class 36 (DS): 0.9671
# Class 37 (DS): 0.8166
# Class 38 (DS): 0.9290
# Class 39 (DS): 0.9686
# Class 40 (DS): 0.9692
# Class 41 (DS): 0.9606
# Class 42 (DS): 0.9041
# Class 43 (DS): 0.9137
# Class 44 (DS): 0.9413
# ----------
# Epoch: 21, Phase: validate, epoch loss: 16.9957, Av. Dice Score: 0.9296
# Class 0 (DS): 0.9011
# Class 1 (DS): 0.8762
# Class 2 (DS): 0.9560
# Class 3 (DS): 0.9367
# Class 4 (DS): 0.9024
# Class 5 (DS): 0.9232
# Class 6 (DS): 0.9553
# Class 7 (DS): 0.9523
# Class 8 (DS): 0.9593
# Class 9 (DS): 0.9395
# Class 10 (DS): 0.9476
# Class 11 (DS): 0.8680
# Class 12 (DS): 0.9183
# Class 13 (DS): 0.9282
# Class 14 (DS): 0.9361
# Class 15 (DS): 0.9372
# Class 16 (DS): 0.9496
# Class 17 (DS): 0.9387
# Class 18 (DS): 0.9778
# Class 19 (DS): 0.8355
# Class 20 (DS): 0.9222
# Class 21 (DS): 0.8825
# Class 22 (DS): 0.9673
# Class 23 (DS): 0.9695
# Class 24 (DS): 0.9193
# Class 25 (DS): 0.9022
# Class 26 (DS): 0.9589
# Class 27 (DS): 0.9518
# Class 28 (DS): 0.9585
# Class 29 (DS): 0.9526
# Class 30 (DS): 0.9410
# Class 31 (DS): 0.9447
# Class 32 (DS): 0.9470
# Class 33 (DS): 0.9401
# Class 34 (DS): 0.9750
# Class 35 (DS): 0.8253
# Class 36 (DS): 0.9779
# Class 37 (DS): 0.8211
# Class 38 (DS): 0.8927
# Class 39 (DS): 0.9584
# Class 40 (DS): 0.9734
# Class 41 (DS): 0.9588
# Class 42 (DS): 0.9138
# Class 43 (DS): 0.8988
# Class 44 (DS): 0.9388
# ----------
# Epoch: 22, Phase: train, epoch loss: 15.6594, Av. Dice Score: 0.9351
# Class 0 (DS): 0.9179
# Class 1 (DS): 0.8719
# Class 2 (DS): 0.9621
# Class 3 (DS): 0.9463
# Class 4 (DS): 0.9125
# Class 5 (DS): 0.9181
# Class 6 (DS): 0.9592
# Class 7 (DS): 0.9513
# Class 8 (DS): 0.9535
# Class 9 (DS): 0.9386
# Class 10 (DS): 0.9530
# Class 11 (DS): 0.9082
# Class 12 (DS): 0.9342
# Class 13 (DS): 0.9394
# Class 14 (DS): 0.9667
# Class 15 (DS): 0.9425
# Class 16 (DS): 0.9581
# Class 17 (DS): 0.9536
# Class 18 (DS): 0.9818
# Class 19 (DS): 0.8502
# Class 20 (DS): 0.9121
# Class 21 (DS): 0.8769
# Class 22 (DS): 0.9650
# Class 23 (DS): 0.9627
# Class 24 (DS): 0.9175
# Class 25 (DS): 0.9245
# Class 26 (DS): 0.9593
# Class 27 (DS): 0.9542
# Class 28 (DS): 0.9588
# Class 29 (DS): 0.9481
# Class 30 (DS): 0.9347
# Class 31 (DS): 0.9649
# Class 32 (DS): 0.9554
# Class 33 (DS): 0.9537
# Class 34 (DS): 0.9808
# Class 35 (DS): 0.8447
# Class 36 (DS): 0.9702
# Class 37 (DS): 0.8111
# Class 38 (DS): 0.9303
# Class 39 (DS): 0.9645
# Class 40 (DS): 0.9682
# Class 41 (DS): 0.9598
# Class 42 (DS): 0.8963
# Class 43 (DS): 0.9095
# Class 44 (DS): 0.9383
# ----------
# Epoch: 22, Phase: validate, epoch loss: 17.4621, Av. Dice Score: 0.9324
# Class 0 (DS): 0.9137
# Class 1 (DS): 0.8754
# Class 2 (DS): 0.9573
# Class 3 (DS): 0.9289
# Class 4 (DS): 0.8922
# Class 5 (DS): 0.9137
# Class 6 (DS): 0.9550
# Class 7 (DS): 0.9564
# Class 8 (DS): 0.9508
# Class 9 (DS): 0.9401
# Class 10 (DS): 0.9585
# Class 11 (DS): 0.9250
# Class 12 (DS): 0.9234
# Class 13 (DS): 0.9384
# Class 14 (DS): 0.9573
# Class 15 (DS): 0.9385
# Class 16 (DS): 0.9457
# Class 17 (DS): 0.9322
# Class 18 (DS): 0.9634
# Class 19 (DS): 0.8564
# Class 20 (DS): 0.9288
# Class 21 (DS): 0.8728
# Class 22 (DS): 0.9663
# Class 23 (DS): 0.9701
# Class 24 (DS): 0.9028
# Class 25 (DS): 0.9224
# Class 26 (DS): 0.9448
# Class 27 (DS): 0.9516
# Class 28 (DS): 0.9730
# Class 29 (DS): 0.9584
# Class 30 (DS): 0.9443
# Class 31 (DS): 0.9513
# Class 32 (DS): 0.9348
# Class 33 (DS): 0.9447
# Class 34 (DS): 0.9816
# Class 35 (DS): 0.8355
# Class 36 (DS): 0.9629
# Class 37 (DS): 0.8178
# Class 38 (DS): 0.9462
# Class 39 (DS): 0.9489
# Class 40 (DS): 0.9606
# Class 41 (DS): 0.9560
# Class 42 (DS): 0.9248
# Class 43 (DS): 0.9161
# Class 44 (DS): 0.9192
# ----------
# Epoch: 23, Phase: train, epoch loss: 15.2481, Av. Dice Score: 0.9364
# Class 0 (DS): 0.9145
# Class 1 (DS): 0.8682
# Class 2 (DS): 0.9594
# Class 3 (DS): 0.9444
# Class 4 (DS): 0.9146
# Class 5 (DS): 0.9290
# Class 6 (DS): 0.9588
# Class 7 (DS): 0.9506
# Class 8 (DS): 0.9557
# Class 9 (DS): 0.9390
# Class 10 (DS): 0.9526
# Class 11 (DS): 0.9185
# Class 12 (DS): 0.9372
# Class 13 (DS): 0.9430
# Class 14 (DS): 0.9656
# Class 15 (DS): 0.9431
# Class 16 (DS): 0.9584
# Class 17 (DS): 0.9565
# Class 18 (DS): 0.9817
# Class 19 (DS): 0.8502
# Class 20 (DS): 0.9126
# Class 21 (DS): 0.8793
# Class 22 (DS): 0.9640
# Class 23 (DS): 0.9619
# Class 24 (DS): 0.9171
# Class 25 (DS): 0.9272
# Class 26 (DS): 0.9612
# Class 27 (DS): 0.9561
# Class 28 (DS): 0.9625
# Class 29 (DS): 0.9511
# Class 30 (DS): 0.9347
# Class 31 (DS): 0.9647
# Class 32 (DS): 0.9594
# Class 33 (DS): 0.9549
# Class 34 (DS): 0.9824
# Class 35 (DS): 0.8451
# Class 36 (DS): 0.9676
# Class 37 (DS): 0.8206
# Class 38 (DS): 0.9254
# Class 39 (DS): 0.9661
# Class 40 (DS): 0.9675
# Class 41 (DS): 0.9614
# Class 42 (DS): 0.8987
# Class 43 (DS): 0.9114
# Class 44 (DS): 0.9430
# ----------
# Epoch: 23, Phase: validate, epoch loss: 17.6721, Av. Dice Score: 0.9293
# Class 0 (DS): 0.9104
# Class 1 (DS): 0.8756
# Class 2 (DS): 0.9510
# Class 3 (DS): 0.9403
# Class 4 (DS): 0.9088
# Class 5 (DS): 0.9164
# Class 6 (DS): 0.9497
# Class 7 (DS): 0.9495
# Class 8 (DS): 0.9553
# Class 9 (DS): 0.9364
# Class 10 (DS): 0.9522
# Class 11 (DS): 0.8863
# Class 12 (DS): 0.9293
# Class 13 (DS): 0.9312
# Class 14 (DS): 0.9592
# Class 15 (DS): 0.9157
# Class 16 (DS): 0.9427
# Class 17 (DS): 0.9417
# Class 18 (DS): 0.9779
# Class 19 (DS): 0.8221
# Class 20 (DS): 0.9195
# Class 21 (DS): 0.8759
# Class 22 (DS): 0.9604
# Class 23 (DS): 0.9697
# Class 24 (DS): 0.9139
# Class 25 (DS): 0.9139
# Class 26 (DS): 0.9609
# Class 27 (DS): 0.9502
# Class 28 (DS): 0.9618
# Class 29 (DS): 0.9554
# Class 30 (DS): 0.9472
# Class 31 (DS): 0.9585
# Class 32 (DS): 0.9423
# Class 33 (DS): 0.9448
# Class 34 (DS): 0.9756
# Class 35 (DS): 0.8211
# Class 36 (DS): 0.9748
# Class 37 (DS): 0.8099
# Class 38 (DS): 0.8931
# Class 39 (DS): 0.9641
# Class 40 (DS): 0.9622
# Class 41 (DS): 0.9500
# Class 42 (DS): 0.9082
# Class 43 (DS): 0.9006
# Class 44 (DS): 0.9342
# ----------
# Epoch: 24, Phase: train, epoch loss: 15.0835, Av. Dice Score: 0.9371
# Class 0 (DS): 0.9198
# Class 1 (DS): 0.8704
# Class 2 (DS): 0.9627
# Class 3 (DS): 0.9480
# Class 4 (DS): 0.9174
# Class 5 (DS): 0.9275
# Class 6 (DS): 0.9586
# Class 7 (DS): 0.9534
# Class 8 (DS): 0.9590
# Class 9 (DS): 0.9396
# Class 10 (DS): 0.9495
# Class 11 (DS): 0.9134
# Class 12 (DS): 0.9354
# Class 13 (DS): 0.9450
# Class 14 (DS): 0.9689
# Class 15 (DS): 0.9429
# Class 16 (DS): 0.9611
# Class 17 (DS): 0.9588
# Class 18 (DS): 0.9806
# Class 19 (DS): 0.8540
# Class 20 (DS): 0.9150
# Class 21 (DS): 0.8782
# Class 22 (DS): 0.9647
# Class 23 (DS): 0.9609
# Class 24 (DS): 0.9189
# Class 25 (DS): 0.9286
# Class 26 (DS): 0.9630
# Class 27 (DS): 0.9560
# Class 28 (DS): 0.9604
# Class 29 (DS): 0.9443
# Class 30 (DS): 0.9329
# Class 31 (DS): 0.9639
# Class 32 (DS): 0.9610
# Class 33 (DS): 0.9545
# Class 34 (DS): 0.9806
# Class 35 (DS): 0.8493
# Class 36 (DS): 0.9673
# Class 37 (DS): 0.8177
# Class 38 (DS): 0.9275
# Class 39 (DS): 0.9693
# Class 40 (DS): 0.9688
# Class 41 (DS): 0.9624
# Class 42 (DS): 0.9005
# Class 43 (DS): 0.9123
# Class 44 (DS): 0.9441
# ----------
# Epoch: 24, Phase: validate, epoch loss: 17.5215, Av. Dice Score: 0.9332
# Class 0 (DS): 0.9072
# Class 1 (DS): 0.8813
# Class 2 (DS): 0.9608
# Class 3 (DS): 0.9225
# Class 4 (DS): 0.9037
# Class 5 (DS): 0.9179
# Class 6 (DS): 0.9577
# Class 7 (DS): 0.9620
# Class 8 (DS): 0.9559
# Class 9 (DS): 0.9349
# Class 10 (DS): 0.9604
# Class 11 (DS): 0.8929
# Class 12 (DS): 0.9293
# Class 13 (DS): 0.9233
# Class 14 (DS): 0.9442
# Class 15 (DS): 0.9386
# Class 16 (DS): 0.9527
# Class 17 (DS): 0.9443
# Class 18 (DS): 0.9776
# Class 19 (DS): 0.8408
# Class 20 (DS): 0.9188
# Class 21 (DS): 0.8713
# Class 22 (DS): 0.9696
# Class 23 (DS): 0.9684
# Class 24 (DS): 0.9217
# Class 25 (DS): 0.9327
# Class 26 (DS): 0.9616
# Class 27 (DS): 0.9589
# Class 28 (DS): 0.9649
# Class 29 (DS): 0.9496
# Class 30 (DS): 0.9492
# Class 31 (DS): 0.9637
# Class 32 (DS): 0.9390
# Class 33 (DS): 0.9520
# Class 34 (DS): 0.9831
# Class 35 (DS): 0.8392
# Class 36 (DS): 0.9624
# Class 37 (DS): 0.8184
# Class 38 (DS): 0.9120
# Class 39 (DS): 0.9689
# Class 40 (DS): 0.9651
# Class 41 (DS): 0.9540
# Class 42 (DS): 0.9166
# Class 43 (DS): 0.9064
# Class 44 (DS): 0.9364
# ----------
# Epoch: 25, Phase: train, epoch loss: 15.3864, Av. Dice Score: 0.9349
# Class 0 (DS): 0.9123
# Class 1 (DS): 0.8628
# Class 2 (DS): 0.9577
# Class 3 (DS): 0.9481
# Class 4 (DS): 0.9154
# Class 5 (DS): 0.9240
# Class 6 (DS): 0.9600
# Class 7 (DS): 0.9527
# Class 8 (DS): 0.9554
# Class 9 (DS): 0.9402
# Class 10 (DS): 0.9541
# Class 11 (DS): 0.9151
# Class 12 (DS): 0.9335
# Class 13 (DS): 0.9423
# Class 14 (DS): 0.9667
# Class 15 (DS): 0.9453
# Class 16 (DS): 0.9610
# Class 17 (DS): 0.9531
# Class 18 (DS): 0.9830
# Class 19 (DS): 0.8492
# Class 20 (DS): 0.9024
# Class 21 (DS): 0.8621
# Class 22 (DS): 0.9646
# Class 23 (DS): 0.9612
# Class 24 (DS): 0.9170
# Class 25 (DS): 0.9204
# Class 26 (DS): 0.9626
# Class 27 (DS): 0.9577
# Class 28 (DS): 0.9606
# Class 29 (DS): 0.9518
# Class 30 (DS): 0.9284
# Class 31 (DS): 0.9604
# Class 32 (DS): 0.9586
# Class 33 (DS): 0.9487
# Class 34 (DS): 0.9822
# Class 35 (DS): 0.8449
# Class 36 (DS): 0.9663
# Class 37 (DS): 0.8152
# Class 38 (DS): 0.9203
# Class 39 (DS): 0.9663
# Class 40 (DS): 0.9702
# Class 41 (DS): 0.9630
# Class 42 (DS): 0.8985
# Class 43 (DS): 0.9108
# Class 44 (DS): 0.9427
# ----------
# Epoch: 25, Phase: validate, epoch loss: 16.2667, Av. Dice Score: 0.9329
# Class 0 (DS): 0.9136
# Class 1 (DS): 0.8579
# Class 2 (DS): 0.9512
# Class 3 (DS): 0.9284
# Class 4 (DS): 0.9106
# Class 5 (DS): 0.9266
# Class 6 (DS): 0.9537
# Class 7 (DS): 0.9564
# Class 8 (DS): 0.9639
# Class 9 (DS): 0.9376
# Class 10 (DS): 0.9584
# Class 11 (DS): 0.9064
# Class 12 (DS): 0.9268
# Class 13 (DS): 0.9412
# Class 14 (DS): 0.9547
# Class 15 (DS): 0.9448
# Class 16 (DS): 0.9496
# Class 17 (DS): 0.9502
# Class 18 (DS): 0.9800
# Class 19 (DS): 0.8495
# Class 20 (DS): 0.9226
# Class 21 (DS): 0.8696
# Class 22 (DS): 0.9699
# Class 23 (DS): 0.9531
# Class 24 (DS): 0.9204
# Class 25 (DS): 0.9371
# Class 26 (DS): 0.9577
# Class 27 (DS): 0.9573
# Class 28 (DS): 0.9630
# Class 29 (DS): 0.9572
# Class 30 (DS): 0.9450
# Class 31 (DS): 0.9534
# Class 32 (DS): 0.9477
# Class 33 (DS): 0.9484
# Class 34 (DS): 0.9824
# Class 35 (DS): 0.8394
# Class 36 (DS): 0.9824
# Class 37 (DS): 0.8193
# Class 38 (DS): 0.8903
# Class 39 (DS): 0.9639
# Class 40 (DS): 0.9682
# Class 41 (DS): 0.9520
# Class 42 (DS): 0.8942
# Class 43 (DS): 0.8989
# Class 44 (DS): 0.9275
# ----------
# Epoch: 26, Phase: train, epoch loss: 15.2605, Av. Dice Score: 0.9361
# Class 0 (DS): 0.9143
# Class 1 (DS): 0.8705
# Class 2 (DS): 0.9623
# Class 3 (DS): 0.9409
# Class 4 (DS): 0.9131
# Class 5 (DS): 0.9219
# Class 6 (DS): 0.9584
# Class 7 (DS): 0.9505
# Class 8 (DS): 0.9538
# Class 9 (DS): 0.9407
# Class 10 (DS): 0.9503
# Class 11 (DS): 0.9142
# Class 12 (DS): 0.9337
# Class 13 (DS): 0.9430
# Class 14 (DS): 0.9682
# Class 15 (DS): 0.9430
# Class 16 (DS): 0.9596
# Class 17 (DS): 0.9547
# Class 18 (DS): 0.9834
# Class 19 (DS): 0.8551
# Class 20 (DS): 0.9148
# Class 21 (DS): 0.8760
# Class 22 (DS): 0.9644
# Class 23 (DS): 0.9641
# Class 24 (DS): 0.9171
# Class 25 (DS): 0.9276
# Class 26 (DS): 0.9646
# Class 27 (DS): 0.9551
# Class 28 (DS): 0.9593
# Class 29 (DS): 0.9483
# Class 30 (DS): 0.9340
# Class 31 (DS): 0.9619
# Class 32 (DS): 0.9578
# Class 33 (DS): 0.9568
# Class 34 (DS): 0.9824
# Class 35 (DS): 0.8487
# Class 36 (DS): 0.9642
# Class 37 (DS): 0.8163
# Class 38 (DS): 0.9212
# Class 39 (DS): 0.9657
# Class 40 (DS): 0.9679
# Class 41 (DS): 0.9629
# Class 42 (DS): 0.9057
# Class 43 (DS): 0.9125
# Class 44 (DS): 0.9414
# ----------
# Epoch: 26, Phase: validate, epoch loss: 16.6121, Av. Dice Score: 0.9346
# Class 0 (DS): 0.9050
# Class 1 (DS): 0.8788
# Class 2 (DS): 0.9566
# Class 3 (DS): 0.9358
# Class 4 (DS): 0.8836
# Class 5 (DS): 0.9209
# Class 6 (DS): 0.9605
# Class 7 (DS): 0.9646
# Class 8 (DS): 0.9653
# Class 9 (DS): 0.9389
# Class 10 (DS): 0.9594
# Class 11 (DS): 0.9179
# Class 12 (DS): 0.9296
# Class 13 (DS): 0.9287
# Class 14 (DS): 0.9583
# Class 15 (DS): 0.9376
# Class 16 (DS): 0.9545
# Class 17 (DS): 0.9419
# Class 18 (DS): 0.9798
# Class 19 (DS): 0.8527
# Class 20 (DS): 0.9175
# Class 21 (DS): 0.8593
# Class 22 (DS): 0.9713
# Class 23 (DS): 0.9568
# Class 24 (DS): 0.9143
# Class 25 (DS): 0.9262
# Class 26 (DS): 0.9675
# Class 27 (DS): 0.9575
# Class 28 (DS): 0.9621
# Class 29 (DS): 0.9520
# Class 30 (DS): 0.9517
# Class 31 (DS): 0.9622
# Class 32 (DS): 0.9493
# Class 33 (DS): 0.9497
# Class 34 (DS): 0.9834
# Class 35 (DS): 0.8437
# Class 36 (DS): 0.9798
# Class 37 (DS): 0.8072
# Class 38 (DS): 0.9372
# Class 39 (DS): 0.9672
# Class 40 (DS): 0.9619
# Class 41 (DS): 0.9575
# Class 42 (DS): 0.9217
# Class 43 (DS): 0.8992
# Class 44 (DS): 0.9315
# ----------
# Epoch: 27, Phase: train, epoch loss: 14.5009, Av. Dice Score: 0.9385
# Class 0 (DS): 0.9231
# Class 1 (DS): 0.8805
# Class 2 (DS): 0.9621
# Class 3 (DS): 0.9541
# Class 4 (DS): 0.9162
# Class 5 (DS): 0.9308
# Class 6 (DS): 0.9608
# Class 7 (DS): 0.9524
# Class 8 (DS): 0.9556
# Class 9 (DS): 0.9404
# Class 10 (DS): 0.9519
# Class 11 (DS): 0.9170
# Class 12 (DS): 0.9364
# Class 13 (DS): 0.9452
# Class 14 (DS): 0.9676
# Class 15 (DS): 0.9461
# Class 16 (DS): 0.9591
# Class 17 (DS): 0.9528
# Class 18 (DS): 0.9815
# Class 19 (DS): 0.8548
# Class 20 (DS): 0.9186
# Class 21 (DS): 0.8863
# Class 22 (DS): 0.9670
# Class 23 (DS): 0.9640
# Class 24 (DS): 0.9180
# Class 25 (DS): 0.9300
# Class 26 (DS): 0.9637
# Class 27 (DS): 0.9583
# Class 28 (DS): 0.9612
# Class 29 (DS): 0.9515
# Class 30 (DS): 0.9355
# Class 31 (DS): 0.9659
# Class 32 (DS): 0.9581
# Class 33 (DS): 0.9535
# Class 34 (DS): 0.9793
# Class 35 (DS): 0.8505
# Class 36 (DS): 0.9712
# Class 37 (DS): 0.8205
# Class 38 (DS): 0.9273
# Class 39 (DS): 0.9679
# Class 40 (DS): 0.9688
# Class 41 (DS): 0.9653
# Class 42 (DS): 0.9013
# Class 43 (DS): 0.9167
# Class 44 (DS): 0.9457
# ----------
# Epoch: 27, Phase: validate, epoch loss: 17.5419, Av. Dice Score: 0.9297
# Class 0 (DS): 0.9151
# Class 1 (DS): 0.8667
# Class 2 (DS): 0.9452
# Class 3 (DS): 0.9319
# Class 4 (DS): 0.8996
# Class 5 (DS): 0.9241
# Class 6 (DS): 0.9535
# Class 7 (DS): 0.9565
# Class 8 (DS): 0.9558
# Class 9 (DS): 0.9185
# Class 10 (DS): 0.9579
# Class 11 (DS): 0.9130
# Class 12 (DS): 0.9329
# Class 13 (DS): 0.9409
# Class 14 (DS): 0.9659
# Class 15 (DS): 0.9485
# Class 16 (DS): 0.9431
# Class 17 (DS): 0.9420
# Class 18 (DS): 0.9790
# Class 19 (DS): 0.8550
# Class 20 (DS): 0.9153
# Class 21 (DS): 0.8611
# Class 22 (DS): 0.9645
# Class 23 (DS): 0.9675
# Class 24 (DS): 0.9159
# Class 25 (DS): 0.9235
# Class 26 (DS): 0.9574
# Class 27 (DS): 0.9460
# Class 28 (DS): 0.9478
# Class 29 (DS): 0.9490
# Class 30 (DS): 0.9316
# Class 31 (DS): 0.9534
# Class 32 (DS): 0.9293
# Class 33 (DS): 0.9472
# Class 34 (DS): 0.9731
# Class 35 (DS): 0.8312
# Class 36 (DS): 0.9763
# Class 37 (DS): 0.8204
# Class 38 (DS): 0.9243
# Class 39 (DS): 0.9729
# Class 40 (DS): 0.9599
# Class 41 (DS): 0.9451
# Class 42 (DS): 0.8693
# Class 43 (DS): 0.8786
# Class 44 (DS): 0.9300
# ----------
# Epoch: 28, Phase: train, epoch loss: 14.3073, Av. Dice Score: 0.9394
# Class 0 (DS): 0.9220
# Class 1 (DS): 0.8787
# Class 2 (DS): 0.9610
# Class 3 (DS): 0.9498
# Class 4 (DS): 0.9185
# Class 5 (DS): 0.9289
# Class 6 (DS): 0.9589
# Class 7 (DS): 0.9537
# Class 8 (DS): 0.9578
# Class 9 (DS): 0.9384
# Class 10 (DS): 0.9543
# Class 11 (DS): 0.9147
# Class 12 (DS): 0.9408
# Class 13 (DS): 0.9447
# Class 14 (DS): 0.9695
# Class 15 (DS): 0.9513
# Class 16 (DS): 0.9621
# Class 17 (DS): 0.9589
# Class 18 (DS): 0.9812
# Class 19 (DS): 0.8567
# Class 20 (DS): 0.9140
# Class 21 (DS): 0.8855
# Class 22 (DS): 0.9666
# Class 23 (DS): 0.9632
# Class 24 (DS): 0.9203
# Class 25 (DS): 0.9265
# Class 26 (DS): 0.9651
# Class 27 (DS): 0.9573
# Class 28 (DS): 0.9638
# Class 29 (DS): 0.9493
# Class 30 (DS): 0.9373
# Class 31 (DS): 0.9662
# Class 32 (DS): 0.9619
# Class 33 (DS): 0.9580
# Class 34 (DS): 0.9801
# Class 35 (DS): 0.8515
# Class 36 (DS): 0.9679
# Class 37 (DS): 0.8234
# Class 38 (DS): 0.9321
# Class 39 (DS): 0.9684
# Class 40 (DS): 0.9695
# Class 41 (DS): 0.9654
# Class 42 (DS): 0.9076
# Class 43 (DS): 0.9200
# Class 44 (DS): 0.9478
# ----------
# Epoch: 28, Phase: validate, epoch loss: 16.7136, Av. Dice Score: 0.9347
# Class 0 (DS): 0.9192
# Class 1 (DS): 0.8508
# Class 2 (DS): 0.9499
# Class 3 (DS): 0.9381
# Class 4 (DS): 0.9147
# Class 5 (DS): 0.9190
# Class 6 (DS): 0.9556
# Class 7 (DS): 0.9642
# Class 8 (DS): 0.9602
# Class 9 (DS): 0.9431
# Class 10 (DS): 0.9585
# Class 11 (DS): 0.9256
# Class 12 (DS): 0.9292
# Class 13 (DS): 0.9350
# Class 14 (DS): 0.9513
# Class 15 (DS): 0.9417
# Class 16 (DS): 0.9505
# Class 17 (DS): 0.9430
# Class 18 (DS): 0.9786
# Class 19 (DS): 0.8586
# Class 20 (DS): 0.9226
# Class 21 (DS): 0.8586
# Class 22 (DS): 0.9629
# Class 23 (DS): 0.9726
# Class 24 (DS): 0.9018
# Class 25 (DS): 0.9137
# Class 26 (DS): 0.9613
# Class 27 (DS): 0.9553
# Class 28 (DS): 0.9710
# Class 29 (DS): 0.9598
# Class 30 (DS): 0.9443
# Class 31 (DS): 0.9532
# Class 32 (DS): 0.9398
# Class 33 (DS): 0.9535
# Class 34 (DS): 0.9749
# Class 35 (DS): 0.8500
# Class 36 (DS): 0.9849
# Class 37 (DS): 0.8225
# Class 38 (DS): 0.9206
# Class 39 (DS): 0.9669
# Class 40 (DS): 0.9696
# Class 41 (DS): 0.9572
# Class 42 (DS): 0.9220
# Class 43 (DS): 0.8965
# Class 44 (DS): 0.9414
# ----------
# Epoch: 29, Phase: train, epoch loss: 14.7505, Av. Dice Score: 0.9376
# Class 0 (DS): 0.9225
# Class 1 (DS): 0.8699
# Class 2 (DS): 0.9583
# Class 3 (DS): 0.9528
# Class 4 (DS): 0.9152
# Class 5 (DS): 0.9319
# Class 6 (DS): 0.9601
# Class 7 (DS): 0.9504
# Class 8 (DS): 0.9553
# Class 9 (DS): 0.9387
# Class 10 (DS): 0.9521
# Class 11 (DS): 0.9125
# Class 12 (DS): 0.9391
# Class 13 (DS): 0.9488
# Class 14 (DS): 0.9703
# Class 15 (DS): 0.9425
# Class 16 (DS): 0.9577
# Class 17 (DS): 0.9566
# Class 18 (DS): 0.9818
# Class 19 (DS): 0.8562
# Class 20 (DS): 0.9177
# Class 21 (DS): 0.8745
# Class 22 (DS): 0.9645
# Class 23 (DS): 0.9650
# Class 24 (DS): 0.9212
# Class 25 (DS): 0.9257
# Class 26 (DS): 0.9634
# Class 27 (DS): 0.9565
# Class 28 (DS): 0.9564
# Class 29 (DS): 0.9544
# Class 30 (DS): 0.9337
# Class 31 (DS): 0.9675
# Class 32 (DS): 0.9589
# Class 33 (DS): 0.9548
# Class 34 (DS): 0.9824
# Class 35 (DS): 0.8465
# Class 36 (DS): 0.9686
# Class 37 (DS): 0.8172
# Class 38 (DS): 0.9208
# Class 39 (DS): 0.9658
# Class 40 (DS): 0.9694
# Class 41 (DS): 0.9616
# Class 42 (DS): 0.9095
# Class 43 (DS): 0.9183
# Class 44 (DS): 0.9459
# ----------
# Epoch: 29, Phase: validate, epoch loss: 15.7250, Av. Dice Score: 0.9351
# Class 0 (DS): 0.9029
# Class 1 (DS): 0.8760
# Class 2 (DS): 0.9562
# Class 3 (DS): 0.9423
# Class 4 (DS): 0.9092
# Class 5 (DS): 0.9329
# Class 6 (DS): 0.9584
# Class 7 (DS): 0.9516
# Class 8 (DS): 0.9604
# Class 9 (DS): 0.9418
# Class 10 (DS): 0.9489
# Class 11 (DS): 0.8971
# Class 12 (DS): 0.9321
# Class 13 (DS): 0.9338
# Class 14 (DS): 0.9611
# Class 15 (DS): 0.9363
# Class 16 (DS): 0.9482
# Class 17 (DS): 0.9507
# Class 18 (DS): 0.9789
# Class 19 (DS): 0.8570
# Class 20 (DS): 0.9263
# Class 21 (DS): 0.8807
# Class 22 (DS): 0.9701
# Class 23 (DS): 0.9676
# Class 24 (DS): 0.9110
# Class 25 (DS): 0.9294
# Class 26 (DS): 0.9610
# Class 27 (DS): 0.9558
# Class 28 (DS): 0.9566
# Class 29 (DS): 0.9585
# Class 30 (DS): 0.9423
# Class 31 (DS): 0.9607
# Class 32 (DS): 0.9536
# Class 33 (DS): 0.9448
# Class 34 (DS): 0.9763
# Class 35 (DS): 0.8417
# Class 36 (DS): 0.9815
# Class 37 (DS): 0.8095
# Class 38 (DS): 0.9440
# Class 39 (DS): 0.9644
# Class 40 (DS): 0.9670
# Class 41 (DS): 0.9580
# Class 42 (DS): 0.9195
# Class 43 (DS): 0.8954
# Class 44 (DS): 0.9297
# ----------
# --------------------------------------------------
# Training complete in 175m 6s
# Best val dice loss: 15.725045, Best Average DS: 0.935137

# %%
optimizer = optim.Adam(model.parameters(),lr = 5e-5)

# %%
def dice_loss_2(true,scores,mean, epsilon = 1e-4,p = 2,we = 0.05):
#     N, C, sh1, sh2 = true1.size()
    
#     true = []
#     scores = []
#     for c in range(N):
#         if not torch.sum(true1[c,1:,:,:])==0:
#             true.append(true1[c,:,:,:])
#             scores.append(scores1[c,:,:,:])
#     try:
#         true = torch.stack(true)
#         scores = torch.stack(scores)
#     except:
#         return -1
    
    
    
    N, C, sh1, sh2 = true.size()
#     grad_mask = get_gradient(true)
#     grad_mask = grad_mask.view(N,C,-1)
    
    preds = F.softmax(scores, dim = 1)
    true = true.view(N, C, -1)
    preds = preds.view(N, C, -1)
    wts = torch.sum(true, dim = 2) + epsilon
#     mean = 1/torch.pow(mean,p)
    wts[:,:] = mean[None].repeat(N,1)
#     wts = wts/(torch.sum(wts,dim = 1)[:,None])
#     print(wts)
    grad_wts = torch.max(mean)
    prod = torch.sum(true*preds,dim = 2)
    sum_tnp = torch.sum(true + preds, dim = 2)
    num = torch.sum(wts * prod, dim = 1)
    denom = torch.sum(wts * sum_tnp, dim = 1) + epsilon
    loss = 1 - 2*(num/denom)
#     cel = -torch.sum(wts * torch.sum(true*torch.log(preds),dim = 2),dim = 1)
#     grad_loss = -torch.sum(2*grad_wts * torch.sum(grad_mask*torch.log(preds),dim = 2),dim = 1)
#     return 40*torch.mean(loss)+we*torch.mean(cel)
    return torch.mean(loss)

# %%
model, loss_hist, dice_hist = train_model(model, optimizer,dataloader,'exp_2_dnc_then_d_lr_5e-5',num_seg = num_seg, num_epochs = 30,\
                                         every = 1, print_all_ds = True)
# Out:
# Epoch: 0, Phase: train, epoch loss: 0.1027, Av. Dice Score: 0.9467
# Class 0 (DS): 0.9184
# Class 1 (DS): 0.8789
# Class 2 (DS): 0.9673
# Class 3 (DS): 0.9574
# Class 4 (DS): 0.9213
# Class 5 (DS): 0.9424
# Class 6 (DS): 0.9627
# Class 7 (DS): 0.9606
# Class 8 (DS): 0.9634
# Class 9 (DS): 0.9431
# Class 10 (DS): 0.9600
# Class 11 (DS): 0.9321
# Class 12 (DS): 0.9425
# Class 13 (DS): 0.9643
# Class 14 (DS): 0.9753
# Class 15 (DS): 0.9581
# Class 16 (DS): 0.9653
# Class 17 (DS): 0.9579
# Class 18 (DS): 0.9839
# Class 19 (DS): 0.8654
# Class 20 (DS): 0.9272
# Class 21 (DS): 0.8967
# Class 22 (DS): 0.9693
# Class 23 (DS): 0.9705
# Class 24 (DS): 0.9252
# Class 25 (DS): 0.9391
# Class 26 (DS): 0.9631
# Class 27 (DS): 0.9642
# Class 28 (DS): 0.9705
# Class 29 (DS): 0.9587
# Class 30 (DS): 0.9494
# Class 31 (DS): 0.9744
# Class 32 (DS): 0.9652
# Class 33 (DS): 0.9573
# Class 34 (DS): 0.9836
# Class 35 (DS): 0.8611
# Class 36 (DS): 0.9772
# Class 37 (DS): 0.8454
# Class 38 (DS): 0.9276
# Class 39 (DS): 0.9736
# Class 40 (DS): 0.9794
# Class 41 (DS): 0.9711
# Class 42 (DS): 0.9299
# Class 43 (DS): 0.9452
# Class 44 (DS): 0.9568
# ----------
# Epoch: 0, Phase: validate, epoch loss: 0.0957, Av. Dice Score: 0.9443
# Class 0 (DS): 0.9219
# Class 1 (DS): 0.8888
# Class 2 (DS): 0.9666
# Class 3 (DS): 0.9441
# Class 4 (DS): 0.9015
# Class 5 (DS): 0.9331
# Class 6 (DS): 0.9597
# Class 7 (DS): 0.9666
# Class 8 (DS): 0.9717
# Class 9 (DS): 0.9380
# Class 10 (DS): 0.9617
# Class 11 (DS): 0.9320
# Class 12 (DS): 0.9426
# Class 13 (DS): 0.9532
# Class 14 (DS): 0.9713
# Class 15 (DS): 0.9637
# Class 16 (DS): 0.9557
# Class 17 (DS): 0.9496
# Class 18 (DS): 0.9802
# Class 19 (DS): 0.8660
# Class 20 (DS): 0.9290
# Class 21 (DS): 0.8903
# Class 22 (DS): 0.9763
# Class 23 (DS): 0.9679
# Class 24 (DS): 0.9276
# Class 25 (DS): 0.9366
# Class 26 (DS): 0.9606
# Class 27 (DS): 0.9643
# Class 28 (DS): 0.9760
# Class 29 (DS): 0.9602
# Class 30 (DS): 0.9596
# Class 31 (DS): 0.9694
# Class 32 (DS): 0.9462
# Class 33 (DS): 0.9515
# Class 34 (DS): 0.9849
# Class 35 (DS): 0.8368
# Class 36 (DS): 0.9861
# Class 37 (DS): 0.8302
# Class 38 (DS): 0.9438
# Class 39 (DS): 0.9739
# Class 40 (DS): 0.9752
# Class 41 (DS): 0.9601
# Class 42 (DS): 0.9381
# Class 43 (DS): 0.9271
# Class 44 (DS): 0.9551
# ----------
# Epoch: 1, Phase: train, epoch loss: 0.0886, Av. Dice Score: 0.9524
# Class 0 (DS): 0.9307
# Class 1 (DS): 0.8981
# Class 2 (DS): 0.9697
# Class 3 (DS): 0.9616
# Class 4 (DS): 0.9258
# Class 5 (DS): 0.9503
# Class 6 (DS): 0.9675
# Class 7 (DS): 0.9628
# Class 8 (DS): 0.9673
# Class 9 (DS): 0.9504
# Class 10 (DS): 0.9637
# Class 11 (DS): 0.9359
# Class 12 (DS): 0.9480
# Class 13 (DS): 0.9651
# Class 14 (DS): 0.9789
# Class 15 (DS): 0.9636
# Class 16 (DS): 0.9686
# Class 17 (DS): 0.9639
# Class 18 (DS): 0.9871
# Class 19 (DS): 0.8689
# Class 20 (DS): 0.9336
# Class 21 (DS): 0.9037
# Class 22 (DS): 0.9725
# Class 23 (DS): 0.9716
# Class 24 (DS): 0.9279
# Class 25 (DS): 0.9455
# Class 26 (DS): 0.9703
# Class 27 (DS): 0.9678
# Class 28 (DS): 0.9701
# Class 29 (DS): 0.9592
# Class 30 (DS): 0.9523
# Class 31 (DS): 0.9760
# Class 32 (DS): 0.9718
# Class 33 (DS): 0.9647
# Class 34 (DS): 0.9871
# Class 35 (DS): 0.8622
# Class 36 (DS): 0.9815
# Class 37 (DS): 0.8519
# Class 38 (DS): 0.9616
# Class 39 (DS): 0.9777
# Class 40 (DS): 0.9820
# Class 41 (DS): 0.9725
# Class 42 (DS): 0.9463
# Class 43 (DS): 0.9538
# Class 44 (DS): 0.9664
# ----------
# Epoch: 1, Phase: validate, epoch loss: 0.0892, Av. Dice Score: 0.9474
# Class 0 (DS): 0.9218
# Class 1 (DS): 0.8951
# Class 2 (DS): 0.9655
# Class 3 (DS): 0.9500
# Class 4 (DS): 0.9093
# Class 5 (DS): 0.9327
# Class 6 (DS): 0.9609
# Class 7 (DS): 0.9641
# Class 8 (DS): 0.9686
# Class 9 (DS): 0.9370
# Class 10 (DS): 0.9673
# Class 11 (DS): 0.9366
# Class 12 (DS): 0.9425
# Class 13 (DS): 0.9569
# Class 14 (DS): 0.9758
# Class 15 (DS): 0.9655
# Class 16 (DS): 0.9522
# Class 17 (DS): 0.9499
# Class 18 (DS): 0.9798
# Class 19 (DS): 0.8666
# Class 20 (DS): 0.9296
# Class 21 (DS): 0.8986
# Class 22 (DS): 0.9773
# Class 23 (DS): 0.9728
# Class 24 (DS): 0.9292
# Class 25 (DS): 0.9388
# Class 26 (DS): 0.9653
# Class 27 (DS): 0.9617
# Class 28 (DS): 0.9768
# Class 29 (DS): 0.9605
# Class 30 (DS): 0.9616
# Class 31 (DS): 0.9725
# Class 32 (DS): 0.9488
# Class 33 (DS): 0.9575
# Class 34 (DS): 0.9845
# Class 35 (DS): 0.8435
# Class 36 (DS): 0.9903
# Class 37 (DS): 0.8419
# Class 38 (DS): 0.9653
# Class 39 (DS): 0.9766
# Class 40 (DS): 0.9792
# Class 41 (DS): 0.9626
# Class 42 (DS): 0.9560
# Class 43 (DS): 0.9271
# Class 44 (DS): 0.9587
# ----------
# Epoch: 2, Phase: train, epoch loss: 0.0852, Av. Dice Score: 0.9529
# Class 0 (DS): 0.9321
# Class 1 (DS): 0.8993
# Class 2 (DS): 0.9712
# Class 3 (DS): 0.9655
# Class 4 (DS): 0.9210
# Class 5 (DS): 0.9472
# Class 6 (DS): 0.9673
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9692
# Class 9 (DS): 0.9489
# Class 10 (DS): 0.9657
# Class 11 (DS): 0.9362
# Class 12 (DS): 0.9477
# Class 13 (DS): 0.9642
# Class 14 (DS): 0.9792
# Class 15 (DS): 0.9655
# Class 16 (DS): 0.9679
# Class 17 (DS): 0.9635
# Class 18 (DS): 0.9873
# Class 19 (DS): 0.8694
# Class 20 (DS): 0.9325
# Class 21 (DS): 0.9073
# Class 22 (DS): 0.9737
# Class 23 (DS): 0.9731
# Class 24 (DS): 0.9253
# Class 25 (DS): 0.9458
# Class 26 (DS): 0.9692
# Class 27 (DS): 0.9679
# Class 28 (DS): 0.9722
# Class 29 (DS): 0.9600
# Class 30 (DS): 0.9534
# Class 31 (DS): 0.9770
# Class 32 (DS): 0.9681
# Class 33 (DS): 0.9644
# Class 34 (DS): 0.9871
# Class 35 (DS): 0.8629
# Class 36 (DS): 0.9827
# Class 37 (DS): 0.8496
# Class 38 (DS): 0.9648
# Class 39 (DS): 0.9779
# Class 40 (DS): 0.9839
# Class 41 (DS): 0.9763
# Class 42 (DS): 0.9520
# Class 43 (DS): 0.9528
# Class 44 (DS): 0.9680
# ----------
# Epoch: 2, Phase: validate, epoch loss: 0.0884, Av. Dice Score: 0.9459
# Class 0 (DS): 0.9195
# Class 1 (DS): 0.8976
# Class 2 (DS): 0.9673
# Class 3 (DS): 0.9450
# Class 4 (DS): 0.9026
# Class 5 (DS): 0.9359
# Class 6 (DS): 0.9632
# Class 7 (DS): 0.9638
# Class 8 (DS): 0.9693
# Class 9 (DS): 0.9343
# Class 10 (DS): 0.9659
# Class 11 (DS): 0.9323
# Class 12 (DS): 0.9400
# Class 13 (DS): 0.9569
# Class 14 (DS): 0.9757
# Class 15 (DS): 0.9659
# Class 16 (DS): 0.9527
# Class 17 (DS): 0.9504
# Class 18 (DS): 0.9756
# Class 19 (DS): 0.8593
# Class 20 (DS): 0.9285
# Class 21 (DS): 0.8976
# Class 22 (DS): 0.9760
# Class 23 (DS): 0.9705
# Class 24 (DS): 0.9235
# Class 25 (DS): 0.9413
# Class 26 (DS): 0.9654
# Class 27 (DS): 0.9662
# Class 28 (DS): 0.9759
# Class 29 (DS): 0.9608
# Class 30 (DS): 0.9577
# Class 31 (DS): 0.9692
# Class 32 (DS): 0.9466
# Class 33 (DS): 0.9523
# Class 34 (DS): 0.9850
# Class 35 (DS): 0.8416
# Class 36 (DS): 0.9922
# Class 37 (DS): 0.8260
# Class 38 (DS): 0.9601
# Class 39 (DS): 0.9710
# Class 40 (DS): 0.9798
# Class 41 (DS): 0.9649
# Class 42 (DS): 0.9524
# Class 43 (DS): 0.9302
# Class 44 (DS): 0.9575
# ----------
# Epoch: 3, Phase: train, epoch loss: 0.0828, Av. Dice Score: 0.9533
# Class 0 (DS): 0.9316
# Class 1 (DS): 0.9025
# Class 2 (DS): 0.9703
# Class 3 (DS): 0.9659
# Class 4 (DS): 0.9207
# Class 5 (DS): 0.9509
# Class 6 (DS): 0.9664
# Class 7 (DS): 0.9640
# Class 8 (DS): 0.9698
# Class 9 (DS): 0.9500
# Class 10 (DS): 0.9676
# Class 11 (DS): 0.9400
# Class 12 (DS): 0.9501
# Class 13 (DS): 0.9653
# Class 14 (DS): 0.9795
# Class 15 (DS): 0.9662
# Class 16 (DS): 0.9685
# Class 17 (DS): 0.9656
# Class 18 (DS): 0.9852
# Class 19 (DS): 0.8689
# Class 20 (DS): 0.9276
# Class 21 (DS): 0.9088
# Class 22 (DS): 0.9710
# Class 23 (DS): 0.9717
# Class 24 (DS): 0.9232
# Class 25 (DS): 0.9478
# Class 26 (DS): 0.9686
# Class 27 (DS): 0.9670
# Class 28 (DS): 0.9715
# Class 29 (DS): 0.9605
# Class 30 (DS): 0.9567
# Class 31 (DS): 0.9779
# Class 32 (DS): 0.9687
# Class 33 (DS): 0.9635
# Class 34 (DS): 0.9864
# Class 35 (DS): 0.8678
# Class 36 (DS): 0.9878
# Class 37 (DS): 0.8436
# Class 38 (DS): 0.9593
# Class 39 (DS): 0.9798
# Class 40 (DS): 0.9839
# Class 41 (DS): 0.9779
# Class 42 (DS): 0.9541
# Class 43 (DS): 0.9550
# Class 44 (DS): 0.9682
# ----------
# Epoch: 3, Phase: validate, epoch loss: 0.0888, Av. Dice Score: 0.9450
# Class 0 (DS): 0.9178
# Class 1 (DS): 0.8946
# Class 2 (DS): 0.9625
# Class 3 (DS): 0.9436
# Class 4 (DS): 0.9055
# Class 5 (DS): 0.9339
# Class 6 (DS): 0.9637
# Class 7 (DS): 0.9659
# Class 8 (DS): 0.9648
# Class 9 (DS): 0.9350
# Class 10 (DS): 0.9661
# Class 11 (DS): 0.9302
# Class 12 (DS): 0.9397
# Class 13 (DS): 0.9581
# Class 14 (DS): 0.9762
# Class 15 (DS): 0.9630
# Class 16 (DS): 0.9500
# Class 17 (DS): 0.9470
# Class 18 (DS): 0.9763
# Class 19 (DS): 0.8553
# Class 20 (DS): 0.9291
# Class 21 (DS): 0.8942
# Class 22 (DS): 0.9764
# Class 23 (DS): 0.9702
# Class 24 (DS): 0.9271
# Class 25 (DS): 0.9392
# Class 26 (DS): 0.9654
# Class 27 (DS): 0.9643
# Class 28 (DS): 0.9731
# Class 29 (DS): 0.9600
# Class 30 (DS): 0.9567
# Class 31 (DS): 0.9693
# Class 32 (DS): 0.9475
# Class 33 (DS): 0.9541
# Class 34 (DS): 0.9863
# Class 35 (DS): 0.8407
# Class 36 (DS): 0.9945
# Class 37 (DS): 0.8114
# Class 38 (DS): 0.9664
# Class 39 (DS): 0.9704
# Class 40 (DS): 0.9794
# Class 41 (DS): 0.9623
# Class 42 (DS): 0.9507
# Class 43 (DS): 0.9292
# Class 44 (DS): 0.9569
# ----------
# Epoch: 4, Phase: train, epoch loss: 0.0807, Av. Dice Score: 0.9537
# Class 0 (DS): 0.9333
# Class 1 (DS): 0.9033
# Class 2 (DS): 0.9700
# Class 3 (DS): 0.9670
# Class 4 (DS): 0.9237
# Class 5 (DS): 0.9504
# Class 6 (DS): 0.9682
# Class 7 (DS): 0.9642
# Class 8 (DS): 0.9675
# Class 9 (DS): 0.9508
# Class 10 (DS): 0.9663
# Class 11 (DS): 0.9457
# Class 12 (DS): 0.9486
# Class 13 (DS): 0.9656
# Class 14 (DS): 0.9806
# Class 15 (DS): 0.9667
# Class 16 (DS): 0.9668
# Class 17 (DS): 0.9643
# Class 18 (DS): 0.9863
# Class 19 (DS): 0.8650
# Class 20 (DS): 0.9343
# Class 21 (DS): 0.9106
# Class 22 (DS): 0.9733
# Class 23 (DS): 0.9729
# Class 24 (DS): 0.9298
# Class 25 (DS): 0.9466
# Class 26 (DS): 0.9702
# Class 27 (DS): 0.9685
# Class 28 (DS): 0.9711
# Class 29 (DS): 0.9585
# Class 30 (DS): 0.9558
# Class 31 (DS): 0.9770
# Class 32 (DS): 0.9670
# Class 33 (DS): 0.9642
# Class 34 (DS): 0.9844
# Class 35 (DS): 0.8661
# Class 36 (DS): 0.9904
# Class 37 (DS): 0.8476
# Class 38 (DS): 0.9611
# Class 39 (DS): 0.9807
# Class 40 (DS): 0.9834
# Class 41 (DS): 0.9762
# Class 42 (DS): 0.9517
# Class 43 (DS): 0.9526
# Class 44 (DS): 0.9693
# ----------
# Epoch: 4, Phase: validate, epoch loss: 0.0830, Av. Dice Score: 0.9489
# Class 0 (DS): 0.9212
# Class 1 (DS): 0.8992
# Class 2 (DS): 0.9659
# Class 3 (DS): 0.9493
# Class 4 (DS): 0.9132
# Class 5 (DS): 0.9371
# Class 6 (DS): 0.9664
# Class 7 (DS): 0.9668
# Class 8 (DS): 0.9721
# Class 9 (DS): 0.9356
# Class 10 (DS): 0.9665
# Class 11 (DS): 0.9365
# Class 12 (DS): 0.9425
# Class 13 (DS): 0.9575
# Class 14 (DS): 0.9768
# Class 15 (DS): 0.9661
# Class 16 (DS): 0.9559
# Class 17 (DS): 0.9510
# Class 18 (DS): 0.9781
# Class 19 (DS): 0.8711
# Class 20 (DS): 0.9329
# Class 21 (DS): 0.9022
# Class 22 (DS): 0.9755
# Class 23 (DS): 0.9706
# Class 24 (DS): 0.9337
# Class 25 (DS): 0.9410
# Class 26 (DS): 0.9672
# Class 27 (DS): 0.9682
# Class 28 (DS): 0.9772
# Class 29 (DS): 0.9614
# Class 30 (DS): 0.9603
# Class 31 (DS): 0.9719
# Class 32 (DS): 0.9459
# Class 33 (DS): 0.9570
# Class 34 (DS): 0.9876
# Class 35 (DS): 0.8510
# Class 36 (DS): 0.9933
# Class 37 (DS): 0.8401
# Class 38 (DS): 0.9666
# Class 39 (DS): 0.9733
# Class 40 (DS): 0.9797
# Class 41 (DS): 0.9653
# Class 42 (DS): 0.9528
# Class 43 (DS): 0.9375
# Class 44 (DS): 0.9612
# ----------
# Epoch: 5, Phase: train, epoch loss: 0.0784, Av. Dice Score: 0.9551
# Class 0 (DS): 0.9332
# Class 1 (DS): 0.9018
# Class 2 (DS): 0.9723
# Class 3 (DS): 0.9693
# Class 4 (DS): 0.9226
# Class 5 (DS): 0.9518
# Class 6 (DS): 0.9690
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9701
# Class 9 (DS): 0.9539
# Class 10 (DS): 0.9688
# Class 11 (DS): 0.9431
# Class 12 (DS): 0.9498
# Class 13 (DS): 0.9673
# Class 14 (DS): 0.9798
# Class 15 (DS): 0.9674
# Class 16 (DS): 0.9699
# Class 17 (DS): 0.9650
# Class 18 (DS): 0.9873
# Class 19 (DS): 0.8732
# Class 20 (DS): 0.9325
# Class 21 (DS): 0.9104
# Class 22 (DS): 0.9719
# Class 23 (DS): 0.9760
# Class 24 (DS): 0.9282
# Class 25 (DS): 0.9471
# Class 26 (DS): 0.9710
# Class 27 (DS): 0.9693
# Class 28 (DS): 0.9728
# Class 29 (DS): 0.9608
# Class 30 (DS): 0.9571
# Class 31 (DS): 0.9766
# Class 32 (DS): 0.9698
# Class 33 (DS): 0.9643
# Class 34 (DS): 0.9884
# Class 35 (DS): 0.8719
# Class 36 (DS): 0.9877
# Class 37 (DS): 0.8525
# Class 38 (DS): 0.9636
# Class 39 (DS): 0.9807
# Class 40 (DS): 0.9839
# Class 41 (DS): 0.9788
# Class 42 (DS): 0.9539
# Class 43 (DS): 0.9609
# Class 44 (DS): 0.9697
# ----------
# Epoch: 5, Phase: validate, epoch loss: 0.0851, Av. Dice Score: 0.9459
# Class 0 (DS): 0.9225
# Class 1 (DS): 0.8949
# Class 2 (DS): 0.9641
# Class 3 (DS): 0.9427
# Class 4 (DS): 0.9005
# Class 5 (DS): 0.9340
# Class 6 (DS): 0.9591
# Class 7 (DS): 0.9671
# Class 8 (DS): 0.9708
# Class 9 (DS): 0.9328
# Class 10 (DS): 0.9682
# Class 11 (DS): 0.9287
# Class 12 (DS): 0.9425
# Class 13 (DS): 0.9553
# Class 14 (DS): 0.9768
# Class 15 (DS): 0.9653
# Class 16 (DS): 0.9559
# Class 17 (DS): 0.9449
# Class 18 (DS): 0.9759
# Class 19 (DS): 0.8683
# Class 20 (DS): 0.9295
# Class 21 (DS): 0.8970
# Class 22 (DS): 0.9716
# Class 23 (DS): 0.9736
# Class 24 (DS): 0.9272
# Class 25 (DS): 0.9335
# Class 26 (DS): 0.9605
# Class 27 (DS): 0.9641
# Class 28 (DS): 0.9752
# Class 29 (DS): 0.9570
# Class 30 (DS): 0.9578
# Class 31 (DS): 0.9711
# Class 32 (DS): 0.9479
# Class 33 (DS): 0.9539
# Class 34 (DS): 0.9840
# Class 35 (DS): 0.8499
# Class 36 (DS): 0.9959
# Class 37 (DS): 0.8222
# Class 38 (DS): 0.9620
# Class 39 (DS): 0.9737
# Class 40 (DS): 0.9798
# Class 41 (DS): 0.9658
# Class 42 (DS): 0.9517
# Class 43 (DS): 0.9326
# Class 44 (DS): 0.9578
# ----------
# Epoch: 6, Phase: train, epoch loss: 0.0774, Av. Dice Score: 0.9551
# Class 0 (DS): 0.9302
# Class 1 (DS): 0.9010
# Class 2 (DS): 0.9723
# Class 3 (DS): 0.9683
# Class 4 (DS): 0.9249
# Class 5 (DS): 0.9510
# Class 6 (DS): 0.9692
# Class 7 (DS): 0.9642
# Class 8 (DS): 0.9697
# Class 9 (DS): 0.9547
# Class 10 (DS): 0.9664
# Class 11 (DS): 0.9429
# Class 12 (DS): 0.9502
# Class 13 (DS): 0.9672
# Class 14 (DS): 0.9808
# Class 15 (DS): 0.9675
# Class 16 (DS): 0.9687
# Class 17 (DS): 0.9662
# Class 18 (DS): 0.9863
# Class 19 (DS): 0.8708
# Class 20 (DS): 0.9327
# Class 21 (DS): 0.9118
# Class 22 (DS): 0.9727
# Class 23 (DS): 0.9756
# Class 24 (DS): 0.9302
# Class 25 (DS): 0.9475
# Class 26 (DS): 0.9699
# Class 27 (DS): 0.9686
# Class 28 (DS): 0.9733
# Class 29 (DS): 0.9610
# Class 30 (DS): 0.9569
# Class 31 (DS): 0.9775
# Class 32 (DS): 0.9685
# Class 33 (DS): 0.9636
# Class 34 (DS): 0.9880
# Class 35 (DS): 0.8735
# Class 36 (DS): 0.9882
# Class 37 (DS): 0.8529
# Class 38 (DS): 0.9625
# Class 39 (DS): 0.9806
# Class 40 (DS): 0.9840
# Class 41 (DS): 0.9796
# Class 42 (DS): 0.9573
# Class 43 (DS): 0.9609
# Class 44 (DS): 0.9695
# ----------
# Epoch: 6, Phase: validate, epoch loss: 0.0827, Av. Dice Score: 0.9479
# Class 0 (DS): 0.9284
# Class 1 (DS): 0.9001
# Class 2 (DS): 0.9665
# Class 3 (DS): 0.9487
# Class 4 (DS): 0.9071
# Class 5 (DS): 0.9336
# Class 6 (DS): 0.9625
# Class 7 (DS): 0.9670
# Class 8 (DS): 0.9727
# Class 9 (DS): 0.9383
# Class 10 (DS): 0.9667
# Class 11 (DS): 0.9332
# Class 12 (DS): 0.9429
# Class 13 (DS): 0.9574
# Class 14 (DS): 0.9761
# Class 15 (DS): 0.9652
# Class 16 (DS): 0.9524
# Class 17 (DS): 0.9474
# Class 18 (DS): 0.9793
# Class 19 (DS): 0.8720
# Class 20 (DS): 0.9336
# Class 21 (DS): 0.9019
# Class 22 (DS): 0.9761
# Class 23 (DS): 0.9742
# Class 24 (DS): 0.9304
# Class 25 (DS): 0.9401
# Class 26 (DS): 0.9635
# Class 27 (DS): 0.9655
# Class 28 (DS): 0.9772
# Class 29 (DS): 0.9607
# Class 30 (DS): 0.9629
# Class 31 (DS): 0.9714
# Class 32 (DS): 0.9477
# Class 33 (DS): 0.9548
# Class 34 (DS): 0.9885
# Class 35 (DS): 0.8436
# Class 36 (DS): 0.9968
# Class 37 (DS): 0.8264
# Class 38 (DS): 0.9649
# Class 39 (DS): 0.9728
# Class 40 (DS): 0.9757
# Class 41 (DS): 0.9629
# Class 42 (DS): 0.9519
# Class 43 (DS): 0.9313
# Class 44 (DS): 0.9611
# ----------
# Epoch: 7, Phase: train, epoch loss: 0.0770, Av. Dice Score: 0.9549
# Class 0 (DS): 0.9312
# Class 1 (DS): 0.9029
# Class 2 (DS): 0.9733
# Class 3 (DS): 0.9690
# Class 4 (DS): 0.9244
# Class 5 (DS): 0.9509
# Class 6 (DS): 0.9705
# Class 7 (DS): 0.9648
# Class 8 (DS): 0.9694
# Class 9 (DS): 0.9504
# Class 10 (DS): 0.9688
# Class 11 (DS): 0.9420
# Class 12 (DS): 0.9495
# Class 13 (DS): 0.9671
# Class 14 (DS): 0.9807
# Class 15 (DS): 0.9651
# Class 16 (DS): 0.9675
# Class 17 (DS): 0.9637
# Class 18 (DS): 0.9849
# Class 19 (DS): 0.8677
# Class 20 (DS): 0.9331
# Class 21 (DS): 0.9128
# Class 22 (DS): 0.9744
# Class 23 (DS): 0.9758
# Class 24 (DS): 0.9291
# Class 25 (DS): 0.9478
# Class 26 (DS): 0.9707
# Class 27 (DS): 0.9692
# Class 28 (DS): 0.9726
# Class 29 (DS): 0.9605
# Class 30 (DS): 0.9559
# Class 31 (DS): 0.9768
# Class 32 (DS): 0.9676
# Class 33 (DS): 0.9633
# Class 34 (DS): 0.9874
# Class 35 (DS): 0.8685
# Class 36 (DS): 0.9892
# Class 37 (DS): 0.8531
# Class 38 (DS): 0.9639
# Class 39 (DS): 0.9819
# Class 40 (DS): 0.9843
# Class 41 (DS): 0.9788
# Class 42 (DS): 0.9562
# Class 43 (DS): 0.9608
# Class 44 (DS): 0.9711
# ----------
# Epoch: 7, Phase: validate, epoch loss: 0.0844, Av. Dice Score: 0.9455
# Class 0 (DS): 0.9215
# Class 1 (DS): 0.9011
# Class 2 (DS): 0.9657
# Class 3 (DS): 0.9445
# Class 4 (DS): 0.9115
# Class 5 (DS): 0.9298
# Class 6 (DS): 0.9633
# Class 7 (DS): 0.9647
# Class 8 (DS): 0.9670
# Class 9 (DS): 0.9357
# Class 10 (DS): 0.9607
# Class 11 (DS): 0.9321
# Class 12 (DS): 0.9360
# Class 13 (DS): 0.9548
# Class 14 (DS): 0.9734
# Class 15 (DS): 0.9625
# Class 16 (DS): 0.9509
# Class 17 (DS): 0.9497
# Class 18 (DS): 0.9782
# Class 19 (DS): 0.8620
# Class 20 (DS): 0.9250
# Class 21 (DS): 0.9012
# Class 22 (DS): 0.9750
# Class 23 (DS): 0.9710
# Class 24 (DS): 0.9312
# Class 25 (DS): 0.9333
# Class 26 (DS): 0.9651
# Class 27 (DS): 0.9661
# Class 28 (DS): 0.9718
# Class 29 (DS): 0.9571
# Class 30 (DS): 0.9577
# Class 31 (DS): 0.9710
# Class 32 (DS): 0.9441
# Class 33 (DS): 0.9545
# Class 34 (DS): 0.9872
# Class 35 (DS): 0.8388
# Class 36 (DS): 0.9946
# Class 37 (DS): 0.8299
# Class 38 (DS): 0.9571
# Class 39 (DS): 0.9711
# Class 40 (DS): 0.9798
# Class 41 (DS): 0.9636
# Class 42 (DS): 0.9495
# Class 43 (DS): 0.9328
# Class 44 (DS): 0.9543
# ----------
# Epoch: 8, Phase: train, epoch loss: 0.0759, Av. Dice Score: 0.9553
# Class 0 (DS): 0.9333
# Class 1 (DS): 0.9059
# Class 2 (DS): 0.9719
# Class 3 (DS): 0.9703
# Class 4 (DS): 0.9259
# Class 5 (DS): 0.9528
# Class 6 (DS): 0.9695
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9699
# Class 9 (DS): 0.9536
# Class 10 (DS): 0.9678
# Class 11 (DS): 0.9430
# Class 12 (DS): 0.9508
# Class 13 (DS): 0.9667
# Class 14 (DS): 0.9810
# Class 15 (DS): 0.9682
# Class 16 (DS): 0.9704
# Class 17 (DS): 0.9660
# Class 18 (DS): 0.9870
# Class 19 (DS): 0.8728
# Class 20 (DS): 0.9342
# Class 21 (DS): 0.9120
# Class 22 (DS): 0.9724
# Class 23 (DS): 0.9771
# Class 24 (DS): 0.9299
# Class 25 (DS): 0.9464
# Class 26 (DS): 0.9711
# Class 27 (DS): 0.9684
# Class 28 (DS): 0.9747
# Class 29 (DS): 0.9609
# Class 30 (DS): 0.9569
# Class 31 (DS): 0.9778
# Class 32 (DS): 0.9699
# Class 33 (DS): 0.9652
# Class 34 (DS): 0.9874
# Class 35 (DS): 0.8696
# Class 36 (DS): 0.9871
# Class 37 (DS): 0.8494
# Class 38 (DS): 0.9602
# Class 39 (DS): 0.9815
# Class 40 (DS): 0.9846
# Class 41 (DS): 0.9789
# Class 42 (DS): 0.9533
# Class 43 (DS): 0.9587
# Class 44 (DS): 0.9699
# ----------
# Epoch: 8, Phase: validate, epoch loss: 0.0825, Av. Dice Score: 0.9471
# Class 0 (DS): 0.9199
# Class 1 (DS): 0.9020
# Class 2 (DS): 0.9652
# Class 3 (DS): 0.9436
# Class 4 (DS): 0.9112
# Class 5 (DS): 0.9348
# Class 6 (DS): 0.9639
# Class 7 (DS): 0.9658
# Class 8 (DS): 0.9716
# Class 9 (DS): 0.9310
# Class 10 (DS): 0.9649
# Class 11 (DS): 0.9316
# Class 12 (DS): 0.9435
# Class 13 (DS): 0.9564
# Class 14 (DS): 0.9753
# Class 15 (DS): 0.9676
# Class 16 (DS): 0.9570
# Class 17 (DS): 0.9524
# Class 18 (DS): 0.9783
# Class 19 (DS): 0.8716
# Class 20 (DS): 0.9273
# Class 21 (DS): 0.9024
# Class 22 (DS): 0.9738
# Class 23 (DS): 0.9723
# Class 24 (DS): 0.9193
# Class 25 (DS): 0.9367
# Class 26 (DS): 0.9660
# Class 27 (DS): 0.9607
# Class 28 (DS): 0.9749
# Class 29 (DS): 0.9582
# Class 30 (DS): 0.9597
# Class 31 (DS): 0.9707
# Class 32 (DS): 0.9505
# Class 33 (DS): 0.9619
# Class 34 (DS): 0.9870
# Class 35 (DS): 0.8505
# Class 36 (DS): 0.9963
# Class 37 (DS): 0.8351
# Class 38 (DS): 0.9566
# Class 39 (DS): 0.9730
# Class 40 (DS): 0.9785
# Class 41 (DS): 0.9642
# Class 42 (DS): 0.9469
# Class 43 (DS): 0.9304
# Class 44 (DS): 0.9577
# ----------
# Epoch: 9, Phase: train, epoch loss: 0.0750, Av. Dice Score: 0.9554
# Class 0 (DS): 0.9311
# Class 1 (DS): 0.9018
# Class 2 (DS): 0.9716
# Class 3 (DS): 0.9696
# Class 4 (DS): 0.9264
# Class 5 (DS): 0.9503
# Class 6 (DS): 0.9702
# Class 7 (DS): 0.9662
# Class 8 (DS): 0.9702
# Class 9 (DS): 0.9548
# Class 10 (DS): 0.9680
# Class 11 (DS): 0.9416
# Class 12 (DS): 0.9523
# Class 13 (DS): 0.9679
# Class 14 (DS): 0.9806
# Class 15 (DS): 0.9680
# Class 16 (DS): 0.9697
# Class 17 (DS): 0.9668
# Class 18 (DS): 0.9868
# Class 19 (DS): 0.8703
# Class 20 (DS): 0.9334
# Class 21 (DS): 0.9156
# Class 22 (DS): 0.9733
# Class 23 (DS): 0.9743
# Class 24 (DS): 0.9302
# Class 25 (DS): 0.9472
# Class 26 (DS): 0.9721
# Class 27 (DS): 0.9710
# Class 28 (DS): 0.9736
# Class 29 (DS): 0.9617
# Class 30 (DS): 0.9574
# Class 31 (DS): 0.9761
# Class 32 (DS): 0.9689
# Class 33 (DS): 0.9656
# Class 34 (DS): 0.9878
# Class 35 (DS): 0.8695
# Class 36 (DS): 0.9881
# Class 37 (DS): 0.8559
# Class 38 (DS): 0.9636
# Class 39 (DS): 0.9804
# Class 40 (DS): 0.9836
# Class 41 (DS): 0.9782
# Class 42 (DS): 0.9553
# Class 43 (DS): 0.9576
# Class 44 (DS): 0.9704
# ----------
# Epoch: 9, Phase: validate, epoch loss: 0.0812, Av. Dice Score: 0.9484
# Class 0 (DS): 0.9180
# Class 1 (DS): 0.9024
# Class 2 (DS): 0.9640
# Class 3 (DS): 0.9466
# Class 4 (DS): 0.9107
# Class 5 (DS): 0.9380
# Class 6 (DS): 0.9666
# Class 7 (DS): 0.9692
# Class 8 (DS): 0.9715
# Class 9 (DS): 0.9349
# Class 10 (DS): 0.9671
# Class 11 (DS): 0.9339
# Class 12 (DS): 0.9411
# Class 13 (DS): 0.9579
# Class 14 (DS): 0.9709
# Class 15 (DS): 0.9692
# Class 16 (DS): 0.9590
# Class 17 (DS): 0.9525
# Class 18 (DS): 0.9773
# Class 19 (DS): 0.8707
# Class 20 (DS): 0.9256
# Class 21 (DS): 0.8980
# Class 22 (DS): 0.9748
# Class 23 (DS): 0.9693
# Class 24 (DS): 0.9277
# Class 25 (DS): 0.9394
# Class 26 (DS): 0.9666
# Class 27 (DS): 0.9661
# Class 28 (DS): 0.9726
# Class 29 (DS): 0.9636
# Class 30 (DS): 0.9578
# Class 31 (DS): 0.9714
# Class 32 (DS): 0.9530
# Class 33 (DS): 0.9607
# Class 34 (DS): 0.9861
# Class 35 (DS): 0.8504
# Class 36 (DS): 0.9979
# Class 37 (DS): 0.8360
# Class 38 (DS): 0.9645
# Class 39 (DS): 0.9709
# Class 40 (DS): 0.9815
# Class 41 (DS): 0.9677
# Class 42 (DS): 0.9496
# Class 43 (DS): 0.9432
# Class 44 (DS): 0.9622
# ----------
# Epoch: 10, Phase: train, epoch loss: 0.0746, Av. Dice Score: 0.9548
# Class 0 (DS): 0.9308
# Class 1 (DS): 0.9066
# Class 2 (DS): 0.9731
# Class 3 (DS): 0.9699
# Class 4 (DS): 0.9243
# Class 5 (DS): 0.9492
# Class 6 (DS): 0.9680
# Class 7 (DS): 0.9643
# Class 8 (DS): 0.9693
# Class 9 (DS): 0.9524
# Class 10 (DS): 0.9668
# Class 11 (DS): 0.9435
# Class 12 (DS): 0.9494
# Class 13 (DS): 0.9673
# Class 14 (DS): 0.9806
# Class 15 (DS): 0.9671
# Class 16 (DS): 0.9670
# Class 17 (DS): 0.9634
# Class 18 (DS): 0.9875
# Class 19 (DS): 0.8708
# Class 20 (DS): 0.9330
# Class 21 (DS): 0.9154
# Class 22 (DS): 0.9723
# Class 23 (DS): 0.9777
# Class 24 (DS): 0.9289
# Class 25 (DS): 0.9457
# Class 26 (DS): 0.9702
# Class 27 (DS): 0.9707
# Class 28 (DS): 0.9730
# Class 29 (DS): 0.9623
# Class 30 (DS): 0.9572
# Class 31 (DS): 0.9788
# Class 32 (DS): 0.9676
# Class 33 (DS): 0.9638
# Class 34 (DS): 0.9858
# Class 35 (DS): 0.8693
# Class 36 (DS): 0.9874
# Class 37 (DS): 0.8513
# Class 38 (DS): 0.9601
# Class 39 (DS): 0.9807
# Class 40 (DS): 0.9849
# Class 41 (DS): 0.9782
# Class 42 (DS): 0.9532
# Class 43 (DS): 0.9559
# Class 44 (DS): 0.9691
# ----------
# Epoch: 10, Phase: validate, epoch loss: 0.0814, Av. Dice Score: 0.9479
# Class 0 (DS): 0.9227
# Class 1 (DS): 0.8979
# Class 2 (DS): 0.9649
# Class 3 (DS): 0.9477
# Class 4 (DS): 0.9135
# Class 5 (DS): 0.9424
# Class 6 (DS): 0.9641
# Class 7 (DS): 0.9639
# Class 8 (DS): 0.9713
# Class 9 (DS): 0.9367
# Class 10 (DS): 0.9640
# Class 11 (DS): 0.9373
# Class 12 (DS): 0.9437
# Class 13 (DS): 0.9555
# Class 14 (DS): 0.9751
# Class 15 (DS): 0.9666
# Class 16 (DS): 0.9598
# Class 17 (DS): 0.9544
# Class 18 (DS): 0.9789
# Class 19 (DS): 0.8742
# Class 20 (DS): 0.9247
# Class 21 (DS): 0.8940
# Class 22 (DS): 0.9761
# Class 23 (DS): 0.9720
# Class 24 (DS): 0.9276
# Class 25 (DS): 0.9400
# Class 26 (DS): 0.9648
# Class 27 (DS): 0.9615
# Class 28 (DS): 0.9773
# Class 29 (DS): 0.9587
# Class 30 (DS): 0.9596
# Class 31 (DS): 0.9728
# Class 32 (DS): 0.9542
# Class 33 (DS): 0.9606
# Class 34 (DS): 0.9882
# Class 35 (DS): 0.8512
# Class 36 (DS): 0.9960
# Class 37 (DS): 0.8298
# Class 38 (DS): 0.9608
# Class 39 (DS): 0.9751
# Class 40 (DS): 0.9777
# Class 41 (DS): 0.9607
# Class 42 (DS): 0.9462
# Class 43 (DS): 0.9351
# Class 44 (DS): 0.9563
# ----------
# Epoch: 11, Phase: train, epoch loss: 0.0742, Av. Dice Score: 0.9549
# Class 0 (DS): 0.9343
# Class 1 (DS): 0.8998
# Class 2 (DS): 0.9702
# Class 3 (DS): 0.9695
# Class 4 (DS): 0.9245
# Class 5 (DS): 0.9507
# Class 6 (DS): 0.9695
# Class 7 (DS): 0.9641
# Class 8 (DS): 0.9692
# Class 9 (DS): 0.9556
# Class 10 (DS): 0.9662
# Class 11 (DS): 0.9407
# Class 12 (DS): 0.9522
# Class 13 (DS): 0.9667
# Class 14 (DS): 0.9804
# Class 15 (DS): 0.9677
# Class 16 (DS): 0.9641
# Class 17 (DS): 0.9635
# Class 18 (DS): 0.9863
# Class 19 (DS): 0.8709
# Class 20 (DS): 0.9335
# Class 21 (DS): 0.9141
# Class 22 (DS): 0.9731
# Class 23 (DS): 0.9763
# Class 24 (DS): 0.9278
# Class 25 (DS): 0.9470
# Class 26 (DS): 0.9705
# Class 27 (DS): 0.9684
# Class 28 (DS): 0.9735
# Class 29 (DS): 0.9615
# Class 30 (DS): 0.9578
# Class 31 (DS): 0.9775
# Class 32 (DS): 0.9669
# Class 33 (DS): 0.9635
# Class 34 (DS): 0.9866
# Class 35 (DS): 0.8676
# Class 36 (DS): 0.9878
# Class 37 (DS): 0.8551
# Class 38 (DS): 0.9649
# Class 39 (DS): 0.9799
# Class 40 (DS): 0.9851
# Class 41 (DS): 0.9802
# Class 42 (DS): 0.9562
# Class 43 (DS): 0.9608
# Class 44 (DS): 0.9704
# ----------
# Epoch: 11, Phase: validate, epoch loss: 0.0806, Av. Dice Score: 0.9469
# Class 0 (DS): 0.9278
# Class 1 (DS): 0.8958
# Class 2 (DS): 0.9659
# Class 3 (DS): 0.9419
# Class 4 (DS): 0.9039
# Class 5 (DS): 0.9320
# Class 6 (DS): 0.9659
# Class 7 (DS): 0.9664
# Class 8 (DS): 0.9683
# Class 9 (DS): 0.9342
# Class 10 (DS): 0.9647
# Class 11 (DS): 0.9358
# Class 12 (DS): 0.9442
# Class 13 (DS): 0.9562
# Class 14 (DS): 0.9724
# Class 15 (DS): 0.9693
# Class 16 (DS): 0.9533
# Class 17 (DS): 0.9470
# Class 18 (DS): 0.9744
# Class 19 (DS): 0.8650
# Class 20 (DS): 0.9265
# Class 21 (DS): 0.8932
# Class 22 (DS): 0.9753
# Class 23 (DS): 0.9755
# Class 24 (DS): 0.9259
# Class 25 (DS): 0.9373
# Class 26 (DS): 0.9659
# Class 27 (DS): 0.9648
# Class 28 (DS): 0.9711
# Class 29 (DS): 0.9581
# Class 30 (DS): 0.9585
# Class 31 (DS): 0.9683
# Class 32 (DS): 0.9446
# Class 33 (DS): 0.9537
# Class 34 (DS): 0.9869
# Class 35 (DS): 0.8448
# Class 36 (DS): 0.9956
# Class 37 (DS): 0.8373
# Class 38 (DS): 0.9690
# Class 39 (DS): 0.9670
# Class 40 (DS): 0.9787
# Class 41 (DS): 0.9670
# Class 42 (DS): 0.9571
# Class 43 (DS): 0.9478
# Class 44 (DS): 0.9551
# ----------
# Epoch: 12, Phase: train, epoch loss: 0.0744, Av. Dice Score: 0.9547
# Class 0 (DS): 0.9307
# Class 1 (DS): 0.9004
# Class 2 (DS): 0.9703
# Class 3 (DS): 0.9695
# Class 4 (DS): 0.9231
# Class 5 (DS): 0.9519
# Class 6 (DS): 0.9683
# Class 7 (DS): 0.9641
# Class 8 (DS): 0.9701
# Class 9 (DS): 0.9534
# Class 10 (DS): 0.9651
# Class 11 (DS): 0.9431
# Class 12 (DS): 0.9462
# Class 13 (DS): 0.9673
# Class 14 (DS): 0.9799
# Class 15 (DS): 0.9684
# Class 16 (DS): 0.9681
# Class 17 (DS): 0.9654
# Class 18 (DS): 0.9861
# Class 19 (DS): 0.8696
# Class 20 (DS): 0.9342
# Class 21 (DS): 0.9088
# Class 22 (DS): 0.9724
# Class 23 (DS): 0.9749
# Class 24 (DS): 0.9290
# Class 25 (DS): 0.9471
# Class 26 (DS): 0.9686
# Class 27 (DS): 0.9683
# Class 28 (DS): 0.9744
# Class 29 (DS): 0.9615
# Class 30 (DS): 0.9588
# Class 31 (DS): 0.9769
# Class 32 (DS): 0.9683
# Class 33 (DS): 0.9660
# Class 34 (DS): 0.9871
# Class 35 (DS): 0.8698
# Class 36 (DS): 0.9881
# Class 37 (DS): 0.8512
# Class 38 (DS): 0.9622
# Class 39 (DS): 0.9810
# Class 40 (DS): 0.9839
# Class 41 (DS): 0.9791
# Class 42 (DS): 0.9560
# Class 43 (DS): 0.9587
# Class 44 (DS): 0.9721
# ----------
# Epoch: 12, Phase: validate, epoch loss: 0.0810, Av. Dice Score: 0.9490
# Class 0 (DS): 0.9260
# Class 1 (DS): 0.9042
# Class 2 (DS): 0.9674
# Class 3 (DS): 0.9492
# Class 4 (DS): 0.9198
# Class 5 (DS): 0.9360
# Class 6 (DS): 0.9626
# Class 7 (DS): 0.9648
# Class 8 (DS): 0.9706
# Class 9 (DS): 0.9331
# Class 10 (DS): 0.9671
# Class 11 (DS): 0.9400
# Class 12 (DS): 0.9465
# Class 13 (DS): 0.9570
# Class 14 (DS): 0.9726
# Class 15 (DS): 0.9693
# Class 16 (DS): 0.9545
# Class 17 (DS): 0.9537
# Class 18 (DS): 0.9783
# Class 19 (DS): 0.8751
# Class 20 (DS): 0.9242
# Class 21 (DS): 0.9055
# Class 22 (DS): 0.9734
# Class 23 (DS): 0.9752
# Class 24 (DS): 0.9304
# Class 25 (DS): 0.9388
# Class 26 (DS): 0.9624
# Class 27 (DS): 0.9608
# Class 28 (DS): 0.9759
# Class 29 (DS): 0.9619
# Class 30 (DS): 0.9605
# Class 31 (DS): 0.9734
# Class 32 (DS): 0.9444
# Class 33 (DS): 0.9609
# Class 34 (DS): 0.9875
# Class 35 (DS): 0.8598
# Class 36 (DS): 0.9979
# Class 37 (DS): 0.8303
# Class 38 (DS): 0.9626
# Class 39 (DS): 0.9773
# Class 40 (DS): 0.9775
# Class 41 (DS): 0.9658
# Class 42 (DS): 0.9495
# Class 43 (DS): 0.9417
# Class 44 (DS): 0.9600
# ----------
# Epoch: 13, Phase: train, epoch loss: 0.0735, Av. Dice Score: 0.9547
# Class 0 (DS): 0.9324
# Class 1 (DS): 0.9055
# Class 2 (DS): 0.9723
# Class 3 (DS): 0.9633
# Class 4 (DS): 0.9264
# Class 5 (DS): 0.9485
# Class 6 (DS): 0.9694
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9692
# Class 9 (DS): 0.9532
# Class 10 (DS): 0.9670
# Class 11 (DS): 0.9431
# Class 12 (DS): 0.9468
# Class 13 (DS): 0.9659
# Class 14 (DS): 0.9810
# Class 15 (DS): 0.9686
# Class 16 (DS): 0.9665
# Class 17 (DS): 0.9637
# Class 18 (DS): 0.9864
# Class 19 (DS): 0.8720
# Class 20 (DS): 0.9308
# Class 21 (DS): 0.9131
# Class 22 (DS): 0.9738
# Class 23 (DS): 0.9747
# Class 24 (DS): 0.9319
# Class 25 (DS): 0.9439
# Class 26 (DS): 0.9709
# Class 27 (DS): 0.9688
# Class 28 (DS): 0.9733
# Class 29 (DS): 0.9603
# Class 30 (DS): 0.9582
# Class 31 (DS): 0.9784
# Class 32 (DS): 0.9663
# Class 33 (DS): 0.9641
# Class 34 (DS): 0.9887
# Class 35 (DS): 0.8691
# Class 36 (DS): 0.9870
# Class 37 (DS): 0.8511
# Class 38 (DS): 0.9613
# Class 39 (DS): 0.9803
# Class 40 (DS): 0.9839
# Class 41 (DS): 0.9781
# Class 42 (DS): 0.9587
# Class 43 (DS): 0.9594
# Class 44 (DS): 0.9679
# ----------
# Epoch: 13, Phase: validate, epoch loss: 0.0777, Av. Dice Score: 0.9498
# Class 0 (DS): 0.9254
# Class 1 (DS): 0.8976
# Class 2 (DS): 0.9704
# Class 3 (DS): 0.9483
# Class 4 (DS): 0.9151
# Class 5 (DS): 0.9358
# Class 6 (DS): 0.9639
# Class 7 (DS): 0.9664
# Class 8 (DS): 0.9709
# Class 9 (DS): 0.9392
# Class 10 (DS): 0.9677
# Class 11 (DS): 0.9372
# Class 12 (DS): 0.9454
# Class 13 (DS): 0.9590
# Class 14 (DS): 0.9747
# Class 15 (DS): 0.9706
# Class 16 (DS): 0.9605
# Class 17 (DS): 0.9541
# Class 18 (DS): 0.9777
# Class 19 (DS): 0.8693
# Class 20 (DS): 0.9342
# Class 21 (DS): 0.9010
# Class 22 (DS): 0.9750
# Class 23 (DS): 0.9742
# Class 24 (DS): 0.9266
# Class 25 (DS): 0.9407
# Class 26 (DS): 0.9665
# Class 27 (DS): 0.9655
# Class 28 (DS): 0.9734
# Class 29 (DS): 0.9608
# Class 30 (DS): 0.9619
# Class 31 (DS): 0.9745
# Class 32 (DS): 0.9491
# Class 33 (DS): 0.9618
# Class 34 (DS): 0.9894
# Class 35 (DS): 0.8614
# Class 36 (DS): 0.9959
# Class 37 (DS): 0.8337
# Class 38 (DS): 0.9646
# Class 39 (DS): 0.9761
# Class 40 (DS): 0.9801
# Class 41 (DS): 0.9641
# Class 42 (DS): 0.9511
# Class 43 (DS): 0.9485
# Class 44 (DS): 0.9602
# ----------
# Epoch: 14, Phase: train, epoch loss: 0.0723, Av. Dice Score: 0.9559
# Class 0 (DS): 0.9337
# Class 1 (DS): 0.9038
# Class 2 (DS): 0.9723
# Class 3 (DS): 0.9706
# Class 4 (DS): 0.9272
# Class 5 (DS): 0.9532
# Class 6 (DS): 0.9682
# Class 7 (DS): 0.9661
# Class 8 (DS): 0.9715
# Class 9 (DS): 0.9543
# Class 10 (DS): 0.9677
# Class 11 (DS): 0.9415
# Class 12 (DS): 0.9510
# Class 13 (DS): 0.9695
# Class 14 (DS): 0.9806
# Class 15 (DS): 0.9690
# Class 16 (DS): 0.9650
# Class 17 (DS): 0.9667
# Class 18 (DS): 0.9871
# Class 19 (DS): 0.8752
# Class 20 (DS): 0.9344
# Class 21 (DS): 0.9098
# Class 22 (DS): 0.9739
# Class 23 (DS): 0.9768
# Class 24 (DS): 0.9317
# Class 25 (DS): 0.9506
# Class 26 (DS): 0.9698
# Class 27 (DS): 0.9672
# Class 28 (DS): 0.9750
# Class 29 (DS): 0.9611
# Class 30 (DS): 0.9597
# Class 31 (DS): 0.9778
# Class 32 (DS): 0.9682
# Class 33 (DS): 0.9652
# Class 34 (DS): 0.9869
# Class 35 (DS): 0.8767
# Class 36 (DS): 0.9884
# Class 37 (DS): 0.8533
# Class 38 (DS): 0.9619
# Class 39 (DS): 0.9812
# Class 40 (DS): 0.9851
# Class 41 (DS): 0.9804
# Class 42 (DS): 0.9563
# Class 43 (DS): 0.9605
# Class 44 (DS): 0.9701
# ----------
# Epoch: 14, Phase: validate, epoch loss: 0.0778, Av. Dice Score: 0.9497
# Class 0 (DS): 0.9201
# Class 1 (DS): 0.9055
# Class 2 (DS): 0.9680
# Class 3 (DS): 0.9508
# Class 4 (DS): 0.9157
# Class 5 (DS): 0.9389
# Class 6 (DS): 0.9651
# Class 7 (DS): 0.9665
# Class 8 (DS): 0.9732
# Class 9 (DS): 0.9392
# Class 10 (DS): 0.9668
# Class 11 (DS): 0.9393
# Class 12 (DS): 0.9419
# Class 13 (DS): 0.9596
# Class 14 (DS): 0.9714
# Class 15 (DS): 0.9665
# Class 16 (DS): 0.9569
# Class 17 (DS): 0.9496
# Class 18 (DS): 0.9788
# Class 19 (DS): 0.8702
# Class 20 (DS): 0.9232
# Class 21 (DS): 0.9026
# Class 22 (DS): 0.9765
# Class 23 (DS): 0.9755
# Class 24 (DS): 0.9332
# Class 25 (DS): 0.9386
# Class 26 (DS): 0.9665
# Class 27 (DS): 0.9665
# Class 28 (DS): 0.9776
# Class 29 (DS): 0.9600
# Class 30 (DS): 0.9598
# Class 31 (DS): 0.9741
# Class 32 (DS): 0.9523
# Class 33 (DS): 0.9554
# Class 34 (DS): 0.9880
# Class 35 (DS): 0.8531
# Class 36 (DS): 0.9963
# Class 37 (DS): 0.8450
# Class 38 (DS): 0.9629
# Class 39 (DS): 0.9741
# Class 40 (DS): 0.9833
# Class 41 (DS): 0.9710
# Class 42 (DS): 0.9510
# Class 43 (DS): 0.9451
# Class 44 (DS): 0.9590
# ----------
# Epoch: 15, Phase: train, epoch loss: 0.0727, Av. Dice Score: 0.9549
# Class 0 (DS): 0.9307
# Class 1 (DS): 0.9015
# Class 2 (DS): 0.9719
# Class 3 (DS): 0.9689
# Class 4 (DS): 0.9232
# Class 5 (DS): 0.9478
# Class 6 (DS): 0.9691
# Class 7 (DS): 0.9655
# Class 8 (DS): 0.9692
# Class 9 (DS): 0.9539
# Class 10 (DS): 0.9671
# Class 11 (DS): 0.9430
# Class 12 (DS): 0.9478
# Class 13 (DS): 0.9669
# Class 14 (DS): 0.9787
# Class 15 (DS): 0.9690
# Class 16 (DS): 0.9676
# Class 17 (DS): 0.9640
# Class 18 (DS): 0.9882
# Class 19 (DS): 0.8714
# Class 20 (DS): 0.9316
# Class 21 (DS): 0.9075
# Class 22 (DS): 0.9744
# Class 23 (DS): 0.9771
# Class 24 (DS): 0.9302
# Class 25 (DS): 0.9447
# Class 26 (DS): 0.9700
# Class 27 (DS): 0.9715
# Class 28 (DS): 0.9731
# Class 29 (DS): 0.9634
# Class 30 (DS): 0.9586
# Class 31 (DS): 0.9779
# Class 32 (DS): 0.9680
# Class 33 (DS): 0.9656
# Class 34 (DS): 0.9883
# Class 35 (DS): 0.8729
# Class 36 (DS): 0.9882
# Class 37 (DS): 0.8530
# Class 38 (DS): 0.9638
# Class 39 (DS): 0.9784
# Class 40 (DS): 0.9841
# Class 41 (DS): 0.9790
# Class 42 (DS): 0.9551
# Class 43 (DS): 0.9599
# Class 44 (DS): 0.9690
# ----------
# Epoch: 15, Phase: validate, epoch loss: 0.0800, Av. Dice Score: 0.9473
# Class 0 (DS): 0.9235
# Class 1 (DS): 0.8976
# Class 2 (DS): 0.9673
# Class 3 (DS): 0.9485
# Class 4 (DS): 0.9076
# Class 5 (DS): 0.9371
# Class 6 (DS): 0.9623
# Class 7 (DS): 0.9644
# Class 8 (DS): 0.9703
# Class 9 (DS): 0.9344
# Class 10 (DS): 0.9686
# Class 11 (DS): 0.9376
# Class 12 (DS): 0.9406
# Class 13 (DS): 0.9555
# Class 14 (DS): 0.9740
# Class 15 (DS): 0.9636
# Class 16 (DS): 0.9528
# Class 17 (DS): 0.9457
# Class 18 (DS): 0.9753
# Class 19 (DS): 0.8725
# Class 20 (DS): 0.9272
# Class 21 (DS): 0.8967
# Class 22 (DS): 0.9762
# Class 23 (DS): 0.9749
# Class 24 (DS): 0.9236
# Class 25 (DS): 0.9361
# Class 26 (DS): 0.9638
# Class 27 (DS): 0.9627
# Class 28 (DS): 0.9740
# Class 29 (DS): 0.9586
# Class 30 (DS): 0.9574
# Class 31 (DS): 0.9713
# Class 32 (DS): 0.9467
# Class 33 (DS): 0.9558
# Class 34 (DS): 0.9858
# Class 35 (DS): 0.8509
# Class 36 (DS): 0.9967
# Class 37 (DS): 0.8278
# Class 38 (DS): 0.9647
# Class 39 (DS): 0.9729
# Class 40 (DS): 0.9812
# Class 41 (DS): 0.9667
# Class 42 (DS): 0.9517
# Class 43 (DS): 0.9475
# Class 44 (DS): 0.9585
# ----------
# Epoch: 16, Phase: train, epoch loss: 0.0718, Av. Dice Score: 0.9552
# Class 0 (DS): 0.9312
# Class 1 (DS): 0.9040
# Class 2 (DS): 0.9707
# Class 3 (DS): 0.9693
# Class 4 (DS): 0.9247
# Class 5 (DS): 0.9502
# Class 6 (DS): 0.9693
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9695
# Class 9 (DS): 0.9547
# Class 10 (DS): 0.9673
# Class 11 (DS): 0.9448
# Class 12 (DS): 0.9458
# Class 13 (DS): 0.9662
# Class 14 (DS): 0.9812
# Class 15 (DS): 0.9687
# Class 16 (DS): 0.9686
# Class 17 (DS): 0.9650
# Class 18 (DS): 0.9871
# Class 19 (DS): 0.8713
# Class 20 (DS): 0.9328
# Class 21 (DS): 0.9058
# Class 22 (DS): 0.9722
# Class 23 (DS): 0.9753
# Class 24 (DS): 0.9280
# Class 25 (DS): 0.9425
# Class 26 (DS): 0.9715
# Class 27 (DS): 0.9691
# Class 28 (DS): 0.9737
# Class 29 (DS): 0.9619
# Class 30 (DS): 0.9607
# Class 31 (DS): 0.9777
# Class 32 (DS): 0.9698
# Class 33 (DS): 0.9662
# Class 34 (DS): 0.9879
# Class 35 (DS): 0.8739
# Class 36 (DS): 0.9891
# Class 37 (DS): 0.8524
# Class 38 (DS): 0.9648
# Class 39 (DS): 0.9817
# Class 40 (DS): 0.9855
# Class 41 (DS): 0.9799
# Class 42 (DS): 0.9564
# Class 43 (DS): 0.9591
# Class 44 (DS): 0.9695
# ----------
# Epoch: 16, Phase: validate, epoch loss: 0.0799, Av. Dice Score: 0.9486
# Class 0 (DS): 0.9266
# Class 1 (DS): 0.9034
# Class 2 (DS): 0.9620
# Class 3 (DS): 0.9434
# Class 4 (DS): 0.9118
# Class 5 (DS): 0.9400
# Class 6 (DS): 0.9595
# Class 7 (DS): 0.9671
# Class 8 (DS): 0.9695
# Class 9 (DS): 0.9412
# Class 10 (DS): 0.9642
# Class 11 (DS): 0.9355
# Class 12 (DS): 0.9385
# Class 13 (DS): 0.9540
# Class 14 (DS): 0.9716
# Class 15 (DS): 0.9653
# Class 16 (DS): 0.9587
# Class 17 (DS): 0.9526
# Class 18 (DS): 0.9779
# Class 19 (DS): 0.8740
# Class 20 (DS): 0.9292
# Class 21 (DS): 0.9027
# Class 22 (DS): 0.9761
# Class 23 (DS): 0.9727
# Class 24 (DS): 0.9245
# Class 25 (DS): 0.9353
# Class 26 (DS): 0.9661
# Class 27 (DS): 0.9621
# Class 28 (DS): 0.9749
# Class 29 (DS): 0.9559
# Class 30 (DS): 0.9574
# Class 31 (DS): 0.9717
# Class 32 (DS): 0.9528
# Class 33 (DS): 0.9575
# Class 34 (DS): 0.9891
# Class 35 (DS): 0.8608
# Class 36 (DS): 0.9961
# Class 37 (DS): 0.8418
# Class 38 (DS): 0.9635
# Class 39 (DS): 0.9770
# Class 40 (DS): 0.9779
# Class 41 (DS): 0.9665
# Class 42 (DS): 0.9521
# Class 43 (DS): 0.9482
# Class 44 (DS): 0.9586
# ----------
# Epoch: 17, Phase: train, epoch loss: 0.0720, Av. Dice Score: 0.9552
# Class 0 (DS): 0.9295
# Class 1 (DS): 0.9035
# Class 2 (DS): 0.9726
# Class 3 (DS): 0.9693
# Class 4 (DS): 0.9234
# Class 5 (DS): 0.9508
# Class 6 (DS): 0.9681
# Class 7 (DS): 0.9653
# Class 8 (DS): 0.9701
# Class 9 (DS): 0.9549
# Class 10 (DS): 0.9663
# Class 11 (DS): 0.9415
# Class 12 (DS): 0.9506
# Class 13 (DS): 0.9686
# Class 14 (DS): 0.9799
# Class 15 (DS): 0.9660
# Class 16 (DS): 0.9686
# Class 17 (DS): 0.9672
# Class 18 (DS): 0.9870
# Class 19 (DS): 0.8718
# Class 20 (DS): 0.9296
# Class 21 (DS): 0.9110
# Class 22 (DS): 0.9731
# Class 23 (DS): 0.9789
# Class 24 (DS): 0.9296
# Class 25 (DS): 0.9478
# Class 26 (DS): 0.9726
# Class 27 (DS): 0.9694
# Class 28 (DS): 0.9732
# Class 29 (DS): 0.9609
# Class 30 (DS): 0.9602
# Class 31 (DS): 0.9769
# Class 32 (DS): 0.9716
# Class 33 (DS): 0.9664
# Class 34 (DS): 0.9874
# Class 35 (DS): 0.8694
# Class 36 (DS): 0.9885
# Class 37 (DS): 0.8528
# Class 38 (DS): 0.9625
# Class 39 (DS): 0.9811
# Class 40 (DS): 0.9841
# Class 41 (DS): 0.9774
# Class 42 (DS): 0.9550
# Class 43 (DS): 0.9576
# Class 44 (DS): 0.9714
# ----------
# Epoch: 17, Phase: validate, epoch loss: 0.0805, Av. Dice Score: 0.9464
# Class 0 (DS): 0.9193
# Class 1 (DS): 0.9036
# Class 2 (DS): 0.9627
# Class 3 (DS): 0.9407
# Class 4 (DS): 0.9025
# Class 5 (DS): 0.9334
# Class 6 (DS): 0.9636
# Class 7 (DS): 0.9631
# Class 8 (DS): 0.9738
# Class 9 (DS): 0.9342
# Class 10 (DS): 0.9711
# Class 11 (DS): 0.9326
# Class 12 (DS): 0.9310
# Class 13 (DS): 0.9569
# Class 14 (DS): 0.9733
# Class 15 (DS): 0.9663
# Class 16 (DS): 0.9527
# Class 17 (DS): 0.9525
# Class 18 (DS): 0.9736
# Class 19 (DS): 0.8666
# Class 20 (DS): 0.9294
# Class 21 (DS): 0.8988
# Class 22 (DS): 0.9729
# Class 23 (DS): 0.9736
# Class 24 (DS): 0.9213
# Class 25 (DS): 0.9349
# Class 26 (DS): 0.9619
# Class 27 (DS): 0.9641
# Class 28 (DS): 0.9766
# Class 29 (DS): 0.9579
# Class 30 (DS): 0.9609
# Class 31 (DS): 0.9698
# Class 32 (DS): 0.9500
# Class 33 (DS): 0.9564
# Class 34 (DS): 0.9877
# Class 35 (DS): 0.8451
# Class 36 (DS): 0.9979
# Class 37 (DS): 0.8294
# Class 38 (DS): 0.9648
# Class 39 (DS): 0.9750
# Class 40 (DS): 0.9807
# Class 41 (DS): 0.9660
# Class 42 (DS): 0.9448
# Class 43 (DS): 0.9448
# Class 44 (DS): 0.9515
# ----------
# Epoch: 18, Phase: train, epoch loss: 0.0717, Av. Dice Score: 0.9552
# Class 0 (DS): 0.9327
# Class 1 (DS): 0.9039
# Class 2 (DS): 0.9722
# Class 3 (DS): 0.9731
# Class 4 (DS): 0.9259
# Class 5 (DS): 0.9484
# Class 6 (DS): 0.9656
# Class 7 (DS): 0.9637
# Class 8 (DS): 0.9696
# Class 9 (DS): 0.9564
# Class 10 (DS): 0.9687
# Class 11 (DS): 0.9445
# Class 12 (DS): 0.9472
# Class 13 (DS): 0.9693
# Class 14 (DS): 0.9805
# Class 15 (DS): 0.9686
# Class 16 (DS): 0.9676
# Class 17 (DS): 0.9629
# Class 18 (DS): 0.9866
# Class 19 (DS): 0.8692
# Class 20 (DS): 0.9323
# Class 21 (DS): 0.9120
# Class 22 (DS): 0.9741
# Class 23 (DS): 0.9750
# Class 24 (DS): 0.9270
# Class 25 (DS): 0.9470
# Class 26 (DS): 0.9720
# Class 27 (DS): 0.9699
# Class 28 (DS): 0.9724
# Class 29 (DS): 0.9630
# Class 30 (DS): 0.9608
# Class 31 (DS): 0.9791
# Class 32 (DS): 0.9675
# Class 33 (DS): 0.9636
# Class 34 (DS): 0.9882
# Class 35 (DS): 0.8692
# Class 36 (DS): 0.9886
# Class 37 (DS): 0.8501
# Class 38 (DS): 0.9627
# Class 39 (DS): 0.9808
# Class 40 (DS): 0.9848
# Class 41 (DS): 0.9804
# Class 42 (DS): 0.9560
# Class 43 (DS): 0.9586
# Class 44 (DS): 0.9712
# ----------
# Epoch: 18, Phase: validate, epoch loss: 0.0823, Av. Dice Score: 0.9473
# Class 0 (DS): 0.9261
# Class 1 (DS): 0.8988
# Class 2 (DS): 0.9708
# Class 3 (DS): 0.9489
# Class 4 (DS): 0.9178
# Class 5 (DS): 0.9367
# Class 6 (DS): 0.9503
# Class 7 (DS): 0.9607
# Class 8 (DS): 0.9719
# Class 9 (DS): 0.9336
# Class 10 (DS): 0.9677
# Class 11 (DS): 0.9342
# Class 12 (DS): 0.9384
# Class 13 (DS): 0.9591
# Class 14 (DS): 0.9755
# Class 15 (DS): 0.9708
# Class 16 (DS): 0.9577
# Class 17 (DS): 0.9524
# Class 18 (DS): 0.9811
# Class 19 (DS): 0.8763
# Class 20 (DS): 0.9184
# Class 21 (DS): 0.8897
# Class 22 (DS): 0.9771
# Class 23 (DS): 0.9726
# Class 24 (DS): 0.9297
# Class 25 (DS): 0.9391
# Class 26 (DS): 0.9651
# Class 27 (DS): 0.9615
# Class 28 (DS): 0.9763
# Class 29 (DS): 0.9630
# Class 30 (DS): 0.9553
# Class 31 (DS): 0.9732
# Class 32 (DS): 0.9475
# Class 33 (DS): 0.9581
# Class 34 (DS): 0.9871
# Class 35 (DS): 0.8535
# Class 36 (DS): 0.9980
# Class 37 (DS): 0.8264
# Class 38 (DS): 0.9613
# Class 39 (DS): 0.9780
# Class 40 (DS): 0.9809
# Class 41 (DS): 0.9625
# Class 42 (DS): 0.9494
# Class 43 (DS): 0.9265
# Class 44 (DS): 0.9501
# ----------
# Epoch: 19, Phase: train, epoch loss: 0.0721, Av. Dice Score: 0.9542
# Class 0 (DS): 0.9285
# Class 1 (DS): 0.8981
# Class 2 (DS): 0.9703
# Class 3 (DS): 0.9696
# Class 4 (DS): 0.9229
# Class 5 (DS): 0.9472
# Class 6 (DS): 0.9690
# Class 7 (DS): 0.9630
# Class 8 (DS): 0.9691
# Class 9 (DS): 0.9530
# Class 10 (DS): 0.9664
# Class 11 (DS): 0.9456
# Class 12 (DS): 0.9481
# Class 13 (DS): 0.9675
# Class 14 (DS): 0.9808
# Class 15 (DS): 0.9681
# Class 16 (DS): 0.9690
# Class 17 (DS): 0.9641
# Class 18 (DS): 0.9880
# Class 19 (DS): 0.8720
# Class 20 (DS): 0.9271
# Class 21 (DS): 0.9033
# Class 22 (DS): 0.9710
# Class 23 (DS): 0.9760
# Class 24 (DS): 0.9279
# Class 25 (DS): 0.9430
# Class 26 (DS): 0.9697
# Class 27 (DS): 0.9701
# Class 28 (DS): 0.9753
# Class 29 (DS): 0.9603
# Class 30 (DS): 0.9583
# Class 31 (DS): 0.9781
# Class 32 (DS): 0.9692
# Class 33 (DS): 0.9639
# Class 34 (DS): 0.9884
# Class 35 (DS): 0.8717
# Class 36 (DS): 0.9872
# Class 37 (DS): 0.8530
# Class 38 (DS): 0.9596
# Class 39 (DS): 0.9822
# Class 40 (DS): 0.9846
# Class 41 (DS): 0.9781
# Class 42 (DS): 0.9555
# Class 43 (DS): 0.9562
# Class 44 (DS): 0.9682
# ----------
# Epoch: 19, Phase: validate, epoch loss: 0.0796, Av. Dice Score: 0.9464
# Class 0 (DS): 0.9195
# Class 1 (DS): 0.8981
# Class 2 (DS): 0.9697
# Class 3 (DS): 0.9433
# Class 4 (DS): 0.9123
# Class 5 (DS): 0.9272
# Class 6 (DS): 0.9573
# Class 7 (DS): 0.9648
# Class 8 (DS): 0.9700
# Class 9 (DS): 0.9321
# Class 10 (DS): 0.9655
# Class 11 (DS): 0.9395
# Class 12 (DS): 0.9271
# Class 13 (DS): 0.9485
# Class 14 (DS): 0.9691
# Class 15 (DS): 0.9692
# Class 16 (DS): 0.9532
# Class 17 (DS): 0.9502
# Class 18 (DS): 0.9783
# Class 19 (DS): 0.8670
# Class 20 (DS): 0.9255
# Class 21 (DS): 0.9003
# Class 22 (DS): 0.9781
# Class 23 (DS): 0.9710
# Class 24 (DS): 0.9230
# Class 25 (DS): 0.9316
# Class 26 (DS): 0.9675
# Class 27 (DS): 0.9617
# Class 28 (DS): 0.9724
# Class 29 (DS): 0.9579
# Class 30 (DS): 0.9583
# Class 31 (DS): 0.9667
# Class 32 (DS): 0.9450
# Class 33 (DS): 0.9563
# Class 34 (DS): 0.9866
# Class 35 (DS): 0.8450
# Class 36 (DS): 0.9963
# Class 37 (DS): 0.8500
# Class 38 (DS): 0.9613
# Class 39 (DS): 0.9707
# Class 40 (DS): 0.9803
# Class 41 (DS): 0.9647
# Class 42 (DS): 0.9512
# Class 43 (DS): 0.9466
# Class 44 (DS): 0.9594
# ----------
# Epoch: 20, Phase: train, epoch loss: 0.0709, Av. Dice Score: 0.9549
# Class 0 (DS): 0.9315
# Class 1 (DS): 0.9038
# Class 2 (DS): 0.9715
# Class 3 (DS): 0.9694
# Class 4 (DS): 0.9265
# Class 5 (DS): 0.9479
# Class 6 (DS): 0.9664
# Class 7 (DS): 0.9655
# Class 8 (DS): 0.9706
# Class 9 (DS): 0.9546
# Class 10 (DS): 0.9694
# Class 11 (DS): 0.9450
# Class 12 (DS): 0.9483
# Class 13 (DS): 0.9670
# Class 14 (DS): 0.9797
# Class 15 (DS): 0.9676
# Class 16 (DS): 0.9675
# Class 17 (DS): 0.9647
# Class 18 (DS): 0.9850
# Class 19 (DS): 0.8688
# Class 20 (DS): 0.9313
# Class 21 (DS): 0.9113
# Class 22 (DS): 0.9725
# Class 23 (DS): 0.9761
# Class 24 (DS): 0.9306
# Class 25 (DS): 0.9425
# Class 26 (DS): 0.9709
# Class 27 (DS): 0.9690
# Class 28 (DS): 0.9743
# Class 29 (DS): 0.9608
# Class 30 (DS): 0.9585
# Class 31 (DS): 0.9775
# Class 32 (DS): 0.9701
# Class 33 (DS): 0.9643
# Class 34 (DS): 0.9868
# Class 35 (DS): 0.8684
# Class 36 (DS): 0.9884
# Class 37 (DS): 0.8521
# Class 38 (DS): 0.9638
# Class 39 (DS): 0.9791
# Class 40 (DS): 0.9840
# Class 41 (DS): 0.9789
# Class 42 (DS): 0.9591
# Class 43 (DS): 0.9597
# Class 44 (DS): 0.9685
# ----------
# Epoch: 20, Phase: validate, epoch loss: 0.0768, Av. Dice Score: 0.9484
# Class 0 (DS): 0.9304
# Class 1 (DS): 0.9018
# Class 2 (DS): 0.9698
# Class 3 (DS): 0.9472
# Class 4 (DS): 0.9157
# Class 5 (DS): 0.9375
# Class 6 (DS): 0.9626
# Class 7 (DS): 0.9670
# Class 8 (DS): 0.9707
# Class 9 (DS): 0.9373
# Class 10 (DS): 0.9653
# Class 11 (DS): 0.9402
# Class 12 (DS): 0.9378
# Class 13 (DS): 0.9529
# Class 14 (DS): 0.9701
# Class 15 (DS): 0.9687
# Class 16 (DS): 0.9524
# Class 17 (DS): 0.9522
# Class 18 (DS): 0.9793
# Class 19 (DS): 0.8657
# Class 20 (DS): 0.9310
# Class 21 (DS): 0.8931
# Class 22 (DS): 0.9748
# Class 23 (DS): 0.9728
# Class 24 (DS): 0.9271
# Class 25 (DS): 0.9399
# Class 26 (DS): 0.9662
# Class 27 (DS): 0.9671
# Class 28 (DS): 0.9739
# Class 29 (DS): 0.9595
# Class 30 (DS): 0.9567
# Class 31 (DS): 0.9730
# Class 32 (DS): 0.9507
# Class 33 (DS): 0.9588
# Class 34 (DS): 0.9879
# Class 35 (DS): 0.8512
# Class 36 (DS): 0.9961
# Class 37 (DS): 0.8314
# Class 38 (DS): 0.9634
# Class 39 (DS): 0.9734
# Class 40 (DS): 0.9822
# Class 41 (DS): 0.9619
# Class 42 (DS): 0.9494
# Class 43 (DS): 0.9498
# Class 44 (DS): 0.9609
# ----------
# Epoch: 21, Phase: train, epoch loss: 0.0701, Av. Dice Score: 0.9551
# Class 0 (DS): 0.9329
# Class 1 (DS): 0.9010
# Class 2 (DS): 0.9715
# Class 3 (DS): 0.9677
# Class 4 (DS): 0.9251
# Class 5 (DS): 0.9505
# Class 6 (DS): 0.9669
# Class 7 (DS): 0.9646
# Class 8 (DS): 0.9695
# Class 9 (DS): 0.9542
# Class 10 (DS): 0.9679
# Class 11 (DS): 0.9407
# Class 12 (DS): 0.9485
# Class 13 (DS): 0.9674
# Class 14 (DS): 0.9808
# Class 15 (DS): 0.9662
# Class 16 (DS): 0.9688
# Class 17 (DS): 0.9653
# Class 18 (DS): 0.9858
# Class 19 (DS): 0.8754
# Class 20 (DS): 0.9340
# Class 21 (DS): 0.9081
# Class 22 (DS): 0.9722
# Class 23 (DS): 0.9760
# Class 24 (DS): 0.9275
# Class 25 (DS): 0.9466
# Class 26 (DS): 0.9708
# Class 27 (DS): 0.9673
# Class 28 (DS): 0.9737
# Class 29 (DS): 0.9622
# Class 30 (DS): 0.9608
# Class 31 (DS): 0.9786
# Class 32 (DS): 0.9673
# Class 33 (DS): 0.9656
# Class 34 (DS): 0.9878
# Class 35 (DS): 0.8703
# Class 36 (DS): 0.9891
# Class 37 (DS): 0.8550
# Class 38 (DS): 0.9628
# Class 39 (DS): 0.9826
# Class 40 (DS): 0.9842
# Class 41 (DS): 0.9800
# Class 42 (DS): 0.9566
# Class 43 (DS): 0.9591
# Class 44 (DS): 0.9721
# ----------
# Epoch: 21, Phase: validate, epoch loss: 0.0797, Av. Dice Score: 0.9465
# Class 0 (DS): 0.9250
# Class 1 (DS): 0.8857
# Class 2 (DS): 0.9691
# Class 3 (DS): 0.9468
# Class 4 (DS): 0.9079
# Class 5 (DS): 0.9321
# Class 6 (DS): 0.9593
# Class 7 (DS): 0.9656
# Class 8 (DS): 0.9718
# Class 9 (DS): 0.9352
# Class 10 (DS): 0.9642
# Class 11 (DS): 0.9377
# Class 12 (DS): 0.9294
# Class 13 (DS): 0.9548
# Class 14 (DS): 0.9695
# Class 15 (DS): 0.9636
# Class 16 (DS): 0.9545
# Class 17 (DS): 0.9470
# Class 18 (DS): 0.9743
# Class 19 (DS): 0.8710
# Class 20 (DS): 0.9219
# Class 21 (DS): 0.8971
# Class 22 (DS): 0.9748
# Class 23 (DS): 0.9727
# Class 24 (DS): 0.9292
# Class 25 (DS): 0.9379
# Class 26 (DS): 0.9663
# Class 27 (DS): 0.9688
# Class 28 (DS): 0.9746
# Class 29 (DS): 0.9605
# Class 30 (DS): 0.9588
# Class 31 (DS): 0.9684
# Class 32 (DS): 0.9410
# Class 33 (DS): 0.9561
# Class 34 (DS): 0.9860
# Class 35 (DS): 0.8500
# Class 36 (DS): 0.9970
# Class 37 (DS): 0.8223
# Class 38 (DS): 0.9671
# Class 39 (DS): 0.9747
# Class 40 (DS): 0.9791
# Class 41 (DS): 0.9688
# Class 42 (DS): 0.9557
# Class 43 (DS): 0.9426
# Class 44 (DS): 0.9575
# ----------
# Epoch: 22, Phase: train, epoch loss: 0.0702, Av. Dice Score: 0.9548
# Class 0 (DS): 0.9294
# Class 1 (DS): 0.9061
# Class 2 (DS): 0.9735
# Class 3 (DS): 0.9670
# Class 4 (DS): 0.9233
# Class 5 (DS): 0.9484
# Class 6 (DS): 0.9672
# Class 7 (DS): 0.9662
# Class 8 (DS): 0.9698
# Class 9 (DS): 0.9567
# Class 10 (DS): 0.9663
# Class 11 (DS): 0.9416
# Class 12 (DS): 0.9488
# Class 13 (DS): 0.9682
# Class 14 (DS): 0.9793
# Class 15 (DS): 0.9675
# Class 16 (DS): 0.9691
# Class 17 (DS): 0.9619
# Class 18 (DS): 0.9864
# Class 19 (DS): 0.8675
# Class 20 (DS): 0.9314
# Class 21 (DS): 0.9129
# Class 22 (DS): 0.9725
# Class 23 (DS): 0.9749
# Class 24 (DS): 0.9317
# Class 25 (DS): 0.9425
# Class 26 (DS): 0.9700
# Class 27 (DS): 0.9706
# Class 28 (DS): 0.9726
# Class 29 (DS): 0.9603
# Class 30 (DS): 0.9590
# Class 31 (DS): 0.9763
# Class 32 (DS): 0.9701
# Class 33 (DS): 0.9639
# Class 34 (DS): 0.9875
# Class 35 (DS): 0.8664
# Class 36 (DS): 0.9883
# Class 37 (DS): 0.8549
# Class 38 (DS): 0.9637
# Class 39 (DS): 0.9782
# Class 40 (DS): 0.9848
# Class 41 (DS): 0.9801
# Class 42 (DS): 0.9568
# Class 43 (DS): 0.9623
# Class 44 (DS): 0.9709
# ----------
# Epoch: 22, Phase: validate, epoch loss: 0.0795, Av. Dice Score: 0.9457
# Class 0 (DS): 0.9211
# Class 1 (DS): 0.8920
# Class 2 (DS): 0.9658
# Class 3 (DS): 0.9442
# Class 4 (DS): 0.9074
# Class 5 (DS): 0.9317
# Class 6 (DS): 0.9564
# Class 7 (DS): 0.9635
# Class 8 (DS): 0.9716
# Class 9 (DS): 0.9335
# Class 10 (DS): 0.9642
# Class 11 (DS): 0.9269
# Class 12 (DS): 0.9390
# Class 13 (DS): 0.9538
# Class 14 (DS): 0.9671
# Class 15 (DS): 0.9680
# Class 16 (DS): 0.9533
# Class 17 (DS): 0.9468
# Class 18 (DS): 0.9767
# Class 19 (DS): 0.8712
# Class 20 (DS): 0.9247
# Class 21 (DS): 0.8964
# Class 22 (DS): 0.9755
# Class 23 (DS): 0.9679
# Class 24 (DS): 0.9206
# Class 25 (DS): 0.9346
# Class 26 (DS): 0.9663
# Class 27 (DS): 0.9688
# Class 28 (DS): 0.9750
# Class 29 (DS): 0.9612
# Class 30 (DS): 0.9561
# Class 31 (DS): 0.9704
# Class 32 (DS): 0.9492
# Class 33 (DS): 0.9537
# Class 34 (DS): 0.9864
# Class 35 (DS): 0.8429
# Class 36 (DS): 0.9972
# Class 37 (DS): 0.8318
# Class 38 (DS): 0.9657
# Class 39 (DS): 0.9758
# Class 40 (DS): 0.9785
# Class 41 (DS): 0.9626
# Class 42 (DS): 0.9483
# Class 43 (DS): 0.9377
# Class 44 (DS): 0.9541
# ----------
# Epoch: 23, Phase: train, epoch loss: 0.0687, Av. Dice Score: 0.9564
# Class 0 (DS): 0.9340
# Class 1 (DS): 0.9070
# Class 2 (DS): 0.9726
# Class 3 (DS): 0.9730
# Class 4 (DS): 0.9277
# Class 5 (DS): 0.9515
# Class 6 (DS): 0.9675
# Class 7 (DS): 0.9664
# Class 8 (DS): 0.9706
# Class 9 (DS): 0.9553
# Class 10 (DS): 0.9677
# Class 11 (DS): 0.9434
# Class 12 (DS): 0.9497
# Class 13 (DS): 0.9689
# Class 14 (DS): 0.9823
# Class 15 (DS): 0.9689
# Class 16 (DS): 0.9683
# Class 17 (DS): 0.9661
# Class 18 (DS): 0.9860
# Class 19 (DS): 0.8737
# Class 20 (DS): 0.9361
# Class 21 (DS): 0.9176
# Class 22 (DS): 0.9730
# Class 23 (DS): 0.9792
# Class 24 (DS): 0.9289
# Class 25 (DS): 0.9478
# Class 26 (DS): 0.9712
# Class 27 (DS): 0.9695
# Class 28 (DS): 0.9752
# Class 29 (DS): 0.9620
# Class 30 (DS): 0.9607
# Class 31 (DS): 0.9804
# Class 32 (DS): 0.9689
# Class 33 (DS): 0.9651
# Class 34 (DS): 0.9875
# Class 35 (DS): 0.8744
# Class 36 (DS): 0.9868
# Class 37 (DS): 0.8593
# Class 38 (DS): 0.9624
# Class 39 (DS): 0.9796
# Class 40 (DS): 0.9842
# Class 41 (DS): 0.9817
# Class 42 (DS): 0.9574
# Class 43 (DS): 0.9584
# Class 44 (DS): 0.9712
# ----------
# Epoch: 23, Phase: validate, epoch loss: 0.0806, Av. Dice Score: 0.9471
# Class 0 (DS): 0.9185
# Class 1 (DS): 0.8865
# Class 2 (DS): 0.9690
# Class 3 (DS): 0.9480
# Class 4 (DS): 0.9185
# Class 5 (DS): 0.9347
# Class 6 (DS): 0.9635
# Class 7 (DS): 0.9670
# Class 8 (DS): 0.9711
# Class 9 (DS): 0.9411
# Class 10 (DS): 0.9671
# Class 11 (DS): 0.9347
# Class 12 (DS): 0.9311
# Class 13 (DS): 0.9546
# Class 14 (DS): 0.9732
# Class 15 (DS): 0.9678
# Class 16 (DS): 0.9557
# Class 17 (DS): 0.9483
# Class 18 (DS): 0.9764
# Class 19 (DS): 0.8770
# Class 20 (DS): 0.9178
# Class 21 (DS): 0.8916
# Class 22 (DS): 0.9725
# Class 23 (DS): 0.9688
# Class 24 (DS): 0.9225
# Class 25 (DS): 0.9391
# Class 26 (DS): 0.9706
# Class 27 (DS): 0.9663
# Class 28 (DS): 0.9736
# Class 29 (DS): 0.9638
# Class 30 (DS): 0.9583
# Class 31 (DS): 0.9695
# Class 32 (DS): 0.9496
# Class 33 (DS): 0.9578
# Class 34 (DS): 0.9860
# Class 35 (DS): 0.8550
# Class 36 (DS): 0.9957
# Class 37 (DS): 0.8289
# Class 38 (DS): 0.9633
# Class 39 (DS): 0.9761
# Class 40 (DS): 0.9743
# Class 41 (DS): 0.9654
# Class 42 (DS): 0.9468
# Class 43 (DS): 0.9405
# Class 44 (DS): 0.9617
# ----------
# Epoch: 24, Phase: train, epoch loss: 0.0690, Av. Dice Score: 0.9562
# Class 0 (DS): 0.9351
# Class 1 (DS): 0.9039
# Class 2 (DS): 0.9719
# Class 3 (DS): 0.9712
# Class 4 (DS): 0.9280
# Class 5 (DS): 0.9498
# Class 6 (DS): 0.9679
# Class 7 (DS): 0.9658
# Class 8 (DS): 0.9710
# Class 9 (DS): 0.9575
# Class 10 (DS): 0.9679
# Class 11 (DS): 0.9446
# Class 12 (DS): 0.9505
# Class 13 (DS): 0.9683
# Class 14 (DS): 0.9813
# Class 15 (DS): 0.9691
# Class 16 (DS): 0.9687
# Class 17 (DS): 0.9648
# Class 18 (DS): 0.9862
# Class 19 (DS): 0.8775
# Class 20 (DS): 0.9373
# Class 21 (DS): 0.9132
# Class 22 (DS): 0.9719
# Class 23 (DS): 0.9755
# Class 24 (DS): 0.9293
# Class 25 (DS): 0.9453
# Class 26 (DS): 0.9707
# Class 27 (DS): 0.9675
# Class 28 (DS): 0.9748
# Class 29 (DS): 0.9616
# Class 30 (DS): 0.9623
# Class 31 (DS): 0.9794
# Class 32 (DS): 0.9699
# Class 33 (DS): 0.9645
# Class 34 (DS): 0.9876
# Class 35 (DS): 0.8725
# Class 36 (DS): 0.9875
# Class 37 (DS): 0.8572
# Class 38 (DS): 0.9613
# Class 39 (DS): 0.9819
# Class 40 (DS): 0.9846
# Class 41 (DS): 0.9803
# Class 42 (DS): 0.9585
# Class 43 (DS): 0.9617
# Class 44 (DS): 0.9718
# ----------
# Epoch: 24, Phase: validate, epoch loss: 0.0786, Av. Dice Score: 0.9452
# Class 0 (DS): 0.9288
# Class 1 (DS): 0.9010
# Class 2 (DS): 0.9684
# Class 3 (DS): 0.9434
# Class 4 (DS): 0.9052
# Class 5 (DS): 0.9354
# Class 6 (DS): 0.9432
# Class 7 (DS): 0.9662
# Class 8 (DS): 0.9675
# Class 9 (DS): 0.9288
# Class 10 (DS): 0.9628
# Class 11 (DS): 0.9336
# Class 12 (DS): 0.9369
# Class 13 (DS): 0.9524
# Class 14 (DS): 0.9728
# Class 15 (DS): 0.9652
# Class 16 (DS): 0.9555
# Class 17 (DS): 0.9440
# Class 18 (DS): 0.9731
# Class 19 (DS): 0.8586
# Class 20 (DS): 0.9244
# Class 21 (DS): 0.8974
# Class 22 (DS): 0.9760
# Class 23 (DS): 0.9671
# Class 24 (DS): 0.9267
# Class 25 (DS): 0.9375
# Class 26 (DS): 0.9619
# Class 27 (DS): 0.9629
# Class 28 (DS): 0.9740
# Class 29 (DS): 0.9587
# Class 30 (DS): 0.9543
# Class 31 (DS): 0.9723
# Class 32 (DS): 0.9402
# Class 33 (DS): 0.9539
# Class 34 (DS): 0.9797
# Class 35 (DS): 0.8407
# Class 36 (DS): 0.9963
# Class 37 (DS): 0.8346
# Class 38 (DS): 0.9627
# Class 39 (DS): 0.9722
# Class 40 (DS): 0.9801
# Class 41 (DS): 0.9655
# Class 42 (DS): 0.9533
# Class 43 (DS): 0.9386
# Class 44 (DS): 0.9602
# ----------
# Epoch: 25, Phase: train, epoch loss: 0.0680, Av. Dice Score: 0.9558
# Class 0 (DS): 0.9334
# Class 1 (DS): 0.9069
# Class 2 (DS): 0.9729
# Class 3 (DS): 0.9665
# Class 4 (DS): 0.9254
# Class 5 (DS): 0.9475
# Class 6 (DS): 0.9672
# Class 7 (DS): 0.9663
# Class 8 (DS): 0.9705
# Class 9 (DS): 0.9579
# Class 10 (DS): 0.9668
# Class 11 (DS): 0.9426
# Class 12 (DS): 0.9514
# Class 13 (DS): 0.9682
# Class 14 (DS): 0.9811
# Class 15 (DS): 0.9672
# Class 16 (DS): 0.9695
# Class 17 (DS): 0.9659
# Class 18 (DS): 0.9858
# Class 19 (DS): 0.8696
# Class 20 (DS): 0.9338
# Class 21 (DS): 0.9079
# Class 22 (DS): 0.9729
# Class 23 (DS): 0.9772
# Class 24 (DS): 0.9292
# Class 25 (DS): 0.9464
# Class 26 (DS): 0.9714
# Class 27 (DS): 0.9694
# Class 28 (DS): 0.9735
# Class 29 (DS): 0.9622
# Class 30 (DS): 0.9592
# Class 31 (DS): 0.9782
# Class 32 (DS): 0.9704
# Class 33 (DS): 0.9653
# Class 34 (DS): 0.9880
# Class 35 (DS): 0.8735
# Class 36 (DS): 0.9873
# Class 37 (DS): 0.8570
# Class 38 (DS): 0.9619
# Class 39 (DS): 0.9816
# Class 40 (DS): 0.9849
# Class 41 (DS): 0.9789
# Class 42 (DS): 0.9609
# Class 43 (DS): 0.9639
# Class 44 (DS): 0.9714
# ----------
# Epoch: 25, Phase: validate, epoch loss: 0.0788, Av. Dice Score: 0.9466
# Class 0 (DS): 0.9175
# Class 1 (DS): 0.9014
# Class 2 (DS): 0.9667
# Class 3 (DS): 0.9452
# Class 4 (DS): 0.9094
# Class 5 (DS): 0.9369
# Class 6 (DS): 0.9517
# Class 7 (DS): 0.9659
# Class 8 (DS): 0.9681
# Class 9 (DS): 0.9326
# Class 10 (DS): 0.9638
# Class 11 (DS): 0.9275
# Class 12 (DS): 0.9399
# Class 13 (DS): 0.9535
# Class 14 (DS): 0.9743
# Class 15 (DS): 0.9642
# Class 16 (DS): 0.9521
# Class 17 (DS): 0.9472
# Class 18 (DS): 0.9784
# Class 19 (DS): 0.8691
# Class 20 (DS): 0.9266
# Class 21 (DS): 0.9008
# Class 22 (DS): 0.9718
# Class 23 (DS): 0.9683
# Class 24 (DS): 0.9216
# Class 25 (DS): 0.9399
# Class 26 (DS): 0.9680
# Class 27 (DS): 0.9615
# Class 28 (DS): 0.9756
# Class 29 (DS): 0.9550
# Class 30 (DS): 0.9599
# Class 31 (DS): 0.9678
# Class 32 (DS): 0.9495
# Class 33 (DS): 0.9549
# Class 34 (DS): 0.9877
# Class 35 (DS): 0.8473
# Class 36 (DS): 0.9973
# Class 37 (DS): 0.8444
# Class 38 (DS): 0.9675
# Class 39 (DS): 0.9715
# Class 40 (DS): 0.9770
# Class 41 (DS): 0.9656
# Class 42 (DS): 0.9504
# Class 43 (DS): 0.9459
# Class 44 (DS): 0.9566
# ----------
# Epoch: 26, Phase: train, epoch loss: 0.0703, Av. Dice Score: 0.9548
# Class 0 (DS): 0.9314
# Class 1 (DS): 0.9047
# Class 2 (DS): 0.9697
# Class 3 (DS): 0.9707
# Class 4 (DS): 0.9255
# Class 5 (DS): 0.9461
# Class 6 (DS): 0.9663
# Class 7 (DS): 0.9652
# Class 8 (DS): 0.9691
# Class 9 (DS): 0.9526
# Class 10 (DS): 0.9680
# Class 11 (DS): 0.9455
# Class 12 (DS): 0.9504
# Class 13 (DS): 0.9662
# Class 14 (DS): 0.9809
# Class 15 (DS): 0.9680
# Class 16 (DS): 0.9683
# Class 17 (DS): 0.9627
# Class 18 (DS): 0.9863
# Class 19 (DS): 0.8756
# Class 20 (DS): 0.9326
# Class 21 (DS): 0.9064
# Class 22 (DS): 0.9706
# Class 23 (DS): 0.9788
# Class 24 (DS): 0.9305
# Class 25 (DS): 0.9421
# Class 26 (DS): 0.9709
# Class 27 (DS): 0.9684
# Class 28 (DS): 0.9728
# Class 29 (DS): 0.9596
# Class 30 (DS): 0.9611
# Class 31 (DS): 0.9771
# Class 32 (DS): 0.9682
# Class 33 (DS): 0.9644
# Class 34 (DS): 0.9853
# Class 35 (DS): 0.8674
# Class 36 (DS): 0.9879
# Class 37 (DS): 0.8543
# Class 38 (DS): 0.9629
# Class 39 (DS): 0.9798
# Class 40 (DS): 0.9859
# Class 41 (DS): 0.9794
# Class 42 (DS): 0.9601
# Class 43 (DS): 0.9582
# Class 44 (DS): 0.9679
# ----------
# Epoch: 26, Phase: validate, epoch loss: 0.0794, Av. Dice Score: 0.9470
# Class 0 (DS): 0.9280
# Class 1 (DS): 0.9029
# Class 2 (DS): 0.9721
# Class 3 (DS): 0.9483
# Class 4 (DS): 0.9101
# Class 5 (DS): 0.9342
# Class 6 (DS): 0.9570
# Class 7 (DS): 0.9654
# Class 8 (DS): 0.9740
# Class 9 (DS): 0.9264
# Class 10 (DS): 0.9630
# Class 11 (DS): 0.9359
# Class 12 (DS): 0.9342
# Class 13 (DS): 0.9546
# Class 14 (DS): 0.9761
# Class 15 (DS): 0.9679
# Class 16 (DS): 0.9545
# Class 17 (DS): 0.9477
# Class 18 (DS): 0.9753
# Class 19 (DS): 0.8675
# Class 20 (DS): 0.9284
# Class 21 (DS): 0.8970
# Class 22 (DS): 0.9705
# Class 23 (DS): 0.9732
# Class 24 (DS): 0.9275
# Class 25 (DS): 0.9396
# Class 26 (DS): 0.9658
# Class 27 (DS): 0.9596
# Class 28 (DS): 0.9738
# Class 29 (DS): 0.9564
# Class 30 (DS): 0.9615
# Class 31 (DS): 0.9709
# Class 32 (DS): 0.9448
# Class 33 (DS): 0.9586
# Class 34 (DS): 0.9833
# Class 35 (DS): 0.8478
# Class 36 (DS): 0.9968
# Class 37 (DS): 0.8278
# Class 38 (DS): 0.9626
# Class 39 (DS): 0.9711
# Class 40 (DS): 0.9830
# Class 41 (DS): 0.9681
# Class 42 (DS): 0.9524
# Class 43 (DS): 0.9431
# Class 44 (DS): 0.9587
# ----------
# Epoch: 27, Phase: train, epoch loss: 0.0681, Av. Dice Score: 0.9564
# Class 0 (DS): 0.9360
# Class 1 (DS): 0.9075
# Class 2 (DS): 0.9745
# Class 3 (DS): 0.9723
# Class 4 (DS): 0.9259
# Class 5 (DS): 0.9498
# Class 6 (DS): 0.9685
# Class 7 (DS): 0.9659
# Class 8 (DS): 0.9702
# Class 9 (DS): 0.9569
# Class 10 (DS): 0.9710
# Class 11 (DS): 0.9461
# Class 12 (DS): 0.9493
# Class 13 (DS): 0.9665
# Class 14 (DS): 0.9796
# Class 15 (DS): 0.9700
# Class 16 (DS): 0.9692
# Class 17 (DS): 0.9647
# Class 18 (DS): 0.9844
# Class 19 (DS): 0.8740
# Class 20 (DS): 0.9330
# Class 21 (DS): 0.9134
# Class 22 (DS): 0.9729
# Class 23 (DS): 0.9772
# Class 24 (DS): 0.9297
# Class 25 (DS): 0.9487
# Class 26 (DS): 0.9706
# Class 27 (DS): 0.9710
# Class 28 (DS): 0.9723
# Class 29 (DS): 0.9615
# Class 30 (DS): 0.9618
# Class 31 (DS): 0.9769
# Class 32 (DS): 0.9700
# Class 33 (DS): 0.9673
# Class 34 (DS): 0.9863
# Class 35 (DS): 0.8715
# Class 36 (DS): 0.9886
# Class 37 (DS): 0.8605
# Class 38 (DS): 0.9620
# Class 39 (DS): 0.9806
# Class 40 (DS): 0.9848
# Class 41 (DS): 0.9797
# Class 42 (DS): 0.9609
# Class 43 (DS): 0.9607
# Class 44 (DS): 0.9722
# ----------
# Epoch: 27, Phase: validate, epoch loss: 0.0761, Av. Dice Score: 0.9494
# Class 0 (DS): 0.9281
# Class 1 (DS): 0.9057
# Class 2 (DS): 0.9717
# Class 3 (DS): 0.9378
# Class 4 (DS): 0.9228
# Class 5 (DS): 0.9419
# Class 6 (DS): 0.9640
# Class 7 (DS): 0.9690
# Class 8 (DS): 0.9715
# Class 9 (DS): 0.9424
# Class 10 (DS): 0.9658
# Class 11 (DS): 0.9347
# Class 12 (DS): 0.9381
# Class 13 (DS): 0.9528
# Class 14 (DS): 0.9668
# Class 15 (DS): 0.9691
# Class 16 (DS): 0.9562
# Class 17 (DS): 0.9531
# Class 18 (DS): 0.9792
# Class 19 (DS): 0.8693
# Class 20 (DS): 0.9274
# Class 21 (DS): 0.8989
# Class 22 (DS): 0.9724
# Class 23 (DS): 0.9714
# Class 24 (DS): 0.9270
# Class 25 (DS): 0.9427
# Class 26 (DS): 0.9658
# Class 27 (DS): 0.9697
# Class 28 (DS): 0.9727
# Class 29 (DS): 0.9594
# Class 30 (DS): 0.9590
# Class 31 (DS): 0.9717
# Class 32 (DS): 0.9481
# Class 33 (DS): 0.9613
# Class 34 (DS): 0.9843
# Class 35 (DS): 0.8528
# Class 36 (DS): 0.9976
# Class 37 (DS): 0.8436
# Class 38 (DS): 0.9662
# Class 39 (DS): 0.9742
# Class 40 (DS): 0.9830
# Class 41 (DS): 0.9707
# Class 42 (DS): 0.9521
# Class 43 (DS): 0.9544
# Class 44 (DS): 0.9556
# ----------
# Epoch: 28, Phase: train, epoch loss: 0.0668, Av. Dice Score: 0.9569
# Class 0 (DS): 0.9344
# Class 1 (DS): 0.9093
# Class 2 (DS): 0.9723
# Class 3 (DS): 0.9725
# Class 4 (DS): 0.9271
# Class 5 (DS): 0.9527
# Class 6 (DS): 0.9684
# Class 7 (DS): 0.9676
# Class 8 (DS): 0.9706
# Class 9 (DS): 0.9605
# Class 10 (DS): 0.9686
# Class 11 (DS): 0.9474
# Class 12 (DS): 0.9451
# Class 13 (DS): 0.9678
# Class 14 (DS): 0.9805
# Class 15 (DS): 0.9702
# Class 16 (DS): 0.9687
# Class 17 (DS): 0.9663
# Class 18 (DS): 0.9872
# Class 19 (DS): 0.8712
# Class 20 (DS): 0.9367
# Class 21 (DS): 0.9145
# Class 22 (DS): 0.9728
# Class 23 (DS): 0.9785
# Class 24 (DS): 0.9296
# Class 25 (DS): 0.9471
# Class 26 (DS): 0.9699
# Class 27 (DS): 0.9696
# Class 28 (DS): 0.9737
# Class 29 (DS): 0.9630
# Class 30 (DS): 0.9605
# Class 31 (DS): 0.9793
# Class 32 (DS): 0.9697
# Class 33 (DS): 0.9677
# Class 34 (DS): 0.9889
# Class 35 (DS): 0.8726
# Class 36 (DS): 0.9892
# Class 37 (DS): 0.8586
# Class 38 (DS): 0.9645
# Class 39 (DS): 0.9809
# Class 40 (DS): 0.9856
# Class 41 (DS): 0.9825
# Class 42 (DS): 0.9630
# Class 43 (DS): 0.9622
# Class 44 (DS): 0.9732
# ----------
# Epoch: 28, Phase: validate, epoch loss: 0.0757, Av. Dice Score: 0.9504
# Class 0 (DS): 0.9307
# Class 1 (DS): 0.9061
# Class 2 (DS): 0.9732
# Class 3 (DS): 0.9548
# Class 4 (DS): 0.9190
# Class 5 (DS): 0.9310
# Class 6 (DS): 0.9598
# Class 7 (DS): 0.9698
# Class 8 (DS): 0.9749
# Class 9 (DS): 0.9372
# Class 10 (DS): 0.9689
# Class 11 (DS): 0.9465
# Class 12 (DS): 0.9437
# Class 13 (DS): 0.9572
# Class 14 (DS): 0.9723
# Class 15 (DS): 0.9671
# Class 16 (DS): 0.9587
# Class 17 (DS): 0.9479
# Class 18 (DS): 0.9791
# Class 19 (DS): 0.8795
# Class 20 (DS): 0.9222
# Class 21 (DS): 0.9000
# Class 22 (DS): 0.9780
# Class 23 (DS): 0.9738
# Class 24 (DS): 0.9308
# Class 25 (DS): 0.9390
# Class 26 (DS): 0.9717
# Class 27 (DS): 0.9671
# Class 28 (DS): 0.9746
# Class 29 (DS): 0.9643
# Class 30 (DS): 0.9643
# Class 31 (DS): 0.9745
# Class 32 (DS): 0.9504
# Class 33 (DS): 0.9575
# Class 34 (DS): 0.9896
# Class 35 (DS): 0.8594
# Class 36 (DS): 0.9975
# Class 37 (DS): 0.8400
# Class 38 (DS): 0.9657
# Class 39 (DS): 0.9735
# Class 40 (DS): 0.9804
# Class 41 (DS): 0.9674
# Class 42 (DS): 0.9501
# Class 43 (DS): 0.9400
# Class 44 (DS): 0.9574
# ----------
# Epoch: 29, Phase: train, epoch loss: 0.0665, Av. Dice Score: 0.9566
# Class 0 (DS): 0.9342
# Class 1 (DS): 0.9099
# Class 2 (DS): 0.9750
# Class 3 (DS): 0.9741
# Class 4 (DS): 0.9258
# Class 5 (DS): 0.9497
# Class 6 (DS): 0.9659
# Class 7 (DS): 0.9667
# Class 8 (DS): 0.9715
# Class 9 (DS): 0.9566
# Class 10 (DS): 0.9670
# Class 11 (DS): 0.9459
# Class 12 (DS): 0.9493
# Class 13 (DS): 0.9676
# Class 14 (DS): 0.9806
# Class 15 (DS): 0.9680
# Class 16 (DS): 0.9671
# Class 17 (DS): 0.9626
# Class 18 (DS): 0.9863
# Class 19 (DS): 0.8757
# Class 20 (DS): 0.9354
# Class 21 (DS): 0.9150
# Class 22 (DS): 0.9752
# Class 23 (DS): 0.9799
# Class 24 (DS): 0.9304
# Class 25 (DS): 0.9476
# Class 26 (DS): 0.9719
# Class 27 (DS): 0.9706
# Class 28 (DS): 0.9747
# Class 29 (DS): 0.9618
# Class 30 (DS): 0.9583
# Class 31 (DS): 0.9790
# Class 32 (DS): 0.9692
# Class 33 (DS): 0.9652
# Class 34 (DS): 0.9882
# Class 35 (DS): 0.8707
# Class 36 (DS): 0.9886
# Class 37 (DS): 0.8609
# Class 38 (DS): 0.9607
# Class 39 (DS): 0.9825
# Class 40 (DS): 0.9858
# Class 41 (DS): 0.9827
# Class 42 (DS): 0.9602
# Class 43 (DS): 0.9628
# Class 44 (DS): 0.9703
# ----------
# Epoch: 29, Phase: validate, epoch loss: 0.0805, Av. Dice Score: 0.9458
# Class 0 (DS): 0.9285
# Class 1 (DS): 0.9056
# Class 2 (DS): 0.9649
# Class 3 (DS): 0.9436
# Class 4 (DS): 0.9086
# Class 5 (DS): 0.9287
# Class 6 (DS): 0.9542
# Class 7 (DS): 0.9687
# Class 8 (DS): 0.9648
# Class 9 (DS): 0.9355
# Class 10 (DS): 0.9612
# Class 11 (DS): 0.9336
# Class 12 (DS): 0.9385
# Class 13 (DS): 0.9504
# Class 14 (DS): 0.9758
# Class 15 (DS): 0.9670
# Class 16 (DS): 0.9514
# Class 17 (DS): 0.9521
# Class 18 (DS): 0.9815
# Class 19 (DS): 0.8738
# Class 20 (DS): 0.9146
# Class 21 (DS): 0.8887
# Class 22 (DS): 0.9748
# Class 23 (DS): 0.9676
# Class 24 (DS): 0.9241
# Class 25 (DS): 0.9415
# Class 26 (DS): 0.9653
# Class 27 (DS): 0.9624
# Class 28 (DS): 0.9732
# Class 29 (DS): 0.9617
# Class 30 (DS): 0.9545
# Class 31 (DS): 0.9725
# Class 32 (DS): 0.9465
# Class 33 (DS): 0.9570
# Class 34 (DS): 0.9863
# Class 35 (DS): 0.8505
# Class 36 (DS): 0.9963
# Class 37 (DS): 0.8275
# Class 38 (DS): 0.9630
# Class 39 (DS): 0.9765
# Class 40 (DS): 0.9780
# Class 41 (DS): 0.9589
# Class 42 (DS): 0.9510
# Class 43 (DS): 0.9391
# Class 44 (DS): 0.9418
# ----------
# --------------------------------------------------
# Training complete in 176m 21s
# Best val dice loss: 0.075729, Best Average DS: 0.950363

# %%
optimizer = optim.Adam(model.parameters(),lr = 1e-5)

# %%
model, loss_hist, dice_hist = train_model(model, optimizer,dataloader,'exp_3_dnc_then_d_lr_1e-5',num_seg = num_seg, num_epochs = 30,\
                                         every = 1, print_all_ds = True)

# %%
def dice_loss_2(true,scores,mean, epsilon = 1e-4,p = 2,we = 0.05):
#     N, C, sh1, sh2 = true1.size()
    
#     true = []
#     scores = []
#     for c in range(N):
#         if not torch.sum(true1[c,1:,:,:])==0:
#             true.append(true1[c,:,:,:])
#             scores.append(scores1[c,:,:,:])
#     try:
#         true = torch.stack(true)
#         scores = torch.stack(scores)
#     except:
#         return -1
    
    
    
    N, C, sh1, sh2 = true.size()
#     grad_mask = get_gradient(true)
#     grad_mask = grad_mask.view(N,C,-1)
    
    preds = F.softmax(scores, dim = 1)
    true = true.view(N, C, -1)
    preds = preds.view(N, C, -1)
    wts = torch.sum(true, dim = 2) + epsilon
#     mean = 1/torch.pow(mean,p)
    wts[:,:] = mean[None].repeat(N,1)
#     wts = wts/(torch.sum(wts,dim = 1)[:,None])
#     print(wts)
    grad_wts = torch.max(mean)
    prod = torch.sum(true*preds,dim = 2)
    sum_tnp = torch.sum(true + preds, dim = 2)
    num = torch.sum(wts * prod, dim = 1)
    denom = torch.sum(wts * sum_tnp, dim = 1) + epsilon
    loss = 1 - 2*(num/denom)
#     cel = -torch.sum(wts * torch.sum(true*torch.log(preds),dim = 2),dim = 1)
#     grad_loss = -torch.sum(2*grad_wts * torch.sum(grad_mask*torch.log(preds),dim = 2),dim = 1)
#     return 40*torch.mean(loss)+we*torch.mean(cel)
    return torch.mean(loss)

# %%
model, loss_hist, dice_hist = train_model(model, optimizer,dataloader,'exp_4_dnc_then_d_lr_1e-5',num_seg = num_seg, num_epochs = 30,\
                                         every = 1, print_all_ds = True)

# %%
#most recent model
#guassian_gamma_v1_4

# %%
def visualize1(image):
    p = F.softmax(image,dim = 0)
    p_maxim = torch.max(p, dim=0)[1]
    img = []
    for seg in range(num_seg):
        masked = (p_maxim==seg).data.type(torch.cuda.FloatTensor)
        img.append(masked)
    return torch.stack(img).unsqueeze(1).cpu()

# %%
# %matplotlib inline
def show(img):    
    npimg = img.numpy()
    plt.figure(figsize = (20,20))
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
    plt.show()

# %%
def visualize_few():
    data = next(iter(dataloader["validate"]))
    model.train(False)
    x = data['x']
    y = data['y']
    x = Variable(x).cuda()
    y = Variable(y).cuda()
                
    output = model(x)
    for i in range(bs):
        print('-'*100)
        print('Ground Truth')
        abc = data['y'][i,:,:,:]
        bcd = abc.unsqueeze(1)
        show(make_grid(bcd,padding=10,pad_value=1)) 
        print('-'*100)
        print('Prediction')
        show(make_grid(visualize1(output[i,:,:,:]),padding=10,pad_value=1))

# %%
visualize_few()
# Out:
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
# ----------------------------------------------------------------------------------------------------
# Ground Truth
# ----------------------------------------------------------------------------------------------------
# Prediction
